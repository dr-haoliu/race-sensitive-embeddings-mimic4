# %% [markdown]
# # Extract Demographic data from AACT

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import sys
import gc
import time
import itertools
import functools
import operator
import json
import psycopg2
import pickle
import os
import requests

# %%
conn_acct = psycopg2.connect(
    host="aact-db.ctti-clinicaltrials.org",
    database="aact",
    user="xxxx",
    password="xxxx")
cur_acct = conn_acct.cursor()

# %% [markdown]
# ## get age segmentation of nctids

# %%
sql = """
select b.nct_id, b.category as cat, sum(b.param_value_num) as total_participants
from
(select bm.nct_id, lower(concat(bm.category, bm.classification)) as category, bm.param_value_num, bm.title, bm.param_type, bm.ctgov_group_code
from baseline_measurements as bm join result_groups as r
on bm.nct_id = r.nct_id and bm.ctgov_group_code = r.ctgov_group_code
and lower(r.title) != 'total') as b
join studies as s on b.nct_id = s.nct_id
where s.overall_status = 'Completed' 
and s.study_first_submitted_date < '2022-01-01'
and (b.param_type = 'Count of Participants' or b.param_type = 'Number')
and (b.title ~* 'Age, Categorical' or b.title ~* 'Age, Customized')
-- and nct_id = 'NCT03086369'
group by b.nct_id, cat
order by b.nct_id;
"""

# %%
cur_acct.execute(sql)
trial_with_age_info = cur_acct.fetchall()
table_trial_age = pd.DataFrame().from_dict(trial_with_age_info)

# %%
len(table_trial_age.nctid.unique())
# Out:
# 17972

# %%
table_trial_age.columns = ["nctid", "age", "count"]
table_trial_age.head(10)
# Out:
#          nctid                      age  count
# 0  NCT00000134               <=18 years    0.0
# 1  NCT00000134               >=65 years    0.0
# 2  NCT00000134  between 18 and 65 years  279.0
# 3  NCT00000135               <=18 years    0.0
# 4  NCT00000135               >=65 years    0.0
# 5  NCT00000135  between 18 and 65 years  209.0
# 6  NCT00000136               <=18 years    0.0
# 7  NCT00000136               >=65 years    0.0
# 8  NCT00000136  between 18 and 65 years  234.0
# 9  NCT00000142               <=18 years    0.0

# %%
file_name = 'age_segment_by_nctid.tsv'
table_trial_age.to_csv(file_name, sep='\t', encoding='utf-8', index=False)

# !cp age_segment_by_nctid.tsv  /content/gdrive/MyDrive/Demographic\ Analysis\ Project/

# %% [markdown]
# ## get race segmentation of nctids

# %%
sql = """
select b.nct_id, b.category as cat, sum(b.param_value_num) as total_participants
from
(select bm.nct_id, lower(concat(bm.category, bm.classification)) as category, bm.param_value_num, bm.title, bm.param_type, bm.ctgov_group_code
from baseline_measurements as bm join result_groups as r
on bm.nct_id = r.nct_id and bm.ctgov_group_code = r.ctgov_group_code
and lower(r.title) != 'total') as b
join studies as s on b.nct_id = s.nct_id
where s.overall_status = 'Completed' 
and s.study_first_submitted_date < '2022-01-01'
and (b.param_type = 'Count of Participants' or b.param_type = 'Number')
and (b.title ~* 'race' or b.title ~* 'ethnicity') 
and (b.category ~* 'africa' or b.category ~* 'black' or b.category ~*'white')
-- and nct_id = 'NCT03086369'
group by b.nct_id, cat
order by b.nct_id;
"""

# %%
cur_acct.execute(sql)
trial_with_race_info = cur_acct.fetchall()
table_trial_race = pd.DataFrame().from_dict(trial_with_race_info)

# %%
table_trial_race.columns = ["nctid", "race", "count"]
table_trial_race.head(10)
# Out:
#          nctid                       race   count
# 0  NCT00000125           african american   408.0
# 1  NCT00000125                      white  1137.0
# 2  NCT00000392                      black    10.0
# 3  NCT00000392                      white   177.0
# 4  NCT00000620                   nonwhite  3647.0
# 5  NCT00000620                      white  6604.0
# 6  NCT00001262  black or african american    10.0
# 7  NCT00001262                      white    44.0
# 8  NCT00001277  black or african american   101.0
# 9  NCT00001277                      white   735.0

# %%
table_trial_race.nctid.nunique()
# Out:
# 19940

# %%
nctid_race_list= table_trial_race.nctid.to_list()
print(f'nctid race list len: {len(set(nctid_race_list))}')
# Out:
# nctid race list len: 19940

# %%
file_name = 'race_segment_by_nctid.tsv'
table_trial_race.to_csv(file_name, sep='\t', encoding='utf-8', index=False)

# !cp race_segment_by_nctid.tsv  /content/gdrive/MyDrive/Demographic\ Analysis\ Project/

# %% [markdown]
# ## get nctids from age and race

# %%
nctid_age_list= table_trial_age.nctid.to_list()
nctid_race_list= table_trial_race.nctid.to_list()
print(f'nctid age list len: {len(set(nctid_age_list))}')
print(f'nctid race list len: {len(set(nctid_race_list))}')

nctid_list = list(set(nctid_age_list).union(set(nctid_race_list)))

print(f'nctid total list len: {len(nctid_list)}')
# Out:
# nctid age list len: 18037
# nctid race list len: 18417
# nctid total list len: 30151

# %% [markdown]
# old results
# ```
# nctid age list len: 18029
# nctid race list len: 22480
# nctid total list len: 34210
# ```

# %%
df = pd.DataFrame(nctid_list)
df.columns =['nctid']
print(df[:10])
file_name = 'nctid_list.tsv'
df.to_csv(file_name, sep='\t', encoding='utf-8', index=False)
# Out:
#          nctid
# 0  NCT03633929
# 1  NCT01822678
# 2  NCT00787761
# 3  NCT02272413
# 4  NCT03720470
# 5  NCT02703259
# 6  NCT02783170
# 7  NCT00723190
# 8  NCT01033747
# 9  NCT01431638

# %%
# !cp nctid_list.tsv  /content/gdrive/MyDrive/Demographic\ Analysis\ Project/

# %%
# !ls /content/gdrive/MyDrive/Demographic\ Analysis\ Project/
# Out:
# 'Demographic Bias Project Proposal.gdoc'   nctid_to_pmid_dict.pickle
#  nctid_list.tsv				  'Script v1.ipynb'

# %% [markdown]
# ## match nctid to pubmed id

# %%
from xml.etree import ElementTree
import requests
import time
import datetime

# %%
def get_pubmed_linked_articles(nct_id, completion_date, query_type):
    '''
    Given an NCT ID, search PubMed for related results articles.
    '''
    url = get_pubmed_linked_articles_url(nct_id, completion_date,
                                         query_type)
    resp = get_response(url)
    data = resp.json()
    ids = extract_pubmed_ids_from_json(data)
    for id1 in ids[:]:
        title = get_pubmed_title(id1)
        if is_study_protocol(title):
            ids.remove(id1)
        time.sleep(0.5)
    return ids

def get_pubmed_linked_articles_url(nct_id, completion_date,
                                   query_type):
    url = 'http://eutils.ncbi.nlm.nih.gov/entrez/eutils/'
    url += 'esearch.fcgi?db=pubmed&retmode=json&term='
    url += '(%s[si] OR %s[Title/Abstract]) ' % (nct_id, nct_id)
    url += 'AND ("%s"[pdat] : ' % completion_date.strftime('%Y/%m/%d')
    url += '"3000"[pdat]) '
    if query_type == 'broad':
        url += "AND ((clinical[Title/Abstract] AND trial[Title/Abstract]) "
        url += "OR clinical trials as topic[MeSH Terms] "
        url += "OR clinical trial[Publication Type] "
        url += "OR random*[Title/Abstract] "
        url += "OR random allocation[MeSH Terms] "
        url += "OR therapeutic use[MeSH Subheading])"
    elif query_type == 'narrow':
        url += "AND (randomized controlled trial[Publication Type] OR "
        url += "(randomized[Title/Abstract] "
        url += "AND controlled[Title/Abstract] AND trial[Title/Abstract]))"
    return url

def get_response(url):
    return requests.get(url)

def extract_pubmed_ids_from_json(data):
    ids = []
    esearchresult = data['esearchresult']
    if 'idlist' in esearchresult:
        ids = esearchresult['idlist']
    return ids

def get_pubmed_title(pmid):
    '''
    Retrieve the title of a PubMed article, from its PMID.
    '''
    url = 'http://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?'
    url += 'db=pubmed&rettype=abstract&id=%s' % pmid
    resp = get_response(url)
    title = extract_title_from_pubmed_data(resp.content)
    return title

def is_study_protocol(title):
    return (title and b'study protocol' in title.lower())

def extract_title_from_pubmed_data(text):
    try:
        tree = ElementTree.fromstring(text)
        title = tree.find('.//Article/ArticleTitle')
        if title is not None and title.text is not None:
            title = title.text.encode('utf8')
        if type(title) != bytes:
          title = ''
    except ElementTree.ParseError:
        print('ParseError', text)
        title = ''
    return title

# %%
nctid_input_file = '/content/gdrive/MyDrive/Demographic Analysis Project/nctid_list.tsv'
nctid_df = pd.read_csv(nctid_input_file, sep='\t')
display(nctid_df)
# Out:
#              nctid
# 0      NCT03633929
# 1      NCT01822678
# 2      NCT00787761
# 3      NCT02272413
# 4      NCT03720470
# ...            ...
# 30146  NCT01377194
# 30147  NCT01629589
# 30148  NCT01967940
# 30149  NCT02517905
# 30150  NCT02588833
#
# [30151 rows x 1 columns]

# %%
# testing 
d = datetime.datetime(2000, 1, 1)
print(get_pubmed_linked_articles('NCT01020916', d, 'narrow'))
print(get_pubmed_linked_articles('NCT03086369', d, 'narrow'))
print(get_pubmed_linked_articles('NCT00007644', d, 'narrow'))
# Out:
# ['28099439', '27887653', '27523954', '27438111', '26525271', '26433116', '25975474', '25844993', '25789868', '25756419', '25365723', '25270900', '25267568', '24237006', '24044764', '22520518']
# ['28838379']
# ['32089359', '28700844', '23988464', '22808955']

# %%
from tqdm.notebook import tqdm

# %%
# nctid_list_to_map = nctid_df.nctid.to_list()
# d = datetime.datetime(2000, 1, 1)
# results_dict ={}
# for i, nctid in enumerate(nctid_list_to_map):
#   print(f'processing {i}')
#   pubmed_id_list = get_pubmed_linked_articles(nctid, d, 'narrow')
#   print(f'get: {nctid}\t{pubmed_id_list}')
#   results_dict[nctid] = pubmed_id_list
#   break

# %%
import pickle
import os

filename = 'nctid_to_pmid_dict.pickle'
def save_pickle(a):
  with open(filename, 'wb') as handle:
      pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)


def save_pickle_and_cp_to_cloud(a, i):
  file_name = f'nctid_to_pmid_dict_{i}.pickle'
  with open(file_name, 'wb') as handle:
      pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)
  os.system(f'cp {file_name}  /content/gdrive/MyDrive/Demographic\ Analysis\ Project/')

# %%
# nctid_list_to_map = nctid_df.nctid.to_list()
# d = datetime.datetime(2000, 1, 1)
# results_dict ={}
# for i, nctid in enumerate(tqdm(nctid_list_to_map)):
#   pubmed_id_list = get_pubmed_linked_articles(nctid, d, 'narrow')
#   print(f'get: {nctid}\t{pubmed_id_list}')
#   results_dict[nctid] = pubmed_id_list
#   time.sleep(0.5)
#   if i%100==0:
#     save_pickle(results_dict)

# %%
nctid_list_to_map = nctid_df.nctid.to_list()
d = datetime.datetime(2000, 1, 1)

with open(filename, 'rb') as handle:
    b = pickle.load(handle)

print(len(b.keys()))
results_dict = b

for i, nctid in enumerate(tqdm(nctid_list_to_map)):
  if nctid in results_dict: continue
  pubmed_id_list = get_pubmed_linked_articles(nctid, d, 'narrow')
  print(f'get: {nctid}\t{pubmed_id_list}')
  results_dict[nctid] = pubmed_id_list
  time.sleep(0.5)
  if i%100==0:
    save_pickle(results_dict)
  if i%1000==0:
    save_pickle_and_cp_to_cloud(results_dict, i)
# Out:
# 25983
#   0%|          | 0/30151 [00:00<?, ?it/s]
# get: NCT00546377	[]
# get: NCT00920829	[]
# get: NCT02661178	[]
# get: NCT03078946	[]
# get: NCT02057406	['30098961']
# get: NCT01399099	['24804638']
# get: NCT01185171	[]
# get: NCT01105975	['27206939', '26564598', '22089718']
# get: NCT01827163	[]
# get: NCT02641561	['27816497']
# get: NCT03448224	['33353412']
# get: NCT02214121	['30972696']
# get: NCT01329562	[]
# get: NCT04109703	[]
# get: NCT03007953	[]
# get: NCT00237666	[]
# get: NCT02413034	[]
# get: NCT02466646	[]
# get: NCT02188459	['33493703']
# get: NCT01296152	[]
# get: NCT03288714	[]
# get: NCT00259090	['23497452']
# get: NCT00313729	[]
# get: NCT01006369	[]
# get: NCT01828593	[]
# get: NCT00849472	[]
# get: NCT02552121	[]
# get: NCT02611362	[]
# get: NCT02250651	[]
# get: NCT02909153	[]
# get: NCT03362944	[]
# get: NCT00606931	[]
# get: NCT02888093	[]
# get: NCT00030147	['33470755']
# get: NCT01375140	[]
# get: NCT01120236	['25847934']
# get: NCT00422058	['23942319', '19853906']
# get: NCT01223196	['23811853']
# get: NCT03557034	[]
# get: NCT04083404	[]
# get: NCT00945945	[]
# get: NCT03041038	[]
# get: NCT00551200	['22961727']
# get: NCT01843023	[]
# get: NCT02016755	[]
# get: NCT02281526	[]
# get: NCT02081586	[]
# get: NCT00937157	[]
# get: NCT01182844	['26509793', '22872030']
# get: NCT00978731	[]
# get: NCT02121795	['27036991']
# get: NCT00237718	['24371300']
# get: NCT00515216	[]
# get: NCT03023423	[]
# get: NCT01085214	[]
# get: NCT00528112	['26378938', '25661510', '24240244']
# get: NCT01511978	[]
# get: NCT00054665	[]
# get: NCT00005937	['23901089']
# get: NCT00368108	[]
# get: NCT02781818	['31490300']
# get: NCT01831804	['30720931']
# get: NCT00036569	[]
# get: NCT00782756	[]
# get: NCT02646423	[]
# get: NCT03301740	['32975783']
# get: NCT03188185	[]
# get: NCT02730403	[]
# get: NCT02942277	[]
# get: NCT01412866	['26932324']
# get: NCT01015560	[]
# get: NCT01777490	[]
# get: NCT03106844	[]
# get: NCT01190228	['29325161']
# get: NCT02958995	[]
# get: NCT00094497	['22551107']
# get: NCT00496197	[]
# get: NCT01693029	['29084409']
# get: NCT04356937	['33085857']
# get: NCT02178696	['26421634']
# get: NCT01035606	[]
# get: NCT00396331	[]
# get: NCT03291067	[]
# get: NCT00160667	[]
# get: NCT02733627	[]
# get: NCT00762762	[]
# get: NCT01351025	[]
# get: NCT00414440	['20581392']
# get: NCT00777049	[]
# get: NCT00633945	[]
# get: NCT00889200	[]
# get: NCT01741012	[]
# get: NCT03124069	[]
# get: NCT02473952	[]
# get: NCT01180127	[]
# get: NCT01342523	[]
# get: NCT00779402	['23896100']
# get: NCT03688711	[]
# get: NCT01045421	[]
# get: NCT00142415	[]
# get: NCT02261714	[]
# get: NCT02274688	['29533154']
# get: NCT02279862	[]
# get: NCT02563106	['30885591']
# get: NCT00075816	['27532508', '23075175']
# get: NCT00801827	[]
# get: NCT02139280	[]
# get: NCT01543152	[]
# get: NCT00648908	[]
# get: NCT00411086	[]
# get: NCT01641809	['26201299']
# get: NCT01038323	['23446065']
# get: NCT03141931	[]
# get: NCT02229552	[]
# get: NCT00781599	[]
# get: NCT00838903	['28683300']
# get: NCT00148759	[]
# get: NCT00650078	['22562974']
# get: NCT00982878	[]
# get: NCT00986232	['25219563']
# get: NCT02013674	['28923793']
# get: NCT02458690	[]
# get: NCT00288574	['16772623']
# get: NCT00695955	[]
# get: NCT01361620	[]
# get: NCT00720213	[]
# get: NCT01902004	['34589902', '32663977', '32382137', '31969201', '31519517']
# get: NCT01552603	[]
# get: NCT00948428	[]
# get: NCT00095628	[]
# get: NCT02664415	['31000477']
# get: NCT03360747	[]
# get: NCT02387749	[]
# get: NCT03460587	[]
# get: NCT00104299	['32841219', '27696762', '26621483', '25776953', '25047592', '23902481', '23754238', '20647199']
# get: NCT00282867	[]
# get: NCT01454414	[]
# get: NCT03950856	[]
# get: NCT02722044	[]
# get: NCT03338816	['32521132', '31792921']
# get: NCT02080403	[]
# get: NCT01400880	[]
# get: NCT02568449	[]
# get: NCT01942668	['33110039', '32932401', '32740481', '31913228', '31364889', '30694918', '30601452', '30586005', '30516713', '30489424', '29889748', '25835751']
# get: NCT02336451	[]
# get: NCT00238264	[]
# get: NCT01536184	[]
# get: NCT01606189	[]
# get: NCT03781726	[]
# get: NCT00756574	['19797474']
# get: NCT00162370	[]
# get: NCT00422695	[]
# get: NCT03295318	['34077644']
# get: NCT02212678	[]
# get: NCT00392951	[]
# get: NCT00533702	['24930625']
# get: NCT00752609	[]
# get: NCT03832738	[]
# get: NCT00829452	[]
# get: NCT03093701	[]
# get: NCT01553201	[]
# get: NCT00004143	[]
# get: NCT01669421	[]
# get: NCT01054742	[]
# get: NCT01436149	[]
# get: NCT01251536	[]
# get: NCT02185014	[]
# get: NCT01283542	[]
# get: NCT01665157	[]
# get: NCT01566526	[]
# get: NCT03039569	[]
# get: NCT03280537	['34382434']
# get: NCT02553512	[]
# get: NCT00469079	['21068204']
# get: NCT00596466	[]
# get: NCT00775645	[]
# get: NCT03178773	[]
# get: NCT00978120	[]
# get: NCT02660034	[]
# get: NCT01597128	[]
# get: NCT00071890	[]
# get: NCT01597635	['28877748']
# get: NCT01707238	[]
# get: NCT00066066	[]
# get: NCT01393990	[]
# get: NCT01956435	[]
# get: NCT00056316	[]
# get: NCT00481507	['19652108']
# get: NCT01192516	['21810253']
# get: NCT03721549	[]
# get: NCT01234870	[]
# get: NCT00933335	[]
# get: NCT01221948	[]
# get: NCT00606177	[]
# get: NCT02312713	['31254451', '29307722', '28371481']
# get: NCT02527694	[]
# get: NCT01859923	[]
# get: NCT00742209	['23165696']
# get: NCT02152605	[]
# get: NCT00962091	[]
# get: NCT00751530	[]
# get: NCT01176773	[]
# get: NCT03415152	[]
# get: NCT01706770	[]
# get: NCT01989169	[]
# get: NCT00495469	['25238025']
# get: NCT00674154	[]
# get: NCT00737672	['30717951']
# get: NCT00230048	[]
# get: NCT01368432	[]
# get: NCT01928524	[]
# get: NCT01569464	['26569149']
# get: NCT02849626	['33839450']
# get: NCT03192176	['32102086']
# get: NCT03057613	[]
# get: NCT00774787	[]
# get: NCT02094534	[]
# get: NCT01588418	['27639082', '26116695']
# get: NCT01673854	[]
# get: NCT03988803	[]
# get: NCT00806156	['28935273']
# get: NCT00676520	['25940520', '23172848']
# get: NCT01057121	[]
# get: NCT02584686	[]
# get: NCT01813422	['30336824', '27846344', '27264224']
# get: NCT00733421	[]
# get: NCT03331042	[]
# get: NCT00983216	[]
# get: NCT01255722	[]
# get: NCT00358332	['20140214']
# get: NCT01116739	['31936256', '27439724', '24469238']
# get: NCT00999713	[]
# get: NCT02573233	[]
# get: NCT00370994	['19935992', '19935991']
# get: NCT00831779	[]
# get: NCT00209339	['23633132', '21422390']
# get: NCT02269787	[]
# get: NCT03579290	[]
# get: NCT01560949	[]
# get: NCT00133809	[]
# get: NCT04072159	[]
# get: NCT01402375	[]
# get: NCT03669861	[]
# get: NCT00183729	[]
# get: NCT01345019	['32524500', '29429912']
# get: NCT03695094	[]
# get: NCT00952692	[]
# get: NCT01715064	['25505413']
# get: NCT02615717	[]
# get: NCT02295280	[]
# get: NCT00257725	[]
# get: NCT00772148	['30667591']
# get: NCT00465816	['22107850']
# get: NCT03519516	[]
# get: NCT02699125	[]
# get: NCT02436330	[]
# get: NCT00416312	[]
# get: NCT00653263	[]
# get: NCT03045809	[]
# get: NCT03126344	['31470814']
# get: NCT03552523	[]
# get: NCT02978157	[]
# get: NCT01324349	[]
# get: NCT01401517	[]
# get: NCT03717155	[]
# get: NCT00860262	[]
# get: NCT01361633	[]
# get: NCT03637959	[]
# get: NCT01201356	[]
# get: NCT00993473	['25041275']
# get: NCT01301066	['28416195', '28252528', '28121706']
# get: NCT02669615	[]
# get: NCT01165216	[]
# get: NCT02734810	[]
# get: NCT00006244	[]
# get: NCT02091362	[]
# get: NCT00755183	[]
# get: NCT01482169	[]
# get: NCT01883895	[]
# get: NCT01006889	[]
# get: NCT01061151	['34415933', '32564058', '31634154', '30890061', '27806243']
# get: NCT02057081	[]
# get: NCT01211184	['22747890']
# get: NCT00864123	['34134828', '30877851', '30149332', '27367832', '20817153']
# get: NCT00695435	[]
# get: NCT02465463	[]
# get: NCT03636893	['33257672']
# get: NCT00937378	[]
# get: NCT00542919	[]
# get: NCT02917031	[]
# get: NCT01028352	[]
# get: NCT02723591	[]
# get: NCT02685007	[]
# get: NCT02465866	[]
# get: NCT00530855	['27528101']
# get: NCT01183559	[]
# get: NCT00446134	[]
# get: NCT02038881	['32057574']
# get: NCT02561806	[]
# get: NCT01981967	[]
# get: NCT04050722	['34511098']
# get: NCT00214487	[]
# get: NCT02476968	[]
# get: NCT00697541	[]
# get: NCT02442622	[]
# get: NCT02507297	[]
# get: NCT00633022	['22974804']
# get: NCT01297257	[]
# get: NCT00606034	[]
# get: NCT02832375	['31164116']
# get: NCT02453750	[]
# get: NCT01316055	[]
# get: NCT00607620	['24450612']
# get: NCT03435783	[]
# get: NCT02683746	[]
# get: NCT03372096	[]
# get: NCT01558661	[]
# get: NCT03308968	['34922436', '34819017', '34246226', '33990144', '33863272', '31427046']
# get: NCT02791516	['33677928']
# get: NCT00385268	[]
# get: NCT00227370	['20547904']
# get: NCT02159352	[]
# get: NCT00115934	['30755054', '29437119', '28687711', '25440099', '24958780', '24952712', '24705119', '24210923', '24097422', '24075564', '23864006', '22901498', '22795436', '22704284', '22698562', '22523314', '22456475', '22341427', '21397260', '20505177']
# get: NCT00578617	[]
# get: NCT03280264	[]
# get: NCT00439413	[]
# get: NCT01185639	[]
# get: NCT02065713	['32193187']
# get: NCT01355458	[]
# get: NCT03468816	[]
# get: NCT02417532	[]
# get: NCT02275338	[]
# get: NCT02142387	[]
# get: NCT00835341	[]
# get: NCT00391053	['19508159']
# get: NCT00379808	[]
# get: NCT00643578	[]
# get: NCT00806624	[]
# get: NCT03627065	[]
# get: NCT00672555	[]
# get: NCT01937260	[]
# get: NCT03501277	[]
# get: NCT03678311	[]
# get: NCT02666430	[]
# get: NCT02284568	['32651286']
# get: NCT00829504	[]
# get: NCT01549275	[]
# get: NCT01375777	['23141812']
# get: NCT00637247	[]
# get: NCT00672958	[]
# get: NCT00729651	[]
# get: NCT01332149	[]
# get: NCT00890682	['22900785', '21842428']
# get: NCT02580799	[]
# get: NCT02347124	[]
# get: NCT00621764	[]
# get: NCT00628407	[]
# get: NCT01321710	['22123869']
# get: NCT02879305	['34739194']
# get: NCT02849509	[]
# get: NCT02383667	[]
# get: NCT01977677	[]
# get: NCT00906165	[]
# get: NCT01282814	[]
# get: NCT00390546	['22962431']
# get: NCT01207583	[]
# get: NCT01736930	[]
# get: NCT02095340	[]
# get: NCT01026948	[]
# get: NCT00577577	[]
# get: NCT02424851	[]
# get: NCT01414010	[]
# get: NCT01472835	['24524866']
# get: NCT03585712	[]
# get: NCT02630706	['30830724']
# get: NCT01534533	[]
# get: NCT02721147	[]
# get: NCT02531802	['31757774', '30473185']
# get: NCT00455923	[]
# get: NCT01124734	[]
# get: NCT02737631	[]
# get: NCT01407523	[]
# get: NCT00947856	[]
# get: NCT02474901	[]
# get: NCT02935738	[]
# get: NCT01458587	[]
# get: NCT00107952	['24708675']
# get: NCT01957163	['26117292']
# get: NCT01297465	[]
# get: NCT01863017	[]
# get: NCT03589807	[]
# get: NCT00453479	[]
# get: NCT03441984	[]
# get: NCT02403180	[]
# get: NCT00348348	['32841261']
# get: NCT01429454	[]
# get: NCT02873689	[]
# get: NCT00171834	[]
# get: NCT00658723	['26636489', '23969113']
# get: NCT02118766	['32981097', '32318744', '31132182', '27417017']
# get: NCT01142908	['32685766', '29754649', '23537965']
# get: NCT00655551	[]
# get: NCT01909778	[]
# get: NCT02593903	[]
# get: NCT02651103	[]
# get: NCT02374255	[]
# get: NCT00149669	['25134047']
# get: NCT01789814	[]
# get: NCT03047980	[]
# get: NCT02019420	['33720350']
# get: NCT00569855	[]
# get: NCT00381706	['27382098']
# get: NCT01078389	['28975718']
# get: NCT02251912	[]
# get: NCT01484275	['30890552']
# get: NCT00418314	['20569704']
# get: NCT00669539	[]
# get: NCT01245764	[]
# get: NCT02948582	[]
# get: NCT00986570	[]
# get: NCT00848042	[]
# get: NCT03207750	['33077301']
# get: NCT04292730	['32821939']
# get: NCT01146795	[]
# get: NCT03095118	[]
# get: NCT02558894	[]
# get: NCT00410124	['23219086', '22824201', '22297244', '22209391', '20194812', '18653228']
# get: NCT00771810	[]
# get: NCT01370590	['25431239']
# get: NCT03550066	[]
# get: NCT00889265	[]
# get: NCT00835211	[]
# get: NCT00868309	[]
# get: NCT03334448	[]
# get: NCT02452346	[]
# get: NCT02436876	[]
# get: NCT01269749	[]
# get: NCT00811395	['28607708']
# get: NCT02237157	[]
# get: NCT02311153	[]
# get: NCT02397057	[]
# get: NCT01811940	[]
# get: NCT03287310	[]
# get: NCT00091572	[]
# get: NCT00109590	['22144539']
# get: NCT02039856	['29979640', '29475630', '27435723']
# get: NCT00631696	['24450301']
# get: NCT03885934	[]
# get: NCT02008318	[]
# get: NCT04007159	[]
# get: NCT01340027	['27514371', '24612659']
# get: NCT01375751	['23129602']
# get: NCT00965081	[]
# get: NCT02431559	[]
# get: NCT00066365	[]
# get: NCT00201201	[]
# get: NCT01855425	[]
# get: NCT00901225	[]
# get: NCT00000125	['23349433', '22395889', '22159015', '20212196', '17420364']
# get: NCT01178671	['26115513']
# get: NCT02458092	[]
# get: NCT00084084	[]
# get: NCT03075644	['32603494']
# get: NCT02968420	[]
# get: NCT04171102	[]
# get: NCT01077804	[]
# get: NCT00628108	['20819318']
# get: NCT00844597	[]
# get: NCT00499031	[]
# get: NCT01049035	[]
# get: NCT02100696	['32445184']
# get: NCT00608543	[]
# get: NCT00238433	[]
# get: NCT00295750	['34350976', '33035140']
# get: NCT03239106	[]
# get: NCT02597907	[]
# get: NCT01456897	[]
# get: NCT03148691	[]
# get: NCT01552343	[]
# get: NCT00547638	[]
# get: NCT01929395	[]
# get: NCT00364013	['31515083', '30019318', '30013091', '29080924', '25956209', '24024839', '22070868']
# get: NCT02784444	['31697972']
# get: NCT01265563	[]
# get: NCT01377584	[]
# get: NCT01885936	['31839530']
# get: NCT00912093	['26556097', '25198193', '23167682', '22123383']
# get: NCT00614926	[]
# get: NCT00194987	['27611703', '17666597']
# get: NCT00277355	[]
# get: NCT01211106	['34881912', '27444425']
# get: NCT02554786	['32653075']
# get: NCT01717859	[]
# get: NCT02949011	['32526195']
# get: NCT00225147	['23535096', '20920772']
# get: NCT03014674	['31317668']
# get: NCT03247543	['34523063', '33750646', '33600233']
# get: NCT00953212	[]
# get: NCT00833898	[]
# get: NCT04274556	[]
# get: NCT02761993	[]
# get: NCT01595282	[]
# get: NCT00286949	[]
# get: NCT02723188	['27727241']
# get: NCT02935595	[]
# get: NCT01577329	['25767382']
# get: NCT01103479	['33416742', '25986137']
# get: NCT00130637	[]
# get: NCT03644017	[]
# get: NCT01066156	[]
# get: NCT01113931	['22431798']
# get: NCT02566317	['33109190', '28859679', '27940181']
# get: NCT00159874	['24637559']
# get: NCT01036165	[]
# get: NCT01246349	[]
# get: NCT00205699	['29898210']
# get: NCT03512041	[]
# get: NCT01579162	[]
# get: NCT01180296	[]
# get: NCT00721799	[]
# get: NCT02820324	['31162798']
# get: NCT01098032	['21844075', '21518686']
# get: NCT01685320	[]
# get: NCT01710358	['32414425', '31040122', '30902094', '30784354', '30219772', '29278006', '28798049', '28199814']
# get: NCT01844388	[]
# get: NCT01733472	[]
# get: NCT01734551	['25624389']
# get: NCT01740791	['27353271', '26183611']
# get: NCT01839916	[]
# get: NCT01336296	[]
# get: NCT03072602	[]
# get: NCT01079390	['26511911']
# get: NCT02600819	[]
# get: NCT01431170	[]
# get: NCT01627249	['32722799', '31502893', '29392288', '27711918', '26605836', '25692915']
# get: NCT03628924	[]
# get: NCT01063049	[]
# get: NCT01440959	[]
# get: NCT01641120	[]
# get: NCT00452413	[]
# get: NCT01011153	[]
# get: NCT01011413	['25877963', '25501988', '24522178']
# get: NCT02473913	[]
# get: NCT01350336	[]
# get: NCT03766646	[]
# get: NCT00520299	[]
# get: NCT01312038	[]
# get: NCT01236196	[]
# get: NCT02599688	[]
# get: NCT01536379	['29910042']
# get: NCT01223404	[]
# get: NCT00695292	[]
# get: NCT03021304	[]
# get: NCT00845507	[]
# get: NCT02291510	['26285584']
# get: NCT03289481	[]
# get: NCT00356590	['20957659']
# get: NCT00256867	[]
# get: NCT00546117	[]
# get: NCT00433745	[]
# get: NCT00598819	[]
# get: NCT00831311	[]
# get: NCT01307631	[]
# get: NCT01246999	['25165161']
# get: NCT01842815	[]
# get: NCT03135015	[]
# get: NCT01500434	['29217001', '24905795']
# get: NCT02544451	[]
# get: NCT01926886	[]
# get: NCT00796302	['31730370', '29173736', '27348211', '27238065', '25885012', '25885010', '25151418', '24342385']
# get: NCT00601146	[]
# get: NCT01941537	[]
# get: NCT03980470	[]
# get: NCT02915159	[]
# get: NCT01400139	['28794653', '26749219']
# get: NCT00547521	['23097311']
# get: NCT03230916	[]
# get: NCT00820664	[]
# get: NCT02927223	[]
# get: NCT02647944	['31665455', '28958851']
# get: NCT00536510	[]
# get: NCT00362440	[]
# get: NCT01737762	['29037354']
# get: NCT01241435	[]
# get: NCT02752880	[]
# get: NCT02760277	[]
# get: NCT00717756	[]
# get: NCT00269633	[]
# get: NCT01387672	[]
# get: NCT00618618	[]
# get: NCT01970176	[]
# get: NCT02052557	['27505115']
# get: NCT00814255	['26198842', '21310077', '19932542']
# get: NCT02884427	[]
# get: NCT03134092	['32969832']
# get: NCT03496701	[]
# get: NCT03784001	[]
# get: NCT00511147	[]
# get: NCT02962648	[]
# get: NCT01690988	['30336852', '28576285', '25231491']
# get: NCT02712359	[]
# get: NCT01973595	['26773784']
# get: NCT01246583	['23387374']
# get: NCT02376790	['32864685', '30747501']
# get: NCT01248962	[]
# get: NCT01153516	[]
# get: NCT00773370	[]
# get: NCT00982865	[]
# get: NCT00244933	[]
# get: NCT01819272	['26285584']
# get: NCT01379651	[]
# get: NCT01380106	[]
# get: NCT02137382	[]
# get: NCT04107493	[]
# get: NCT03049280	[]
# get: NCT00290498	[]
# get: NCT01115231	[]
# get: NCT01420536	['22486470']
# get: NCT02841033	[]
# get: NCT03065647	['33541748']
# get: NCT01131065	[]
# get: NCT01599234	[]
# get: NCT01124916	['27403758', '27180224', '24463657']
# get: NCT00663702	['27229685']
# get: NCT00552084	['25465932']
# get: NCT04090164	[]
# get: NCT02080273	['26087570']
# get: NCT01707290	['26070913']
# get: NCT03197883	[]
# get: NCT01098851	[]
# get: NCT00462761	[]
# get: NCT01848184	[]
# get: NCT01046084	[]
# get: NCT02369159	[]
# get: NCT00140231	['23193213', '21917874']
# get: NCT02916693	[]
# get: NCT03417102	[]
# get: NCT03472469	['33486130']
# get: NCT00923559	[]
# get: NCT02632526	[]
# get: NCT02731469	[]
# get: NCT01649375	['33722947', '28544533', '28235249', '27582421', '26699169']
# get: NCT00763412	[]
# get: NCT00413582	[]
# get: NCT00538512	['31117986', '25858957', '21998477', '19776407']
# get: NCT01890954	[]
# get: NCT03772327	['33306564']
# get: NCT00573066	[]
# get: NCT01249261	[]
# get: NCT00720941	['32171288', '31601514', '29788981', '27000445', '26685869', '26457466', '23964934']
# get: NCT02357290	[]
# get: NCT00122369	[]
# get: NCT03991494	[]
# get: NCT01683994	[]
# get: NCT00673257	[]
# get: NCT02569996	[]
# get: NCT00412360	['25354103']
# get: NCT00415519	[]
# get: NCT02461693	[]
# get: NCT01290315	[]
# get: NCT02424565	[]
# get: NCT02847858	['30869649', '29326184']
# get: NCT03163758	[]
# get: NCT01020487	[]
# get: NCT02003352	[]
# get: NCT03122587	[]
# get: NCT02798354	['30720339']
# get: NCT01214434	[]
# get: NCT01867580	[]
# get: NCT02993107	[]
# get: NCT00030901	[]
# get: NCT00623545	[]
# get: NCT00079937	['33223095', '19910033']
# get: NCT04267380	[]
# get: NCT03124602	[]
# get: NCT01740297	['31353364', '28981385']
# get: NCT02518464	[]
# get: NCT00761774	['32731118']
# get: NCT02554929	[]
# get: NCT01138657	['28426849', '28237411', '27602665']
# get: NCT00758043	['21916639']
# get: NCT01495481	[]
# get: NCT01062308	['23345636']
# get: NCT00853021	[]
# get: NCT02738138	[]
# get: NCT02214290	[]
# get: NCT03198715	[]
# get: NCT02299427	[]
# get: NCT01283009	[]
# get: NCT03097861	['33834354']
# get: NCT01363258	['22100010']
# get: NCT00484354	[]
# get: NCT01877642	[]
# get: NCT00948506	[]
# get: NCT02360605	[]
# get: NCT03222037	[]
# get: NCT02154425	[]
# get: NCT01067469	[]
# get: NCT01040845	[]
# get: NCT01797120	['29664714']
# get: NCT02497976	[]
# get: NCT00583713	[]
# get: NCT04537910	[]
# get: NCT00450866	[]
# get: NCT00381849	[]
# get: NCT00175877	['29246162', '22596211', '22589265', '19015207']
# get: NCT00127231	[]
# get: NCT01351480	[]
# get: NCT01314001	['31502736', '30614717', '29986268', '26069034', '25732567', '25588294']
# get: NCT03069417	[]
# get: NCT01993940	['31145214', '28576452']
# get: NCT00736996	[]
# get: NCT01115933	[]
# get: NCT00017563	[]
# get: NCT01829516	[]
# get: NCT01515176	[]
# get: NCT01275586	[]
# get: NCT01786174	[]
# get: NCT02566135	[]
# get: NCT00567268	[]
# get: NCT02682784	[]
# get: NCT01494987	[]
# get: NCT01262599	['25919263']
# get: NCT01881737	[]
# get: NCT00055692	[]
# get: NCT01740713	[]
# get: NCT01732406	[]
# get: NCT00922272	[]
# get: NCT00499473	[]
# get: NCT01527162	[]
# get: NCT02224508	[]
# get: NCT00389168	[]
# get: NCT01225887	[]
# get: NCT01083667	[]
# get: NCT02597790	[]
# get: NCT00396409	[]
# get: NCT01509040	[]
# get: NCT02974088	[]
# get: NCT04992442	[]
# get: NCT03885661	[]
# get: NCT01720225	['28774880']
# get: NCT01771991	[]
# get: NCT00183170	[]
# get: NCT02614547	['32666402', '28619476']
# get: NCT01144182	[]
# get: NCT03168334	['34076400', '33196747', '32845584', '32726105']
# get: NCT03111108	['31765046']
# get: NCT03993392	[]
# get: NCT00340834	['26111826', '25245812', '23531349', '21571593', '20937112', '20089954']
# get: NCT04355767	['34407339']
# get: NCT02597101	[]
# get: NCT02837237	[]
# get: NCT02318797	[]
# get: NCT02372383	[]
# get: NCT02932943	[]
# get: NCT00470600	[]
# get: NCT03492281	['33469832', '33332699']
# get: NCT01636076	[]
# get: NCT01462110	[]
# get: NCT01592071	[]
# get: NCT00502697	[]
# get: NCT00474487	[]
# get: NCT00685178	['24814607']
# get: NCT00926328	[]
# get: NCT00506753	[]
# get: NCT01493947	[]
# get: NCT01957085	[]
# get: NCT00928434	['34350976', '33035140']
# get: NCT01963845	[]
# get: NCT02370537	[]
# get: NCT00821678	['32521100', '25409287']
# get: NCT02033083	[]
# get: NCT02903030	[]
# get: NCT01011465	['20025778']
# get: NCT01748825	[]
# get: NCT01395914	[]
# get: NCT00325195	['31203212', '24588936', '24447425', '24286509', '21846852']
# get: NCT02856282	[]
# get: NCT01596088	[]
# get: NCT00379821	['22912697']
# get: NCT03294538	[]
# get: NCT01439581	[]
# get: NCT01053429	[]
# get: NCT01861704	[]
# get: NCT03687450	[]
# get: NCT01982812	['31672143']
# get: NCT03111940	[]
# get: NCT02370238	['34476645']
# get: NCT01828073	[]
# get: NCT02477839	[]
# get: NCT01197573	[]
# get: NCT00513604	['23650429']
# get: NCT04086472	[]
# get: NCT01066624	[]
# get: NCT02252211	[]
# get: NCT01715948	[]
# get: NCT02531022	['29899015']
# get: NCT02911818	['30926955', '30902750', '30421856']
# get: NCT02710214	[]
# get: NCT01845155	[]
# get: NCT01265992	[]
# get: NCT02549859	['29654112']
# get: NCT04032977	[]
# get: NCT03373383	[]
# get: NCT01263782	[]
# get: NCT01338506	[]
# get: NCT01181804	[]
# get: NCT00434512	['24391139', '21208909']
# get: NCT00301366	[]
# get: NCT01317095	[]
# get: NCT03553758	[]
# get: NCT00475020	[]
# get: NCT03208088	[]
# get: NCT03431441	[]
# get: NCT02457247	[]
# get: NCT02395471	[]
# get: NCT01484834	[]
# get: NCT03545893	[]
# get: NCT02501629	['32066536']
# get: NCT00327171	[]
# get: NCT00700375	[]
# get: NCT01473368	[]
# get: NCT02699996	[]
# get: NCT03559933	[]
# get: NCT00668525	[]
# get: NCT02966509	['30054634']
# get: NCT01678196	[]
# get: NCT03129321	[]
# get: NCT01477892	[]
# get: NCT01174342	[]
# get: NCT02722564	[]
# get: NCT02915874	['34672928', '34619441']
# get: NCT02357043	[]
# get: NCT01426009	[]
# get: NCT03762200	[]
# get: NCT02625571	[]
# get: NCT00791908	[]
# get: NCT02772757	[]
# get: NCT00606320	[]
# get: NCT00917124	[]
# get: NCT01789476	[]
# get: NCT03602885	[]
# get: NCT01756976	[]
# get: NCT02394548	[]
# get: NCT00568399	[]
# get: NCT00558467	[]
# get: NCT01054456	[]
# get: NCT01451749	['28596794']
# get: NCT02006108	[]
# get: NCT02040259	[]
# get: NCT00438750	[]
# get: NCT00804609	[]
# get: NCT01199263	[]
# get: NCT02605642	[]
# get: NCT00989950	[]
# get: NCT03346759	[]
# get: NCT03935399	[]
# get: NCT03350724	[]
# get: NCT03196505	[]
# get: NCT01301079	[]
# get: NCT02982590	[]
# get: NCT02475070	[]
# get: NCT02198651	['32404343', '29490959']
# get: NCT01786707	[]
# get: NCT02969928	['31257591']
# get: NCT00834535	[]
# get: NCT00869622	[]
# get: NCT01767103	[]
# get: NCT00322491	[]
# get: NCT01120028	['29226570', '25078310']
# get: NCT00274742	[]
# get: NCT00762216	[]
# get: NCT02348684	[]
# get: NCT02421952	[]
# get: NCT01585779	[]
# get: NCT01875159	['24445955']
# get: NCT01076361	[]
# get: NCT01072175	['28991513', '26811525', '26340744', '23020132']
# get: NCT00926497	[]
# get: NCT00263575	[]
# get: NCT01818284	[]
# get: NCT00407654	[]
# get: NCT01041274	['33814546']
# get: NCT03077724	[]
# get: NCT03407313	[]
# get: NCT00763867	['28194841', '25104521', '24833648', '24162898', '23478662', '22991405']
# get: NCT01946165	[]
# get: NCT01634191	[]
# get: NCT01991483	['30677788']
# get: NCT02386189	[]
# get: NCT03266588	['34455556']
# get: NCT01055314	[]
# get: NCT01524627	[]
# get: NCT01727297	[]
# get: NCT02690714	[]
# get: NCT00567541	[]
# get: NCT00410202	[]
# get: NCT02418312	[]
# get: NCT03510273	[]
# get: NCT03319277	[]
# get: NCT01087905	['22992296']
# get: NCT01281501	[]
# get: NCT02520531	[]
# get: NCT00651313	[]
# get: NCT02006121	['33486139', '30055903']
# get: NCT02480153	['34563243', '33883254', '30111357']
# get: NCT00891839	[]
# get: NCT03304054	[]
# get: NCT01017250	[]
# get: NCT02128763	['33290317', '31425752', '31116166', '29883769', '29652551']
# get: NCT01896232	['28097356']
# get: NCT01463202	[]
# get: NCT01034111	[]
# get: NCT01853618	[]
# get: NCT00033540	[]
# get: NCT00121485	['22282104', '19920051']
# get: NCT02639910	[]
# get: NCT01846442	[]
# get: NCT00891982	[]
# get: NCT02023099	['27084721']
# get: NCT00923936	[]
# get: NCT01117311	[]
# get: NCT03181529	['33146667']
# get: NCT00742235	[]
# get: NCT00003590	[]
# get: NCT00096785	['19065670']
# get: NCT01697800	[]
# get: NCT01109069	['31196847']
# get: NCT03018223	[]
# get: NCT03951610	[]
# get: NCT02959996	['29889750']
# get: NCT01220609	[]
# get: NCT01815229	[]
# get: NCT00200057	[]
# get: NCT00993265	['26139231', '23452680']
# get: NCT01983969	[]
# get: NCT01732770	['31776637', '27270237']
# get: NCT01835158	['31399500', '29550566']
# get: NCT02374164	[]
# get: NCT00711997	[]
# get: NCT00096447	[]
# get: NCT00460408	[]
# get: NCT01262872	['30975570', '28389097']
# get: NCT02446899	['33977796', '33913260', '31851795']
# get: NCT01699178	[]
# get: NCT00201240	[]
# get: NCT00363168	[]
# get: NCT02377674	[]
# get: NCT03079531	[]
# get: NCT00720369	[]
# get: NCT02296112	[]
# get: NCT01258153	[]
# get: NCT02582242	['30872064']
# get: NCT01218971	[]
# get: NCT00996281	[]
# get: NCT00962650	[]
# get: NCT03691844	[]
# get: NCT00246337	['17914062']
# get: NCT02327013	['30843450']
# get: NCT02424799	[]
# get: NCT00995371	['22272730']
# get: NCT01079299	[]
# get: NCT01114438	[]
# get: NCT02328547	['31326345']
# get: NCT02585895	[]
# get: NCT01327612	[]
# get: NCT01814241	[]
# get: NCT00027378	['19321268']
# get: NCT01831089	[]
# get: NCT02280473	[]
# get: NCT01426854	[]
# get: NCT01050153	[]
# get: NCT00076219	['32470389', '22595826', '20507953', '18492867']
# get: NCT02200458	[]
# get: NCT02845752	[]
# get: NCT01407094	['34000130', '32921587', '32658822', '31895437', '31537090', '30718038', '29641834', '27038550']
# get: NCT01063075	[]
# get: NCT02542761	['33856155']
# get: NCT01761643	['30295803', '29228144']
# get: NCT00406107	[]
# get: NCT03003000	['31576162']
# get: NCT00041080	[]
# get: NCT01621776	[]
# get: NCT00564278	['25736422']
# get: NCT00835770	[]
# get: NCT01302080	[]
# get: NCT01395329	['27113048']
# get: NCT03115827	[]
# get: NCT00929500	[]
# get: NCT01016678	[]
# get: NCT01770743	[]
# get: NCT02068885	['34582545', '30429127', '30283914']
# get: NCT02610231	[]
# get: NCT02558374	[]
# get: NCT00593827	[]
# get: NCT02625844	[]
# get: NCT01883427	[]
# get: NCT02127931	[]
# get: NCT02786953	[]
# get: NCT02478489	[]
# get: NCT00227903	['28270105', '24447885', '22795046']
# get: NCT01473394	['29608461', '27980409', '25470094', '25396353']
# get: NCT02457325	['26202994']
# get: NCT04446247	[]
# get: NCT03100825	[]
# get: NCT00618449	[]
# get: NCT03482011	[]
# get: NCT00581919	[]
# get: NCT00319046	[]
# get: NCT02130297	[]
# get: NCT02130284	[]
# get: NCT01944462	[]
# get: NCT02339285	[]
# get: NCT04456634	['34694880']
# get: NCT00724503	['31840815', '28781171', '26903575', '25487708']
# get: NCT01265446	['30541606']
# get: NCT00728923	[]
# get: NCT03542474	[]
# get: NCT00074308	[]
# get: NCT02669121	[]
# get: NCT00058058	[]
# get: NCT00909649	[]
# get: NCT03702608	[]
# get: NCT01214668	[]
# get: NCT01774799	['29868778']
# get: NCT01723163	[]
# get: NCT00934141	['30032945']
# get: NCT01297985	[]
# get: NCT01720602	[]
# get: NCT00601172	['21822913']
# get: NCT00360685	['20102746']
# get: NCT01408992	[]
# get: NCT00423358	[]
# get: NCT00423722	['23169523']
# get: NCT01317667	[]
# get: NCT00249444	[]
# get: NCT00104858	[]
# get: NCT01923285	['31494275']
# get: NCT01120093	['22497752']
# get: NCT02040116	[]
# get: NCT03488108	['31574029']
# get: NCT00556140	[]
# get: NCT03736928	[]
# get: NCT00771849	[]
# get: NCT02757092	[]
# get: NCT01181258	['29218366']
# get: NCT01538628	[]
# get: NCT00459368	['23352524', '20569973', '19055201']
# get: NCT00654329	[]
# get: NCT01151280	[]
# get: NCT00203424	[]
# get: NCT02787655	[]
# get: NCT00621543	[]
# get: NCT01831466	['27716172']
# get: NCT00090259	['25828348', '25742759', '19922995']
# get: NCT01856907	[]
# get: NCT01509664	['28590084']
# get: NCT01968070	['28857461']
# get: NCT01504711	[]
# get: NCT02413333	[]
# get: NCT02065245	['28977399']
# get: NCT01237301	[]
# get: NCT02340104	[]
# get: NCT00399529	[]
# get: NCT00752102	['32775985']
# get: NCT02349789	[]
# get: NCT02612688	['32628258', '31779684', '30852167', '30134976']
# get: NCT02159768	[]
# get: NCT00503906	[]
# get: NCT01737281	['31957794', '29551324', '25518878']
# get: NCT02431806	[]
# get: NCT00004412	[]
# get: NCT02044419	[]
# get: NCT00813150	['28905189']
# get: NCT00960843	[]
# get: NCT01228591	[]
# get: NCT01781234	[]
# get: NCT00393913	[]
# get: NCT00746668	[]
# get: NCT00241839	[]
# get: NCT01310179	[]
# get: NCT01489826	[]
# get: NCT01197794	['29765200']
# get: NCT00181883	[]
# get: NCT00415532	['21067381']
# get: NCT01662778	[]
# get: NCT00765947	[]
# get: NCT02132754	[]
# get: NCT01967862	[]
# get: NCT03933774	['32869680']
# get: NCT00129259	['24115337', '23835333']
# get: NCT03358355	[]
# get: NCT03733899	[]
# get: NCT00889707	[]
# get: NCT00841815	[]
# get: NCT00303329	[]
# get: NCT01537068	['30423468']
# get: NCT01381874	['26504153']
# get: NCT00687739	['29631362']
# get: NCT02502864	[]
# get: NCT02154061	['34174187']
# get: NCT00507546	['24090266']
# get: NCT02504554	[]
# get: NCT03231800	['35048745']
# get: NCT00819052	[]
# get: NCT02733991	['32412858', '31047902']
# get: NCT00455702	[]
# get: NCT02007863	[]
# get: NCT00590226	[]
# get: NCT00632099	[]
# get: NCT01767376	['29960800']
# get: NCT03345394	[]
# get: NCT00577824	['22913891', '24843529', '24843486']
# get: NCT00265317	['23788751']
# get: NCT00423943	[]
# get: NCT02493660	[]
# get: NCT02135445	[]
# get: NCT00056498	['20664583']
# get: NCT00667576	[]
# get: NCT01427608	['32101271', '31429896', '31207561', '23351522']
# get: NCT02070991	[]
# get: NCT02337465	[]
# get: NCT01675661	['34197135', '31712969', '28847455', '28623823']
# get: NCT02508532	['34343033']
# get: NCT02452047	['32154325', '32094127', '31400759']
# get: NCT00298610	[]
# get: NCT00287222	[]
# get: NCT02835339	['33156201']
# get: NCT04006795	[]
# get: NCT00630396	[]
# get: NCT00617409	[]
# get: NCT00663260	['27306615', '24067431']
# get: NCT02092116	[]
# get: NCT01338792	[]
# get: NCT03209050	[]
# get: NCT02249182	[]
# get: NCT01525407	[]
# get: NCT01287377	[]
# get: NCT02730208	[]
# get: NCT00847509	[]
# get: NCT02053753	[]
# get: NCT02217332	[]
# get: NCT03367793	['33394936']
# get: NCT00354679	[]
# get: NCT02509156	['29910056']
# get: NCT00611624	[]
# get: NCT00666835	[]
# get: NCT01852175	['26848148']
# get: NCT03157089	[]
# get: NCT02292719	['28833938']
# get: NCT02388191	['27824753']
# get: NCT04401579	['33306283']
# get: NCT01891721	[]
# get: NCT00299416	[]
# get: NCT02462486	[]
# get: NCT00899600	[]
# get: NCT01055184	[]
# get: NCT02176083	[]
# get: NCT02332902	[]
# get: NCT02982018	[]
# get: NCT00705679	['28178109', '27146827', '26850270', '26155597', '25651245']
# get: NCT01189617	[]
# get: NCT01876446	[]
# get: NCT01175148	[]
# get: NCT02587221	['33577767']
# get: NCT00369486	[]
# get: NCT01588353	[]
# get: NCT02338960	['33538638', '31599840', '28189361']
# get: NCT02450799	[]
# get: NCT02677493	[]
# get: NCT00337935	[]
# get: NCT00258908	[]
# get: NCT00376506	[]
# get: NCT00419380	['30073253']
# get: NCT00387751	[]
# get: NCT02835846	[]
# get: NCT00846495	[]
# get: NCT04065074	[]
# get: NCT03242408	[]
# get: NCT01075048	[]
# get: NCT01709318	[]
# get: NCT01614093	[]
# get: NCT01462695	[]
# get: NCT00090402	[]
# get: NCT02475265	[]
# get: NCT00631007	['24722496']
# get: NCT04531527	[]
# get: NCT00552058	['25146586']
# get: NCT01977599	[]
# get: NCT00507442	['22422823']
# get: NCT02439814	[]
# get: NCT01408537	[]
# get: NCT02319668	[]
# get: NCT01042509	[]
# get: NCT02370498	['34363528', '34082019', '29880231']
# get: NCT03487718	[]
# get: NCT02363907	[]
# get: NCT02499770	['34408488', '31504118']
# get: NCT02891629	[]
# get: NCT00985153	[]
# get: NCT00951561	[]
# get: NCT02530294	['32147881', '31111409', '30451318', '30378087']
# get: NCT01072032	['24933720']
# get: NCT00696137	[]
# get: NCT02937350	[]
# get: NCT00763139	['24782291', '24020899']
# get: NCT03196973	[]
# get: NCT00572468	[]
# get: NCT00106626	[]
# get: NCT02217436	['30422942']
# get: NCT00316186	[]
# get: NCT00991302	[]
# get: NCT00993915	[]
# get: NCT03338556	[]
# get: NCT02987205	[]
# get: NCT03065179	[]
# get: NCT01965652	[]
# get: NCT00461851	[]
# get: NCT01336647	[]
# get: NCT03567005	[]
# get: NCT01665872	[]
# get: NCT01614821	[]
# get: NCT02816723	[]
# get: NCT02393755	[]
# get: NCT01922934	['31485965']
# get: NCT00655889	[]
# get: NCT00434161	[]
# get: NCT00660530	[]
# get: NCT02910466	[]
# get: NCT00650260	[]
# get: NCT00719615	[]
# get: NCT01852071	[]
# get: NCT02533258	[]
# get: NCT02254486	['28803744']
# get: NCT02024867	['26578074']
# get: NCT00842764	[]
# get: NCT02372253	['29988125']
# get: NCT00037830	[]
# get: NCT01249872	[]
# get: NCT00765661	[]
# get: NCT00527904	['21319944']
# get: NCT00782626	[]
# get: NCT01536795	[]
# get: NCT02124044	[]
# get: NCT02163447	['34795281', '31307883', '30016328', '29547881', '28982374', '26962728']
# get: NCT02994732	[]
# get: NCT03776175	['34635855']
# get: NCT01069354	[]
# get: NCT01232868	[]
# get: NCT00702507	[]
# get: NCT00540982	[]
# get: NCT02457637	[]
# get: NCT01162317	['30549498']
# get: NCT02033993	[]
# get: NCT01941030	[]
# get: NCT01980914	[]
# get: NCT00700817	['24132613', '23537458', '21355967', '20417856']
# get: NCT02207530	[]
# get: NCT03238352	[]
# get: NCT00844428	[]
# get: NCT02372344	['28344197']
# get: NCT01609348	[]
# get: NCT02926677	[]
# get: NCT02110706	['34857535']
# get: NCT00900159	[]
# get: NCT00986154	['29248859', '28689179', '27570090', '27476789', '27132697', '26179767', '23991658']
# get: NCT00620828	[]
# get: NCT01748552	[]
# get: NCT02159859	[]
# get: NCT01349972	['26022709']
# get: NCT01490723	[]
# get: NCT01810783	['34901863']
# get: NCT01790438	[]
# get: NCT02614729	['29070709']
# get: NCT02237898	[]
# get: NCT02585934	[]
# get: NCT00667745	['26476489', '23911057', '23670706', '23288387', '22076437']
# get: NCT01221623	['26199168']
# get: NCT02127281	[]
# get: NCT00613379	[]
# get: NCT02642393	['34519802']
# get: NCT00464711	[]
# get: NCT01194830	['23134211']
# get: NCT01576172	['29261439']
# get: NCT00653861	[]
# get: NCT01441843	['23635914']
# get: NCT00510068	['27621394', '25479584', '21306238']
# get: NCT01108055	[]
# get: NCT02643615	[]
# get: NCT00178256	[]
# get: NCT03380845	[]
# get: NCT00128193	['24874401']
# get: NCT02812342	[]
# get: NCT00289913	['26308112']
# get: NCT00435461	[]
# get: NCT00261040	[]
# get: NCT03158272	[]
# get: NCT02334787	[]
# get: NCT01761565	[]
# get: NCT01855919	['28919811']
# get: NCT01186770	['33788162']
# get: NCT00785928	['23599435']
# get: NCT00014222	[]
# get: NCT01172418	[]
# get: NCT00778830	[]
# get: NCT00589888	[]
# get: NCT00423137	['20007923']
# get: NCT01821391	[]
# get: NCT02633046	[]
# get: NCT00243269	[]
# get: NCT02150109	[]
# get: NCT04373421	[]
# get: NCT00345293	[]
# get: NCT01507350	[]
# get: NCT03205150	[]
# get: NCT00419393	['26716580']
# get: NCT01707225	[]
# get: NCT03109873	[]
# get: NCT02752087	[]
# get: NCT03585790	[]
# get: NCT00666666	[]
# get: NCT01953081	['31990087']
# get: NCT00006392	['27519183', '27197287', '23064404', '21990298', '20833684', '19066370']
# get: NCT00604825	[]
# get: NCT00613834	['22067774']
# get: NCT00590681	[]
# get: NCT03411902	['33103032']
# get: NCT02051816	['26426458']
# get: NCT02556918	[]
# get: NCT01986933	['29753033', '28249150']
# get: NCT02035553	['29452684']
# get: NCT00804999	[]
# get: NCT00394771	[]
# get: NCT01860534	[]
# get: NCT02444988	['33196806', '31454263', '29485925']
# get: NCT01484132	[]
# get: NCT01365793	[]
# get: NCT03506386	[]
# get: NCT02624375	[]
# get: NCT01742078	[]
# get: NCT02229513	[]
# get: NCT00835263	[]
# get: NCT02489045	[]
# get: NCT02500043	['32128634', '31600365', '30355453']
# get: NCT00605540	[]
# get: NCT02431299	[]
# get: NCT01862029	[]
# get: NCT01897766	[]
# get: NCT01966471	[]
# get: NCT00625846	[]
# get: NCT01943110	[]
# get: NCT01347632	[]
# get: NCT01375010	[]
# get: NCT00254462	[]
# get: NCT00911547	[]
# get: NCT00793910	[]
# get: NCT00427661	[]
# get: NCT01435603	['29596950']
# get: NCT00450723	[]
# get: NCT02468700	[]
# get: NCT03439072	['34620618']
# get: NCT03927209	[]
# get: NCT02420691	[]
# get: NCT00999661	[]
# get: NCT01885000	['26416154']
# get: NCT01260324	[]
# get: NCT03107715	[]
# get: NCT02070302	[]
# get: NCT02779166	[]
# get: NCT03856320	['34258469']
# get: NCT00795704	['28619294']
# get: NCT01324700	[]
# get: NCT02557035	[]
# get: NCT00992433	['22275399']
# get: NCT01335308	['25825539']
# get: NCT01338415	[]
# get: NCT00390221	['25416807', '23562009']
# get: NCT01083433	[]
# get: NCT00004146	[]
# get: NCT01959490	[]
# get: NCT01454583	['23474245']
# get: NCT02532179	[]
# get: NCT02700984	[]
# get: NCT03875508	[]
# get: NCT00940576	[]
# get: NCT03128411	[]
# get: NCT00088413	[]
# get: NCT02134353	['33715994']
# get: NCT00434057	[]
# get: NCT00116844	[]
# get: NCT00676676	[]
# get: NCT01707693	[]
# get: NCT02104895	['32840419', '30474504', '26350524', '25605582']
# get: NCT02322047	[]
# get: NCT02284386	[]
# get: NCT00693498	['21926663']
# get: NCT00385255	['22212127']
# get: NCT00076050	['21824950']
# get: NCT03476850	[]
# get: NCT03096847	[]
# get: NCT04249336	['34615511']
# get: NCT00524342	[]
# get: NCT02575079	[]
# get: NCT02833935	[]
# get: NCT02918071	[]
# get: NCT00857857	[]
# get: NCT00857220	['25266438']
# get: NCT02791945	[]
# get: NCT04303156	[]
# get: NCT01890265	['31575509']
# get: NCT00463151	[]
# get: NCT00551460	[]
# get: NCT00858390	[]
# get: NCT04112069	[]
# get: NCT01432938	['28357715']
# get: NCT02396537	['27739142']
# get: NCT02322593	['32682457']
# get: NCT00495157	['22968888']
# get: NCT01562678	['26831302']
# get: NCT01648491	[]
# get: NCT02557100	['34537057']
# get: NCT00717249	[]
# get: NCT02004158	[]
# get: NCT01049503	['23873319']
# get: NCT00462462	[]
# get: NCT01828034	[]
# get: NCT00934843	['31206501', '23870160', '23587468']
# get: NCT01068626	[]
# get: NCT01635504	[]
# get: NCT03384329	[]
# get: NCT01360996	[]
# get: NCT00981825	[]
# get: NCT01584440	['26393847']
# get: NCT02713490	['30799269', '28802777']
# get: NCT00955955	['26613389', '24813065', '23212058']
# get: NCT04280705	['32445440']
# get: NCT00593385	[]
# get: NCT00614445	['29342163', '27881103', '26844757', '25884778', '25052410', '22972538', '20843504']
# get: NCT02724956	[]
# get: NCT00704028	[]
# get: NCT00722566	['21507715']
# get: NCT01896128	[]
# get: NCT00322712	[]
# get: NCT02184988	['26233808']
# get: NCT01408485	[]
# get: NCT00305565	[]
# get: NCT03198754	[]
# get: NCT01537887	[]
# get: NCT01721772	['32997575', '30422243', '25399552']
# get: NCT01703117	[]
# get: NCT00325143	[]
# get: NCT00689819	['32622346']
# get: NCT03633448	[]
# get: NCT03000283	[]
# get: NCT00922974	[]
# get: NCT01893281	[]
# get: NCT00786838	[]
# get: NCT02635828	[]
# get: NCT02103855	[]
# get: NCT03839511	[]
# get: NCT00033371	['25792707']
# get: NCT02180659	['27434441']
# get: NCT01703000	[]
# get: NCT02514824	[]
# get: NCT00104650	['33270906', '23234632', '19524963']
# get: NCT02461745	[]
# get: NCT02232243	[]
# get: NCT01044576	[]
# get: NCT00875667	['28771673', '26899778']
# get: NCT00782340	['28494751', '27538531']
# get: NCT00631358	[]
# get: NCT01989793	[]
# get: NCT02870309	[]
# get: NCT01296568	[]
# get: NCT01672242	[]
# get: NCT02633501	[]
# get: NCT03999684	[]
# get: NCT00294645	['19926006']
# get: NCT01824498	[]
# get: NCT04492397	[]
# get: NCT01675167	[]
# get: NCT01654796	[]
# get: NCT03214640	[]
# get: NCT00880750	['22657252']
# get: NCT01936844	[]
# get: NCT03478371	[]
# get: NCT01838876	[]
# get: NCT01532089	[]
# get: NCT00871715	['29554849', '28434819', '26864411', '23311856']
# get: NCT01199705	[]
# get: NCT02071823	[]
# get: NCT02092649	['28212390']
# get: NCT03850275	[]
# get: NCT01091428	['30347019']
# get: NCT00361504	['20602712']
# get: NCT01691885	['26550687']
# get: NCT02366845	[]
# get: NCT00203203	['21641354']
# get: NCT03654326	[]
# get: NCT02408445	[]
# get: NCT04203537	[]
# get: NCT01587040	[]
# get: NCT01128153	[]
# get: NCT02583230	[]
# get: NCT02030041	[]
# get: NCT00569868	[]
# get: NCT01282723	[]
# get: NCT03342560	[]
# get: NCT03134209	[]
# get: NCT03271528	[]
# get: NCT02629991	[]
# get: NCT00436852	[]
# get: NCT00477659	[]
# get: NCT03735862	[]
# get: NCT02688556	[]
# get: NCT01594762	[]
# get: NCT03416621	['33109394']
# get: NCT00869024	[]
# get: NCT01052038	[]
# get: NCT02564471	['31743394']
# get: NCT00044655	['22480442', '21536693']
# get: NCT03035929	[]
# get: NCT02538523	[]
# get: NCT01979003	[]
# get: NCT02593864	[]
# get: NCT00810108	[]
# get: NCT00976820	['22801094']
# get: NCT02563808	[]
# get: NCT00781885	[]
# get: NCT00909428	[]
# get: NCT00638924	[]
# get: NCT00624065	[]
# get: NCT01339247	[]
# get: NCT00652314	[]
# get: NCT02801370	[]
# get: NCT02566044	[]
# get: NCT00203268	[]
# get: NCT01494610	[]
# get: NCT02839200	['31953863']
# get: NCT01469039	['28937706', '27574838', '26114240']
# get: NCT02375698	[]
# get: NCT01249404	['32741133', '32108436', '29093068']
# get: NCT00302159	[]
# get: NCT00837811	['25168268']
# get: NCT00230802	[]
# get: NCT01419171	[]
# get: NCT01598753	[]
# get: NCT02581995	[]
# get: NCT01334944	[]
# get: NCT02234115	[]
# get: NCT02185729	[]
# get: NCT01349049	[]
# get: NCT00888628	[]
# get: NCT00357396	[]
# get: NCT00570141	[]
# get: NCT01191476	[]
# get: NCT01461707	['26649879']
# get: NCT00975637	['24079852', '22455412']
# get: NCT02672176	['32130184', '29449200', '29439942']
# get: NCT02109133	['26317357']
# get: NCT00515879	[]
# get: NCT00268892	[]
# get: NCT00314236	[]
# get: NCT00654927	[]
# get: NCT00889928	[]
# get: NCT00756964	[]
# get: NCT01791491	[]
# get: NCT02067468	['32049551', '31625399']
# get: NCT02959138	[]
# get: NCT00575185	[]
# get: NCT02080455	[]
# get: NCT00200785	[]
# get: NCT00231777	[]
# get: NCT00736255	[]
# get: NCT01983020	[]
# get: NCT02493868	['34235612', '32860422', '31166571']
# get: NCT03740659	['32285142']
# get: NCT02548650	[]
# get: NCT02146326	[]
# get: NCT00637000	[]
# get: NCT01193517	[]
# get: NCT01595438	['34374952', '29912399', '27313268']
# get: NCT02347410	[]
# get: NCT03119610	[]
# get: NCT02117713	[]
# get: NCT00116649	[]
# get: NCT00867009	[]
# get: NCT02097537	[]
# get: NCT02199717	[]
# get: NCT00984815	['25495134']
# get: NCT00620321	[]
# get: NCT00673881	[]
# get: NCT02062151	[]
# get: NCT01209520	[]
# get: NCT02638493	[]
# get: NCT01075399	[]
# get: NCT00561431	[]
# get: NCT00842985	[]
# get: NCT00957853	[]
# get: NCT01472939	['25693609']
# get: NCT01850563	[]
# get: NCT00841659	[]
# get: NCT02096679	[]
# get: NCT02442830	['29935143']
# get: NCT02412735	[]
# get: NCT02175966	['27943563']
# get: NCT01987895	[]
# get: NCT02338154	[]
# get: NCT00115076	[]
# get: NCT01186978	[]
# get: NCT02347631	[]
# get: NCT02662608	[]
# get: NCT00940771	[]
# get: NCT00943722	['29767739', '29269325', '26101366', '26086587']
# get: NCT02315534	[]
# get: NCT02955329	[]
# get: NCT02996474	[]
# get: NCT01437449	[]
# get: NCT02769858	[]
# get: NCT00227877	['31225897']
# get: NCT02370784	[]
# get: NCT01409382	[]
# get: NCT03054077	[]
# get: NCT01190878	[]
# get: NCT02926950	[]
# get: NCT00881894	['24006953']
# get: NCT01755143	[]
# get: NCT01165320	[]
# get: NCT00525057	[]
# get: NCT00548249	[]
# get: NCT03315208	[]
# get: NCT01703832	[]
# get: NCT01253980	[]
# get: NCT04431908	[]
# get: NCT01669096	[]
# get: NCT03300050	['33288923', '31630990']
# get: NCT02718248	[]
# get: NCT00674609	[]
# get: NCT02589665	['31493397']
# get: NCT02936323	[]
# get: NCT00324350	['26305617', '22723583']
# get: NCT00700973	[]
# get: NCT02487979	[]
# get: NCT01318135	['24843617']
# get: NCT00930293	[]
# get: NCT00525837	[]
# get: NCT00584285	[]
# get: NCT00373425	['26324372']
# get: NCT00742417	[]
# get: NCT00924352	[]
# get: NCT00508482	['25526462']
# get: NCT00677833	['25881046']
# get: NCT02565706	['32153828']
# get: NCT00822757	[]
# get: NCT01040819	[]
# get: NCT02109640	['27762434']
# get: NCT01227889	['31864178', '26040620', '24769640', '22735384']
# get: NCT02120001	['30181363']
# get: NCT01029535	[]
# get: NCT03022799	[]
# get: NCT02287675	[]
# get: NCT03036150	['34619108', '34619106', '34446370', '33338413', '33186054', '32970396', '32862232', '32030417']
# get: NCT01783574	['32660299']
# get: NCT02365558	[]
# get: NCT00983918	[]
# get: NCT01199744	[]
# get: NCT01692938	[]
# get: NCT01848210	[]
# get: NCT00714792	[]
# get: NCT01259492	['25183661', '24371021']
# get: NCT02887989	[]
# get: NCT00842153	[]
# get: NCT01109849	['31473291']
# get: NCT02628223	[]
# get: NCT01170117	['30654643']
# get: NCT03643952	[]
# get: NCT00691665	[]
# get: NCT00840073	[]
# get: NCT03011840	[]
# get: NCT02320175	[]
# get: NCT00833560	[]
# get: NCT02469857	['32657946']
# get: NCT00754741	[]
# get: NCT03535649	[]
# get: NCT02587065	[]
# get: NCT01767467	['31399377']
# get: NCT00850889	[]
# get: NCT01518322	[]
# get: NCT01996917	[]
# get: NCT00165776	[]
# get: NCT00319696	[]
# get: NCT02763046	[]
# get: NCT00620542	['24448227', '24043299', '22085316', '21446892']
# get: NCT01308008	[]
# get: NCT01347034	[]
# get: NCT00985712	[]
# get: NCT01995045	[]
# get: NCT01106157	['25500887']
# get: NCT02974543	[]
# get: NCT03500198	[]
# get: NCT01519206	[]
# get: NCT01272960	[]
# get: NCT02006979	[]
# get: NCT01100762	[]
# get: NCT02310906	['34788571', '32139505']
# get: NCT00821327	[]
# get: NCT00702689	[]
# get: NCT00151411	['21704212', '21193187']
# get: NCT03268941	['34148244']
# get: NCT03292692	['31380690']
# get: NCT01982968	['30100404']
# get: NCT02198794	['31296586']
# get: NCT02009046	['25886554']
# get: NCT01222585	[]
# get: NCT00733304	[]
# get: NCT00120523	['25802354']
# get: NCT00116831	['21359834', '20194881', '19033001']
# get: NCT02045511	[]
# get: NCT03618017	[]
# get: NCT00952068	[]
# get: NCT03915860	[]
# get: NCT02004613	['34148803', '32682483']
# get: NCT01236768	[]
# get: NCT02290925	[]
# get: NCT01662908	['27165711']
# get: NCT01051310	[]
# get: NCT03049488	[]
# get: NCT00759096	[]
# get: NCT03296787	[]
# get: NCT01490086	[]
# get: NCT01116986	[]
# get: NCT03480802	[]
# get: NCT01396486	['26646031']
# get: NCT02848599	['30640654']
# get: NCT00693303	[]
# get: NCT01949155	['26985629']
# get: NCT02090426	['31914242']
# get: NCT02622568	[]
# get: NCT00951015	['22018760']
# get: NCT02486692	['29746232', '28239485']
# get: NCT03059901	[]
# get: NCT01306656	[]
# get: NCT01569529	[]
# get: NCT03119389	[]
# get: NCT02991118	['32609313', '31714986']
# get: NCT03085797	[]
# get: NCT00248040	[]
# get: NCT00594256	[]
# get: NCT00864032	[]
# get: NCT02076997	[]
# get: NCT01840579	[]
# get: NCT01532999	[]
# get: NCT01811225	[]
# get: NCT00969280	['19958541']
# get: NCT02512042	[]
# get: NCT00122317	[]
# get: NCT00951483	[]
# get: NCT02308046	[]
# get: NCT01786512	['33176443', '33176437', '27914656']
# get: NCT02154581	[]
# get: NCT03115411	[]
# get: NCT01120990	[]
# get: NCT00878800	[]
# get: NCT02694029	[]
# get: NCT02643355	[]
# get: NCT02033005	[]
# get: NCT03349710	[]
# get: NCT02906033	['33576579']
# get: NCT01650831	[]
# get: NCT00322621	[]
# get: NCT01334086	[]
# get: NCT02165826	['29797235']
# get: NCT02725593	[]
# get: NCT01029704	[]
# get: NCT01310075	[]
# get: NCT00431951	[]
# get: NCT02691702	[]
# get: NCT02793674	[]
# get: NCT00711477	[]
# get: NCT00590564	[]
# get: NCT01189760	[]
# get: NCT02298361	['29747644']
# get: NCT01947647	['34996343']
# get: NCT01193114	[]
# get: NCT02909439	['32405975']
# get: NCT00572195	['32690786']
# get: NCT01557517	[]
# get: NCT00950729	[]
# get: NCT02448719	[]
# get: NCT00440518	[]
# get: NCT01267253	[]
# get: NCT00444600	['20008710']
# get: NCT01330108	[]
# get: NCT01981356	[]
# get: NCT00097708	[]
# get: NCT01901419	[]
# get: NCT02729909	[]
# get: NCT00157157	[]
# get: NCT01300923	[]
# get: NCT00675584	['22111718']
# get: NCT00352417	[]
# get: NCT01500200	[]
# get: NCT00289536	[]
# get: NCT02475395	[]
# get: NCT02363322	['27732819']
# get: NCT02363998	[]
# get: NCT01727765	[]
# get: NCT03430349	['31174831']
# get: NCT02467777	[]
# get: NCT00084383	[]
# get: NCT02370602	[]
# get: NCT01108341	[]
# get: NCT02210052	[]
# get: NCT02422290	[]
# get: NCT00593112	[]
# get: NCT03131167	[]
# get: NCT01429077	[]
# get: NCT00437658	[]
# get: NCT01163266	['31818787', '26035185']
# get: NCT00363415	['30073795', '19720897']
# get: NCT03546842	[]
# get: NCT02107339	[]
# get: NCT01929642	[]
# get: NCT00603187	[]
# get: NCT03098979	['31162568']
# get: NCT02132533	['34259466']
# get: NCT02110264	['27282118']
# get: NCT03396913	[]
# get: NCT03717051	[]
# get: NCT02047981	['34991704', '34037753', '33176084', '32931496', '32426812', '31981558', '31443654', '29694816']
# get: NCT01032200	[]
# get: NCT01584024	['31526071']
# get: NCT02290509	['28968871']
# get: NCT00990288	[]
# get: NCT01062074	[]
# get: NCT01929759	[]
# get: NCT00473837	[]
# get: NCT01296542	[]
# get: NCT02998684	[]
# get: NCT02332239	[]
# get: NCT00238108	['23024438']
# get: NCT00533273	[]
# get: NCT00779909	[]
# get: NCT02239692	[]
# get: NCT02622113	[]
# get: NCT00827359	[]
# get: NCT01382251	[]
# get: NCT01519453	['33016987']
# get: NCT00549562	[]
# get: NCT00196326	[]
# get: NCT01437501	[]
# get: NCT01598090	[]
# get: NCT02697773	['32252976', '31265100']
# get: NCT01087788	['30191421', '29717036', '27696727', '24996416', '24942382', '24339179', '23942869', '23942868']
# get: NCT04452435	[]
# get: NCT01526889	[]
# get: NCT00897676	[]
# get: NCT01494298	[]
# get: NCT02317627	[]
# get: NCT02635204	[]
# get: NCT01631812	[]
# get: NCT00345254	[]
# get: NCT02164539	['31151458', '28947022']
# get: NCT02299336	[]
# get: NCT03734601	[]
# get: NCT02382276	[]
# get: NCT03150758	[]
# get: NCT01004744	[]
# get: NCT01292135	[]
# get: NCT01959841	[]
# get: NCT00223808	['21674393']
# get: NCT00238238	['32470440', '26304886']
# get: NCT01912729	[]
# get: NCT01135394	[]
# get: NCT01394952	['34153269', '33537745', '33239067', '32562683', '31924562', '31189511', '31189509']
# get: NCT01171924	[]
# get: NCT01877915	['32171760', '31461239', '31017637', '30146935']
# get: NCT01269125	['32147182']
# get: NCT02672423	[]
# get: NCT01568034	[]
# get: NCT01895608	[]
# get: NCT02130258	[]
# get: NCT03192137	[]
# get: NCT02413190	[]
# get: NCT02029521	[]
# get: NCT02879383	[]
# get: NCT01950039	['29860335']
# get: NCT02975297	['33831213']
# get: NCT01523873	[]
# get: NCT00753506	[]
# get: NCT00835978	['30616534', '24140184']
# get: NCT02803138	[]
# get: NCT00415610	[]
# get: NCT00381966	[]
# get: NCT00084929	[]
# get: NCT02110108	[]
# get: NCT00486434	['31481084', '25582279', '25576879']
# get: NCT00910715	[]
# get: NCT01198028	[]
# get: NCT00717626	[]
# get: NCT00550147	[]
# get: NCT00594659	[]
# get: NCT00446264	[]
# ...
# get: NCT01293695	['34403019']
# get: NCT00726999	[]
# get: NCT02101190	[]
# get: NCT04035694	[]
# get: NCT00943436	[]
# get: NCT01381861	[]
# get: NCT04087343	[]
# get: NCT03200925	[]
# get: NCT03612856	['34086880']
# get: NCT01946191	['32808209', '31711168']
# get: NCT03291288	[]
# get: NCT00927563	[]
# get: NCT00973622	[]
# get: NCT02032888	['26196502']
# get: NCT02167256	[]
# get: NCT01934972	['25566387']
# get: NCT00810797	[]
# get: NCT00967369	[]
# get: NCT00834197	[]
# get: NCT01311687	['27081177', '26250580', '26160879', '26149712', '25425684', '24007748']
# get: NCT01472185	['26049552']
# get: NCT00686075	[]
# get: NCT01534520	['27500351']
# get: NCT02544984	['27638496']
# get: NCT02395822	[]
# get: NCT00950755	[]
# get: NCT01013883	[]
# get: NCT02246608	[]
# get: NCT01891864	[]
# get: NCT02380742	['28594757']
# get: NCT03888755	[]
# get: NCT01340482	[]
# get: NCT00283686	['30803434', '25399733', '25111236', '22205355']
# get: NCT02101437	['30783954']
# get: NCT02807844	[]
# get: NCT03694925	[]
# get: NCT00592774	[]
# get: NCT00906971	[]
# get: NCT02058589	['30843046']
# get: NCT03017508	[]
# get: NCT01149096	[]
# get: NCT01806662	[]
# get: NCT02516150	[]
# get: NCT02364037	[]
# get: NCT00869960	[]
# get: NCT02724111	[]
# get: NCT03116828	[]
# get: NCT00115037	[]
# get: NCT01383213	[]
# get: NCT01411137	[]
# get: NCT00400153	['20172704']
# get: NCT01845831	['27964837']
# get: NCT00468208	[]
# get: NCT00926796	['25031289']
# get: NCT03041441	[]
# get: NCT02701985	[]
# get: NCT02611765	['28200045']
# get: NCT00127413	[]
# get: NCT00979810	[]
# get: NCT03394924	[]
# get: NCT02132910	['28919191']
# get: NCT00472303	['25054392']
# get: NCT03056690	['33328761']
# get: NCT01451632	[]
# get: NCT00256724	[]
# get: NCT03191552	['30293457']
# get: NCT00803400	[]
# get: NCT00521599	[]
# get: NCT01664130	[]
# get: NCT00203229	[]
# get: NCT00431496	[]
# get: NCT00434330	[]
# get: NCT00517296	[]
# get: NCT04005391	['34709526', '32819394']
# get: NCT01794312	[]
# get: NCT00996632	[]
# get: NCT02005016	[]
# get: NCT00179673	[]
# get: NCT00356278	['30059794', '27183343', '24743802']
# get: NCT01853696	['26020827']
# get: NCT02799381	[]
# get: NCT00570739	['22913890', '22836068', '20634176', '20634175']
# get: NCT01160640	['32052831']
# get: NCT01214980	['25868409']
# get: NCT02903836	[]
# get: NCT01209234	['30763195']
# get: NCT03004638	[]
# get: NCT01174368	[]
# get: NCT01051739	[]
# get: NCT02038218	[]
# get: NCT03553940	[]
# get: NCT02343406	['33601293', '31747009']
# get: NCT01544166	[]
# get: NCT00460525	['28282396', '27087149', '24260195', '21916638']
# get: NCT00932113	['25946554']
# get: NCT03373110	[]
# get: NCT01539759	['26241250']
# get: NCT00195013	[]
# get: NCT01182441	['29103847', '26627989']
# get: NCT02001064	[]
# get: NCT00097773	['26288390', '25972024', '21893650', '19470318']
# get: NCT01212744	[]
# get: NCT02034409	[]
# get: NCT00491894	[]
# get: NCT04137627	['32372215']
# get: NCT02636699	['30794314']
# get: NCT01681810	[]
# get: NCT01282242	[]
# get: NCT00498706	['22706833']
# get: NCT01682135	[]
# get: NCT00877058	['27716095', '20504358']
# get: NCT00958243	[]
# get: NCT00519623	[]
# get: NCT01669811	[]
# get: NCT02796963	['30153265']
# get: NCT00296400	['25660356']
# get: NCT00532779	['20673995']
# get: NCT03535974	[]
# get: NCT04280445	[]
# get: NCT00740220	[]
# get: NCT00460421	[]
# get: NCT04057768	[]
# get: NCT03087786	[]
# get: NCT01628016	['25245928']
# get: NCT00824512	[]
# get: NCT03226275	['30232699']
# get: NCT00748657	[]
# get: NCT02389361	[]
# get: NCT01412229	[]
# get: NCT01174576	['21346100']
# get: NCT02794870	[]
# get: NCT01184417	[]
# get: NCT00111007	[]
# get: NCT02092662	[]
# get: NCT03276078	[]
# get: NCT02987231	[]
# get: NCT00928707	[]
# get: NCT01220869	[]
# get: NCT01925417	[]
# get: NCT01785186	['28100438']
# get: NCT00564733	[]
# get: NCT00424476	['34741731', '33568389', '31302695', '23524886', '22337213', '22275291', '21296403']
# get: NCT01988571	[]
# get: NCT01868633	[]
# get: NCT00770146	['24013058']
# get: NCT00810693	['27457511', '26135803', '23883378']
# get: NCT02038946	[]
# get: NCT01081834	['29022746', '28327140', '28241822', '28197834', '27600862', '26580237', '26579834', '26373629', '26121561', '25813214', '24585202', '24517339', '24073995']
# get: NCT03061214	[]
# get: NCT04409041	[]
# get: NCT00319592	[]
# get: NCT03252964	[]
# get: NCT00834522	[]
# get: NCT01433081	[]
# get: NCT00723450	['26598477']
# get: NCT01121211	['31219558']
# get: NCT00147030	[]
# get: NCT01615328	[]
# get: NCT01759446	[]
# get: NCT00244751	[]
# get: NCT01594853	[]
# get: NCT00855166	['26894924', '23906445', '22651373']
# get: NCT01063972	['31367875']
# get: NCT00905151	[]
# get: NCT00501852	['20541381']
# get: NCT02369835	[]
# get: NCT00398073	[]
# get: NCT01006629	[]
# get: NCT02765490	['30693573']
# get: NCT02596321	[]
# get: NCT00194779	[]
# get: NCT02975206	[]
# get: NCT02468830	[]
# get: NCT03342963	[]
# get: NCT00999544	['22260216']
# get: NCT00384670	[]
# get: NCT00957359	['31916890', '27909164']
# get: NCT00376935	[]
# get: NCT01539239	['32143828', '29945799']
# get: NCT00942851	[]
# get: NCT01971385	[]
# get: NCT00178685	['27923864', '27839954', '21999719', '21382516', '19373517', '18838243']
# get: NCT01470989	[]
# get: NCT03319810	[]
# get: NCT00919932	[]
# get: NCT01404611	['28006041']
# get: NCT03109262	[]
# get: NCT01095653	[]
# get: NCT02940860	['32049331']
# get: NCT00619073	['20736449']
# get: NCT03101462	[]
# get: NCT01411267	[]
# get: NCT00678639	['21835378']
# get: NCT02597452	[]
# get: NCT01889667	[]
# get: NCT00725985	['24502830']
# get: NCT01878006	[]
# get: NCT02928536	[]
# get: NCT01144715	['26122686', '25782693', '23280269']
# get: NCT02515058	['30161278']
# get: NCT00591240	[]
# get: NCT02549339	[]
# get: NCT01115738	['24718367', '24065443']
# get: NCT00190684	[]
# get: NCT02504320	[]
# get: NCT03339570	[]
# get: NCT00371644	['29905663', '29573657', '26198645', '23325750']
# get: NCT02936648	[]
# get: NCT00162123	['25210016']
# get: NCT00808470	['22122960']
# get: NCT02539368	[]
# get: NCT02105636	['32583557', '31422216', '31246283', '30972702', '29884413', '28939066', '28651929', '27718784']
# get: NCT02108522	[]
# get: NCT00729326	[]
# get: NCT00900601	[]
# get: NCT00416182	[]
# get: NCT00565721	[]
# get: NCT00926783	['24425420']
# get: NCT00515541	[]
# get: NCT00319111	[]
# get: NCT00912925	['33874971']
# get: NCT01853137	[]
# get: NCT00110214	[]
# get: NCT02588586	[]
# get: NCT02923349	[]
# get: NCT00553332	[]
# get: NCT01753999	['33202147']
# get: NCT02596971	[]
# get: NCT01854359	[]
# get: NCT02688933	[]
# get: NCT03343639	['32007513']
# get: NCT00142298	[]
# get: NCT01847638	[]
# get: NCT01873989	[]
# get: NCT02500628	[]
# get: NCT00304746	[]
# get: NCT01375569	[]
# get: NCT01015170	[]
# get: NCT04203225	[]
# get: NCT02589977	[]
# get: NCT03226457	['32865004', '29042392']
# get: NCT01416155	[]
# get: NCT02364271	[]
# get: NCT00928226	[]
# get: NCT00600886	['27039081', '25103549']
# get: NCT02367859	[]
# get: NCT00361595	[]
# get: NCT02492802	[]
# get: NCT02474355	[]
# get: NCT02657226	[]
# get: NCT00822328	[]
# get: NCT03549598	[]
# get: NCT02360293	['32687474', '30694208', '30681965']
# get: NCT02608450	['32320027']
# get: NCT01642147	[]
# get: NCT02962687	[]
# get: NCT00958568	[]
# get: NCT02185105	[]
# get: NCT02949271	[]
# get: NCT01113749	['24083403', '22091750']
# get: NCT01451996	[]
# get: NCT00231309	[]
# get: NCT00790400	['30192751', '30053159', '29569806', '28792952', '26156073', '23312829']
# get: NCT00576927	[]
# get: NCT00479115	[]
# get: NCT01560260	[]
# get: NCT03128099	[]
# get: NCT01335685	[]
# get: NCT01587703	[]
# get: NCT03123874	[]
# get: NCT00005901	[]
# get: NCT00112957	[]
# get: NCT01194440	[]
# get: NCT00474266	['26780033', '21443965']
# get: NCT02194933	['32450497']
# get: NCT02580877	[]
# get: NCT01451645	[]
# get: NCT01592435	[]
# get: NCT02734979	[]
# get: NCT03384745	['33894834']
# get: NCT01566162	[]
# get: NCT02474498	[]
# get: NCT02821403	['28045969']
# get: NCT02980978	['30711463']
# get: NCT01466881	[]
# get: NCT01823861	['29191231', '25388660']
# get: NCT03433794	[]
# get: NCT03152110	[]
# get: NCT00373269	[]
# get: NCT02752074	['31221619']
# get: NCT00655707	[]
# get: NCT01104584	[]
# get: NCT03587207	[]
# get: NCT01966458	['30007559']
# get: NCT00798018	[]
# get: NCT03691831	[]
# get: NCT03201419	['34932192']
# get: NCT02411591	[]
# get: NCT00446641	[]
# get: NCT00355199	[]
# get: NCT00227266	['20808854']
# get: NCT02000921	[]
# get: NCT01220973	[]
# get: NCT02049476	[]
# get: NCT01554982	[]
# get: NCT01778127	[]
# get: NCT01150357	[]
# get: NCT01687790	[]
# get: NCT00525174	[]
# get: NCT01330030	[]
# get: NCT03237481	['31429023']
# get: NCT00721214	[]
# get: NCT01808066	[]
# get: NCT02417064	['34288609', '34235612', '32860422', '32367114', '31290965']
# get: NCT02867059	[]
# get: NCT02940574	[]
# get: NCT03232736	[]
# get: NCT03049917	['33048877']
# get: NCT02933879	[]
# get: NCT01602484	[]
# get: NCT00723021	[]
# get: NCT02326233	['30464411']
# get: NCT00332241	['24138011', '20973712', '19948625']
# get: NCT02410837	[]
# get: NCT00454207	[]
# get: NCT00771927	[]
# get: NCT01698008	[]
# get: NCT00765245	[]
# get: NCT04198948	[]
# get: NCT03252145	['33872573']
# get: NCT01903811	['32299820']
# get: NCT02501538	[]
# get: NCT00400569	[]
# get: NCT01188876	[]
# get: NCT02018562	['31385620']
# get: NCT00122460	['32993574', '23265711', '18784101']
# get: NCT01002547	['31332029']
# get: NCT00548262	[]
# get: NCT01106352	['31082669']
# get: NCT01982786	['29903505']
# get: NCT01635244	['26819292']
# get: NCT00529191	[]
# get: NCT03885596	[]
# get: NCT01948076	['25387438']
# get: NCT02109107	[]
# get: NCT01830842	[]
# get: NCT01854047	['31351189', '30138668', '29355679', '27130691']
# get: NCT04025684	[]
# get: NCT01440881	[]
# get: NCT01194271	[]
# get: NCT01613768	[]
# get: NCT01248741	[]
# get: NCT03528577	[]
# get: NCT01262105	[]
# get: NCT04308694	[]
# get: NCT00444067	['25646746']
# get: NCT01061866	[]
# get: NCT00726063	[]
# get: NCT02334267	['28851317']
# get: NCT00106704	[]
# get: NCT01168427	[]
# get: NCT03145818	[]
# get: NCT01363011	[]
# get: NCT01837654	[]
# get: NCT02239770	[]
# get: NCT01808573	['34553296', '33909203', '32678716']
# get: NCT02770521	[]
# get: NCT02611154	[]
# get: NCT01189279	[]
# get: NCT02830880	[]
# get: NCT02169674	[]
# get: NCT02358473	[]
# get: NCT02224625	[]
# get: NCT03495817	[]
# get: NCT03839641	[]
# get: NCT01147926	['25869393']
# get: NCT01127139	[]
# get: NCT02570425	['29954359']
# get: NCT01040351	['20672903']
# get: NCT00490815	[]
# get: NCT01045499	[]
# get: NCT03052530	[]
# get: NCT02296138	['32943047', '32776202', '29605624']
# get: NCT01551212	['34525259']
# get: NCT02395055	[]
# get: NCT02818114	[]
# get: NCT01173601	['27035159']
# get: NCT02752048	['31957953']
# get: NCT01272882	[]
# get: NCT01471457	['29474292', '25935783']
# get: NCT00919867	['23615868']
# get: NCT01957761	[]
# get: NCT03129568	[]
# get: NCT01863563	[]
# get: NCT01813058	[]
# get: NCT02952365	[]
# get: NCT00304954	[]
# get: NCT02658019	[]
# get: NCT00724451	[]
# get: NCT03029780	[]
# get: NCT00888173	[]
# get: NCT00293020	[]
# get: NCT00140413	[]
# get: NCT00548041	[]
# get: NCT01977092	[]
# get: NCT02968602	[]
# get: NCT00920816	['33947608', '27498023', '24206640']
# get: NCT00815035	[]
# get: NCT01285609	[]
# get: NCT02445755	[]
# get: NCT00183196	['21454917']
# get: NCT00873327	['22569355']
# get: NCT00966875	['26669919', '24623718']
# get: NCT00638716	[]
# get: NCT02777086	[]
# get: NCT00396019	[]
# get: NCT01306890	[]
# get: NCT03127956	[]
# get: NCT01606735	[]
# get: NCT00181155	['22361399']
# get: NCT00953927	['26554383', '24912498', '23391465']
# get: NCT01001052	[]
# get: NCT01037218	[]
# get: NCT03816761	[]
# get: NCT01248468	[]
# get: NCT01821300	[]
# get: NCT00684749	[]
# get: NCT02246582	[]
# get: NCT02427477	[]
# get: NCT03312023	[]
# get: NCT00415870	['23085329', '19141433']
# get: NCT00747617	['21270326']
# get: NCT01564953	[]
# get: NCT01763788	['30797492']
# get: NCT01325714	[]
# get: NCT01639339	['32937045']
# get: NCT02880254	[]
# get: NCT00397579	[]
# get: NCT02795767	['33512413']
# get: NCT03483961	[]
# get: NCT02983552	['30352226']
# get: NCT01214356	[]
# get: NCT01807026	[]
# get: NCT01514786	['31128959']
# get: NCT00927810	[]
# get: NCT03065530	[]
# get: NCT01093417	['22293363']
# get: NCT00373256	[]
# get: NCT00837434	[]
# get: NCT01059903	['24006953']
# get: NCT02156271	[]
# get: NCT00366275	[]
# get: NCT01107015	['29217502']
# get: NCT00711971	['31783739', '29940888', '27485050', '23531328', '21696635']
# get: NCT02425891	['31786121', '30345906']
# get: NCT00243191	[]
# get: NCT01059773	['27515070']
# get: NCT01419249	[]
# get: NCT00403481	['21777013', '20085534']
# get: NCT01625091	[]
# get: NCT00627393	['26333778']
# get: NCT01446913	['26429745']
# get: NCT02877927	['31861009', '31474458', '31367742']
# get: NCT01871506	['33048154']
# get: NCT02859597	[]
# get: NCT02566525	[]
# get: NCT03712189	[]
# get: NCT02023151	[]
# get: NCT00600925	['20825316']
# get: NCT03029091	[]
# get: NCT01347307	[]
# get: NCT01427738	['27677161']
# get: NCT00812877	[]
# get: NCT02308696	[]
# get: NCT02670343	[]
# get: NCT03395808	[]
# get: NCT01894906	[]
# get: NCT01396226	[]
# get: NCT01754389	['29326124']
# get: NCT01798225	[]
# get: NCT03197389	[]
# get: NCT01442779	[]
# get: NCT01794741	['29490769']
# get: NCT01500226	['26272768']
# get: NCT01064687	['26691396']
# get: NCT02038543	[]
# get: NCT00617396	[]
# get: NCT01561963	[]
# get: NCT00438854	[]
# get: NCT01202279	[]
# get: NCT01870596	[]
# get: NCT01219959	[]
# get: NCT00891319	['27608819']
# get: NCT00107900	[]
# get: NCT00761267	[]
# get: NCT00424827	[]
# get: NCT02104765	[]
# get: NCT00059787	[]
# get: NCT00547534	[]
# get: NCT00905125	[]
# get: NCT02016105	['33651341']
# get: NCT00191451	[]
# get: NCT01431131	[]
# get: NCT02355821	[]
# get: NCT01714687	[]
# get: NCT01243957	[]
# get: NCT01640808	[]
# get: NCT00004562	['30950656', '23141853', '22025606', '20547926', '19228620', '19194534', '17105759']
# get: NCT00872430	['20433751']
# get: NCT01297322	[]
# get: NCT01640873	[]
# get: NCT02017860	[]
# get: NCT01218204	[]
# get: NCT00788151	['22863660']
# get: NCT02576938	['33826132']
# get: NCT00509106	['30597021', '26702925', '25487791', '23357290', '21482568', '21482570']
# get: NCT01615484	[]
# get: NCT01879722	['29103081']
# get: NCT01300546	[]
# get: NCT03334747	['34930267']
# get: NCT00475085	['22915657']
# get: NCT01533246	[]
# get: NCT01026181	[]
# get: NCT03631732	['34397746']
# get: NCT00584454	[]
# get: NCT02778932	[]
# get: NCT01740323	[]
# get: NCT01472081	[]
# get: NCT00667615	[]
# get: NCT02172664	[]
# get: NCT02828436	[]
# get: NCT01098539	[]
# get: NCT03654404	[]
# get: NCT01352221	[]
# get: NCT02364388	[]
# get: NCT02115542	[]
# get: NCT02387801	[]
# get: NCT00423657	['34741280', '30597021', '21115456', '21115455', '20695801']
# get: NCT01392625	['27856208', '25354998']
# get: NCT01534897	[]
# get: NCT01208324	[]
# get: NCT00965341	[]
# get: NCT00594165	['25997442', '25444083', '22326237']
# get: NCT04041700	[]
# get: NCT01019694	['23658479']
# get: NCT02992197	['31607603']
# get: NCT01677858	[]
# get: NCT00233480	['22041323']
# get: NCT00577655	[]
# get: NCT01569815	[]
# get: NCT02283762	['27746061']
# get: NCT01989130	['27100764']
# get: NCT02626780	[]
# get: NCT02683668	[]
# get: NCT02437890	[]
# get: NCT04027686	[]
# get: NCT01390779	[]
# get: NCT00223236	[]
# get: NCT00790582	[]
# get: NCT03312348	[]
# get: NCT03937570	[]
# get: NCT02326220	['27572070', '27206951']
# get: NCT02140970	[]
# get: NCT03402386	[]
# get: NCT03374683	['33904820']
# get: NCT02120300	[]
# get: NCT00414635	[]
# get: NCT02482675	[]
# get: NCT01875861	['24103648']
# get: NCT01716533	[]
# get: NCT03223350	[]
# get: NCT01087814	[]
# get: NCT02519244	[]
# get: NCT01720264	[]
# get: NCT01663103	[]
# get: NCT01451541	[]
# get: NCT00325442	['22628490']
# get: NCT00734500	[]
# get: NCT02788175	[]
# get: NCT04246021	[]
# get: NCT00534001	[]
# get: NCT00997373	[]
# get: NCT01551030	[]
# get: NCT02139046	['30073793']
# get: NCT01943916	[]
# get: NCT02961894	[]
# get: NCT00701675	[]
# get: NCT03508843	[]
# get: NCT00645827	[]
# get: NCT01215357	[]
# get: NCT00796523	[]
# get: NCT03629184	['32516282']
# get: NCT01258803	['24019197']
# get: NCT00762892	[]
# get: NCT03799211	[]
# get: NCT01529450	[]
# get: NCT02296242	[]
# get: NCT02385708	[]
# get: NCT01835496	[]
# get: NCT01677741	[]
# get: NCT03618147	[]
# get: NCT00535587	[]
# get: NCT01965366	[]
# get: NCT02248103	[]
# get: NCT02530385	['32150549']
# get: NCT00619866	[]
# get: NCT00447057	[]
# get: NCT00253890	[]
# get: NCT01278303	[]
# get: NCT00495222	[]
# get: NCT01212107	[]
# get: NCT01690130	['23485014']
# get: NCT01151540	[]
# get: NCT02618928	[]
# get: NCT00736580	['24294709']
# get: NCT00644995	['21414216']
# get: NCT00665366	[]
# get: NCT00004635	[]
# get: NCT00556504	[]
# get: NCT00359736	['20012639']
# get: NCT00975923	['21312329']
# get: NCT00673933	[]
# get: NCT01390246	[]
# get: NCT01925677	[]
# get: NCT03650452	[]
# get: NCT01420068	[]
# get: NCT01377194	['26773906', '24144196']
# get: NCT01629589	['31301919']
# get: NCT01967940	[]
# get: NCT02517905	[]
# get: NCT02588833	[]

# %%
print(f'size of result dict: {len(results_dict)}')
results_dict_updated = {}
for k, v in results_dict.items():
  if k in nctid_list_to_map:
    results_dict_updated[k] = v
print(f'size of result dict updated: {len(results_dict_updated)}')
# Out:
# size of result dict: 30604
# size of result dict updated: 30151

# %%
save_pickle(results_dict_updated)
# !cp nctid_to_pmid_dict.pickle  /content/gdrive/MyDrive/Demographic\ Analysis\ Project/

# %%
print(len(results_dict_updated.keys()))
nctid_count = 0
pmid_count = 0
pmid_set = set()
for k, v in results_dict_updated.items():
  if v:
    nctid_count += 1
    print(f'{k}:\t{v}')
    for pm in v:
      pmid_count += 1 
      pmid_set.add(pm)

print(f'number of nctid: {nctid_count}')
print(f'number of pmid: {pmid_count}')
print(f'number of unique pmid: {len(pmid_set)}')
# Out:
# Streaming output truncated to the last 5000 lines.
# NCT00970944:	['22375973']
# NCT01844115:	['27486544', '27382289', '27232052']
# NCT02136069:	['32445184']
# NCT01640951:	['28580579']
# NCT03091920:	['31858186']
# NCT02597127:	['31630870', '31553410', '30487231', '29735484', '28306389']
# NCT02425098:	['31843269']
# NCT00711009:	['22730929', '22180523']
# NCT03228433:	['33990969']
# NCT02974153:	['34823467', '33781209', '33314079', '33023473', '32209650']
# NCT02542410:	['34934987']
# NCT01969708:	['33415354', '31600368', '29476687', '28492860']
# NCT03428750:	['33840781']
# NCT00332202:	['27217449']
# NCT02394730:	['30257802']
# NCT02863328:	['32827435', '31530666']
# NCT02104739:	['32228379']
# NCT00444080:	['24210765']
# NCT02820038:	['32799397']
# NCT02092220:	['28007348']
# NCT01130844:	['26893546']
# NCT00307684:	['21798108']
# NCT00735644:	['24656175', '22777096']
# NCT00794196:	['23950967', '19656386']
# NCT01170533:	['21521834']
# NCT03058991:	['31918169']
# NCT01475734:	['25263215']
# NCT03247322:	['34197699']
# NCT00856206:	['25028379']
# NCT00159432:	['22622147']
# NCT01261390:	['31116848', '27018174']
# NCT01498692:	['29217001', '24905795']
# NCT02245815:	['30898471']
# NCT00568178:	['23207876', '22739977', '21285125']
# NCT00607243:	['20600480']
# NCT00810810:	['31608454']
# NCT01362296:	['25722381']
# NCT02142504:	['31001633', '27354368']
# NCT02616783:	['31578954']
# NCT00106106:	['20921123']
# NCT00504309:	['23592752', '22865498', '21159789']
# NCT00962949:	['22247480']
# NCT01522651:	['26226999']
# NCT00805935:	['25385669']
# NCT01900561:	['30925126']
# NCT03583450:	['32618627']
# NCT00891293:	['19597368']
# NCT01440101:	['28104251']
# NCT03071263:	['31533906']
# NCT00809965:	['31535314', '29976285', '25318481', '23602776', '23500262', '22077192', '21570509']
# NCT03190369:	['33964907']
# NCT00095303:	['25462653', '23795871']
# NCT01721200:	['26195173']
# NCT02159079:	['30630380']
# NCT02260921:	['28336454']
# NCT01545076:	['30672091', '29122523']
# NCT02286895:	['29659924']
# NCT01013844:	['24418949']
# NCT01327547:	['27924779', '25923596']
# NCT01010204:	['25006684']
# NCT00320788:	['32374423']
# NCT00116207:	['23740194']
# NCT01952301:	['24597764']
# NCT02965456:	['32886337']
# NCT02065557:	['34153231']
# NCT00474058:	['24602411', '24457253', '21790503', '21322021']
# NCT02161458:	['32913021']
# NCT01143896:	['27364808']
# NCT01261611:	['30168896', '27653448']
# NCT00768287:	['22764744']
# NCT01127061:	['28306757']
# NCT03387683:	['30618324']
# NCT00845728:	['24461613']
# NCT00753935:	['22311905']
# NCT02309138:	['34259458']
# NCT00036270:	['29885375', '21247627']
# NCT00113269:	['21591943']
# NCT00350727:	['23054212']
# NCT01588457:	['34523118']
# NCT00369577:	['21294997']
# NCT01205503:	['25909710']
# NCT02269943:	['29764853']
# NCT01010282:	['25659956']
# NCT01357720:	['24176498']
# NCT00108862:	['25582793', '22010914']
# NCT03238911:	['32016310']
# NCT01490580:	['33301785', '29715354']
# NCT00124449:	['19933744']
# NCT01458951:	['33127596', '32816215', '30476584', '29850873', '29028981', '28467869']
# NCT01272921:	['24108248']
# NCT00997984:	['26547425']
# NCT02324920:	['33279955']
# NCT00886834:	['22825094', '21527040']
# NCT01870778:	['33189635', '31433919', '28452195']
# NCT02652390:	['34677593']
# NCT01346839:	['26304875']
# NCT00328016:	['20200548']
# NCT01402141:	['22136279']
# NCT01863186:	['32002194', '31606589', '30531234']
# NCT00643123:	['22420596']
# NCT01152359:	['27133551', '26075751', '25149197']
# NCT00334282:	['26685869', '25227656', '23321547']
# NCT00760435:	['24572997', '23901839']
# NCT00421928:	['26535967', '24916058', '24353047']
# NCT00266825:	['31004139', '30392575', '30311214', '29381793', '27884184', '27362506', '27637340', '27499448', '23803884', '23426033']
# NCT03509350:	['33620405', '31801567', '30953543']
# NCT00106028:	['23927913']
# NCT00836693:	['22790642', '21707928']
# NCT01700530:	['23583255']
# NCT02463487:	['32139102']
# NCT01467466:	['29130810']
# NCT00377260:	['21226576']
# NCT03010631:	['33834354']
# NCT00683020:	['26102298']
# NCT00140205:	['21917874', '21660636']
# NCT02254421:	['31915807']
# NCT00705939:	['27174694']
# NCT02159053:	['33722947']
# NCT00295061:	['20920295']
# NCT03320941:	['32072763']
# NCT00328042:	['27206463', '20529203']
# NCT02432209:	['35041662']
# NCT00539279:	['32216149', '30978622']
# NCT02565186:	['34366152', '33784930', '33730977', '32093628', '31433669']
# NCT01675882:	['29136445']
# NCT00266864:	['21717386']
# NCT02876887:	['32078436']
# NCT01578577:	['29987324', '24157649']
# NCT02282293:	['30530597', '28329368']
# NCT02708121:	['31586443']
# NCT03163446:	['32271718']
# NCT01764854:	['27340281']
# NCT00537303:	['21550957']
# NCT01234402:	['28220020']
# NCT02007434:	['27787269']
# NCT02831855:	['34103405']
# NCT00322153:	['29771687', '23733403']
# NCT03162055:	['31267366']
# NCT00742170:	['19574017']
# NCT01790490:	['24035344']
# NCT01278953:	['26260733']
# NCT01995487:	['28794001']
# NCT01767909:	['34101779', '32568367']
# NCT02193776:	['31732485']
# NCT03525548:	['31679946']
# NCT00843622:	['21994343']
# NCT01814787:	['28192551']
# NCT00980148:	['26699167']
# NCT01218243:	['23593139']
# NCT01606761:	['28215362']
# NCT01506609:	['29045554', '27739325']
# NCT03882970:	['34370970']
# NCT00509223:	['26926656']
# NCT01251380:	['31691605', '28914131']
# NCT01384734:	['27922453', '26423650']
# NCT01441180:	['24983321', '23982366']
# NCT01295320:	['26432913']
# NCT03016325:	['33248986', '30703258']
# NCT01699789:	['27629796', '25402400']
# NCT02906358:	['29299814']
# NCT01325181:	['21742303']
# NCT02637557:	['32092310']
# NCT01159535:	['31304887', '24647726']
# NCT02345889:	['29530353']
# NCT03241030:	['33867179']
# NCT00631449:	['21402547']
# NCT00667381:	['20650437']
# NCT03102736:	['33522376']
# NCT01375764:	['23128163']
# NCT01958476:	['31987653', '29913015']
# NCT00969878:	['24793366']
# NCT01983228:	['28086853']
# NCT01826981:	['26261007']
# NCT01085812:	['24653937']
# NCT01097694:	['28514613']
# NCT00047385:	['30821827', '28069970', '27009070', '27006427', '25928649', '25746779', '25372087', '25199624', '24004119', '23697514', '21714641', '21045183']
# NCT03354325:	['32675334', '32628250']
# NCT01330459:	['23090523']
# NCT01123941:	['21980445']
# NCT02310646:	['28796913']
# NCT00985725:	['24309905']
# NCT02378844:	['31522546']
# NCT01625416:	['29087256', '26467327']
# NCT02577042:	['32941476', '27999056']
# NCT01423604:	['26351344']
# NCT04418947:	['34190999']
# NCT02063087:	['30646167']
# NCT01838551:	['31542384']
# NCT03274453:	['30113350']
# NCT00367835:	['20806988']
# NCT00753922:	['25158767']
# NCT02713594:	['29079405']
# NCT03742154:	['33249458']
# NCT02224755:	['32340871', '32276809', '31939996', '30883052', '30586698', '30245150', '29807933', '29526139', '29154131', '29153637', '28385948', '27959709']
# NCT01142726:	['31819995', '31278695', '30341453', '26865601', '25367713']
# NCT01855399:	['34750128']
# NCT03015220:	['33460016', '32333876']
# NCT02714595:	['33393598', '33058795']
# NCT00494780:	['22409295']
# NCT00829244:	['25596910']
# NCT03123471:	['32032692']
# NCT00088699:	['33074143', '32929215', '31928949', '30826253', '30094160', '29580569', '27929610', '27718369', '27233466', '25451430', '25400146', '25295436', '22297150', '20679587', '19744406', '18996507', '16894061']
# NCT02917603:	['32787506']
# NCT02877680:	['32379496', '29535081']
# NCT01523392:	['26152562']
# NCT01260272:	['24393750']
# NCT02291445:	['30284674']
# NCT00453154:	['25732163']
# NCT00553358:	['29902299', '26181252', '25851628', '25130998', '22257673']
# NCT00960661:	['25011946']
# NCT01957202:	['25900517']
# NCT00262847:	['31216226', '29550184', '26487588', '23219660', '22204724']
# NCT01527383:	['29126292']
# NCT00542789:	['22591121']
# NCT01231373:	['26992303']
# NCT03218397:	['32374822']
# NCT00704912:	['33059886', '32968804', '27253669', '27172435', '26401593']
# NCT02251717:	['27842383']
# NCT01743001:	['30586694']
# NCT00297492:	['20537810']
# NCT02239536:	['32989532']
# NCT00884897:	['26879587', '23415472']
# NCT00907088:	['20624802']
# NCT01628692:	['26453968']
# NCT01462812:	['25355310']
# NCT02611752:	['28655025']
# NCT00980174:	['25607608', '22723310']
# NCT02607865:	['30903796']
# NCT03086330:	['30833170']
# NCT04238650:	['34269848']
# NCT00417989:	['25175313', '20587585']
# NCT01434121:	['24484547']
# NCT02638103:	['33009665', '32913018']
# NCT00440115:	['22770436', '19349629']
# NCT02787551:	['31530665']
# NCT00127205:	['32929540']
# NCT02805907:	['33154023']
# NCT01829191:	['30994197']
# NCT02579382:	['29851204']
# NCT00541229:	['19691426']
# NCT03024606:	['29857773']
# NCT00741013:	['19574441']
# NCT00108524:	['20101008']
# NCT00760838:	['23291349']
# NCT00642707:	['20377413']
# NCT03568942:	['34130619']
# NCT02812160:	['34793746']
# NCT01154036:	['25985907', '24063830']
# NCT00357656:	['33772963']
# NCT03292809:	['34481407']
# NCT02584855:	['31964419']
# NCT00987389:	['32053298', '23497590']
# NCT02813694:	['33964925']
# NCT01808339:	['26823210']
# NCT01138969:	['21144850']
# NCT02545868:	['32727835']
# NCT03191630:	['32912051']
# NCT03474081:	['34035312']
# NCT01955044:	['27356083']
# NCT01535053:	['32460997']
# NCT00510510:	['20416390']
# NCT00461292:	['22965657', '21798658']
# NCT00389064:	['23070803']
# NCT02029976:	['33601934', '30342255']
# NCT00536198:	['26351969']
# NCT00598442:	['23343062', '23343061']
# NCT02152371:	['29430801', '29110972']
# NCT00780026:	['31901245']
# NCT02355210:	['29954454']
# NCT01398176:	['25866155']
# NCT00660179:	['31109190', '29501590', '29447737', '27671974', '26493786', '25457902', '23984728']
# NCT00844857:	['25721187']
# NCT02760056:	['32120028']
# NCT01604109:	['22805294']
# NCT03350217:	['31288028']
# NCT03058679:	['34052278']
# NCT00750737:	['22814329']
# NCT01627561:	['31469776', '29424799']
# NCT00233402:	['20850152']
# NCT02709538:	['31248471']
# NCT02166476:	['29486041']
# NCT02735382:	['31089727']
# NCT01789203:	['30811872']
# NCT01068158:	['23113480']
# NCT00724126:	['21208106']
# NCT01464619:	['28733799']
# NCT01229228:	['24127200']
# NCT00957996:	['23985625']
# NCT00411671:	['22586319']
# NCT01851330:	['27553375', '24720702']
# NCT01443130:	['30195996']
# NCT04814459:	['34598692']
# NCT00580840:	['25302624']
# NCT01159262:	['24238862']
# NCT00624013:	['19729522']
# NCT00375973:	['25660434']
# NCT02559206:	['33065589']
# NCT03242018:	['34338408']
# NCT02046369:	['29173735']
# NCT03029819:	['31237242']
# NCT02067039:	['34406551', '31738378']
# NCT01085760:	['23384404']
# NCT02688621:	['32446752']
# NCT00787891:	['23863328']
# NCT01346475:	['22225814']
# NCT00259610:	['27483410', '27188329', '22730343', '22508468']
# NCT00852995:	['22863328']
# NCT01854632:	['27746224']
# NCT00641056:	['24731672', '23748506', '23522121', '20609969']
# NCT01020019:	['29457671']
# NCT02185794:	['29063860']
# NCT03480763:	['34489128']
# NCT01898689:	['25248648']
# NCT01618305:	['32386720']
# NCT00500331:	['25223369']
# NCT02923245:	['29980460']
# NCT00094770:	['21477878', '20456211']
# NCT02536833:	['32432388']
# NCT02197065:	['29398998']
# NCT02319317:	['29701615']
# NCT00919711:	['31776637']
# NCT02322892:	['27044557']
# NCT00381485:	['20687982']
# NCT01583985:	['31529104', '29509867', '28893675']
# NCT00477490:	['27862898', '25172115']
# NCT02677766:	['30250407']
# NCT03538678:	['30808389']
# NCT00846365:	['29334491']
# NCT02638207:	['35038723']
# NCT00880893:	['23839107', '22894958']
# NCT01244061:	['24911368']
# NCT02767011:	['29169546']
# NCT00600106:	['20569710']
# NCT00713830:	['27267268', '24650952']
# NCT01485770:	['26298786']
# NCT00468910:	['26503631']
# NCT03005288:	['33439265']
# NCT00765648:	['25141250', '21707983']
# NCT02105987:	['28401876']
# NCT00500149:	['21156071', '19508731']
# NCT00680017:	['23891363']
# NCT01638013:	['32164762']
# NCT00632619:	['26903253']
# NCT02850965:	['33317345']
# NCT01287065:	['24200619']
# NCT01109004:	['30653422']
# NCT01990768:	['32897344']
# NCT01994993:	['33902072']
# NCT02585960:	['33150384']
# NCT01826851:	['30170012']
# NCT02991859:	['32484940']
# NCT03329690:	['32469182']
# NCT01452412:	['31699517']
# NCT01898442:	['26404199']
# NCT01901289:	['33025243']
# NCT02976103:	['31612292']
# NCT03040414:	['33453783']
# NCT00903032:	['24247275']
# NCT02147613:	['25190739']
# NCT01026454:	['21998479']
# NCT00149799:	['31505519']
# NCT00676403:	['20466589']
# NCT00955201:	['30804739']
# NCT00307333:	['34798080', '34247026', '29703576', '24412138', '21864846']
# NCT02215200:	['30967424', '30012675']
# NCT00088218:	['18565853']
# NCT01098266:	['29753703']
# NCT02174861:	['34928306', '32216456', '31707815', '31159727']
# NCT01895777:	['33290737']
# NCT02656173:	['33245533']
# NCT00249873:	['20979470', '19336502']
# NCT02001194:	['26976287']
# NCT00688519:	['22587791']
# NCT01962922:	['29162334']
# NCT01432405:	['21956711']
# NCT02234284:	['31937527', '30791871', '30130430', '28599636']
# NCT00668434:	['25988461']
# NCT01140347:	['33531690', '33188713', '32817068', '32107609', '30665869', '28950290', '28591675', '27549242', '26095784']
# NCT00677014:	['34706949', '30476543']
# NCT02953821:	['34478124', '33687687', '32996096']
# NCT00812955:	['20524719']
# NCT01381172:	['29754812', '25285748']
# NCT00177294:	['20957693']
# NCT01821352:	['27935737']
# NCT00419770:	['21937481']
# NCT01754350:	['34487222', '32619561']
# NCT03092219:	['34608092']
# NCT00791778:	['23591401']
# NCT00347919:	['23283526', '23054212']
# NCT01806506:	['28767558']
# NCT03306043:	['34389506']
# NCT00365378:	['22277329']
# NCT02548078:	['32199492']
# NCT00996840:	['28004376', '26102252']
# NCT01808092:	['34374952', '32349879', '32071051', '29912399', '29254862']
# NCT00218426:	['27436632']
# NCT01677910:	['32146619', '30477789', '29724499']
# NCT00324038:	['21477658']
# NCT00740584:	['21935377']
# NCT01839487:	['33478521', '29232172']
# NCT00516321:	['26173631', '24126097']
# NCT02437487:	['32255488']
# NCT01168687:	['22367657']
# NCT00494975:	['21668425']
# NCT00597207:	['27155547', '25461493', '24642406', '21196070']
# NCT00632229:	['23842022']
# NCT01797575:	['30549489']
# NCT01231620:	['28094141']
# NCT01540773:	['30893070']
# NCT00662909:	['24246044']
# NCT00373685:	['23399552']
# NCT02646891:	['32251641']
# NCT00947544:	['22961727']
# NCT01215253:	['30071993']
# NCT01193244:	['25701170']
# NCT02696850:	['29879268']
# NCT01161563:	['24354113']
# NCT01691482:	['27621609', '25197005']
# NCT01641159:	['24911028']
# NCT02133742:	['32816890']
# NCT03180138:	['29540571']
# NCT00919100:	['22134226']
# NCT00057681:	['26598476', '26598475', '22917200', '22213771', '17335331']
# NCT01393158:	['22508772']
# NCT00134056:	['24616308', '24565955', '23871417']
# NCT00553475:	['30206821', '27448285', '27611736']
# NCT02006160:	['30566030']
# NCT00321464:	['32474744', '26335402', '25976743', '23975226', '21060033']
# NCT02742103:	['30580130']
# NCT00805532:	['31337325']
# NCT00818454:	['27130202']
# NCT02259400:	['25667244']
# NCT00389493:	['26613263', '25375780', '24026523', '23945445']
# NCT02256345:	['27927683']
# NCT03000075:	['31667790', '31237727']
# NCT02435992:	['35006163', '34587385']
# NCT00097591:	['32164882', '24947719', '24140678', '22633653', '22199016', '21606391', '19699846', '19249633', '18757948', '18498956', '18377975', '17982182']
# NCT01670825:	['26447705']
# NCT01755091:	['29121334']
# NCT01081145:	['26871297']
# NCT00765817:	['24621255', '23043166', '22913891', '22432107', '21138825']
# NCT01302067:	['24552358']
# NCT01949090:	['28302407']
# NCT03289676:	['31977840', '31863582']
# NCT00256750:	['26816011', '24831918', '21992533']
# NCT00411645:	['21414843']
# NCT02970305:	['34861170']
# NCT02236598:	['32556595', '29092881']
# NCT01494506:	['33214082', '31856081', '31789476', '30842038', '30654298', '30458340', '30414528', '26615328']
# NCT02942004:	['32666402', '30177236']
# NCT01128361:	['28187125']
# NCT02174276:	['30930022']
# NCT00257660:	['34888518', '25324317']
# NCT00708162:	['22015077']
# NCT00590707:	['30857604', '30090923', '20042557']
# NCT00100698:	['18677023']
# NCT00655629:	['20456213']
# NCT00691483:	['24074849', '22080588']
# NCT02630992:	['28438923']
# NCT01871805:	['31706099']
# NCT02621931:	['34819017', '33413075', '33009665', '32958075', '32747522', '31675102', '29171818']
# NCT00271102:	['23508540']
# NCT00339183:	['26341920', '22070868']
# NCT00620282:	['25212693']
# NCT01394159:	['22658389']
# NCT01444027:	['30946495', '27048707', '26484426', '25547480']
# NCT00353418:	['22592094']
# NCT00263757:	['30522886']
# NCT02388568:	['30304382', '29676530', '29288545', '28600158', '28124502']
# NCT02210780:	['30092324']
# NCT02391337:	['33351042', '28729311']
# NCT00717236:	['26614481', '26568428', '22923753']
# NCT02459080:	['32393215']
# NCT02980692:	['33985942']
# NCT00955110:	['21102969']
# NCT00961805:	['23020850']
# NCT04036292:	['34767866']
# NCT02896400:	['29287665']
# NCT04497415:	['35045900']
# NCT01168401:	['28249841', '25803642', '24951828']
# NCT01357551:	['28853051', '28241185', '25117805']
# NCT01862419:	['25726515', '25023200']
# NCT01136382:	['26460293']
# NCT00827242:	['26299520', '21871706']
# NCT00528606:	['21967070', '19726771']
# NCT02198040:	['30176883']
# NCT02091284:	['30018558']
# NCT02526290:	['30472141']
# NCT02826694:	['29950170']
# NCT03141242:	['32726475']
# NCT00921557:	['31573608']
# NCT02432456:	['30376537']
# NCT02943460:	['30661255']
# NCT02883452:	['33676969']
# NCT03101241:	['31244760']
# NCT01431391:	['27836866']
# NCT00067470:	['33874971']
# NCT02435511:	['30789775']
# NCT00461097:	['26924470', '22808958']
# NCT04350307:	['32883241']
# NCT03738332:	['34387119']
# NCT03194334:	['31593541', '29569535']
# NCT00488033:	['25402757', '24754493']
# NCT00004031:	['24625415', '24171516']
# NCT01378858:	['32857445', '24928218']
# NCT00382720:	['25416687']
# NCT00246090:	['24682463']
# NCT01717742:	['32011642']
# NCT00252720:	['21309844', '21225239', '19451554', '18823656']
# NCT01556165:	['30534374']
# NCT02697916:	['33999548', '32186653']
# NCT01647945:	['28893866']
# NCT02037438:	['25409112']
# NCT02688387:	['31060740']
# NCT02420821:	['32127394', '31079938']
# NCT01410357:	['30160510', '29280685']
# NCT02193828:	['28854973']
# NCT01130103:	['21908494']
# NCT00128713:	['28679741', '22538854', '22496156', '20164484']
# NCT02800642:	['33556381']
# NCT01636661:	['25413621']
# NCT02655354:	['34225296', '33688908']
# NCT01336205:	['25112584']
# NCT01479270:	['22840413']
# NCT00397631:	['22405352']
# NCT02155829:	['33113596']
# NCT03185065:	['33242419', '29113955']
# NCT04098497:	['32965227']
# NCT00413231:	['28366302']
# NCT01334918:	['24314823']
# NCT02641249:	['27304988']
# NCT01771809:	['33599720']
# NCT03511937:	['31586510']
# NCT02100124:	['26002807']
# NCT01594333:	['34144603', '32741143', '32221587', '32066146', '30415610', '23895801']
# NCT01431105:	['27923814']
# NCT00321789:	['23146744', '20599337']
# NCT00985088:	['22315336']
# NCT01383174:	['34998436', '33937611', '25905829', '24577971']
# NCT02109562:	['34551218']
# NCT01540838:	['32246138']
# NCT03205488:	['33315105']
# NCT02888171:	['32694162']
# NCT00678301:	['24633268', '22112189']
# NCT02151643:	['32651955']
# NCT01966978:	['31803482']
# NCT00886639:	['27940278']
# NCT01203852:	['28115488']
# NCT02094586:	['29317118']
# NCT02366091:	['34722661']
# NCT00943111:	['28167660', '25819691']
# NCT00126776:	['20075385']
# NCT00460603:	['24423921', '23605883']
# NCT01592695:	['27535024']
# NCT01610414:	['34406911', '31394276', '31287523']
# NCT00772590:	['21930607']
# NCT01254422:	['24135573']
# NCT00835731:	['23743471']
# NCT01278927:	['26439325']
# NCT02635035:	['34232582']
# NCT03022396:	['28963118']
# NCT02222337:	['25377349']
# NCT01191255:	['26239948']
# NCT00019682:	['21631324']
# NCT01151579:	['21960699']
# NCT02360475:	['29401325']
# NCT02631876:	['33667670', '29424243']
# NCT02077374:	['30430605']
# NCT01501162:	['26302024']
# NCT02280044:	['29145631']
# NCT00403767:	['32323192', '30219887', '29898836', '28615214', '28477860', '27358435', '26955859', '26888572', '26673560', '26386791', '25736441', '24668660', '24552831', '24315894', '23778903', '23723250', '23525418', '23500298', '23212720', '22402056']
# NCT02440594:	['26558530']
# NCT02293499:	['34874404']
# NCT00551031:	['24120672']
# NCT01497366:	['25040192', '23607594']
# NCT02903511:	['34391872']
# NCT02504424:	['31881599']
# NCT00313781:	['24536060']
# NCT00848211:	['22336878']
# NCT00244101:	['22025591']
# NCT01615263:	['27138896']
# NCT02435433:	['33531690', '33188713', '32817068', '32107609', '30665869']
# NCT03789292:	['33546755']
# NCT01452529:	['28794653', '26111544']
# NCT00486863:	['33861768', '31188820', '29546300', '26511959']
# NCT00896064:	['24607003']
# NCT03356145:	['34352829']
# NCT02321098:	['26867498']
# NCT02959853:	['32499757']
# NCT01033851:	['28314552', '23541163']
# NCT02750306:	['31944580']
# NCT02291549:	['29350840']
# NCT02952872:	['31436446']
# NCT00435812:	['29628151']
# NCT01653288:	['26089554']
# NCT01786993:	['29759832']
# NCT01687218:	['27986684']
# NCT01171989:	['23838777']
# NCT01757184:	['34774639', '26352813', '24993530']
# NCT01650844:	['29309483']
# NCT01553084:	['32800078', '31056710', '26813210']
# NCT02105324:	['26850709']
# NCT02066129:	['29504498']
# NCT00079001:	['33270906', '24590644']
# NCT00991276:	['24899755']
# NCT02908100:	['34042314']
# NCT01105247:	['31196847', '25724156', '25381051']
# NCT01188564:	['25680925']
# NCT00626925:	['26891181', '24786948']
# NCT01925469:	['24745839']
# NCT00408200:	['21076158', '19738139']
# NCT03613649:	['34606332']
# NCT02486627:	['30786187']
# NCT02493751:	['33947608']
# NCT02224703:	['34406656', '32119035', '30582156']
# NCT02956616:	['31669738']
# NCT01265498:	['31965579', '31634532', '30253043', '29333665', '25468160']
# NCT00683618:	['28836458']
# NCT01732536:	['26992115', '25266981']
# NCT00122954:	['26799942']
# NCT01629862:	['31922899']
# NCT00760513:	['28294174', '27106721', '26748347', '26272871', '26021488', '24556343']
# NCT02385799:	['31780970']
# NCT02268214:	['32946821', '30756462', '30352894', '28919061']
# NCT03571256:	['34661664']
# NCT01630200:	['32725799']
# NCT00955682:	['26780033']
# NCT00682643:	['23806459']
# NCT02915302:	['30395011']
# NCT01523301:	['27322571']
# NCT00960505:	['30297199', '29258678', '28459931']
# NCT01445548:	['25525171']
# NCT00160641:	['29246162', '26353833']
# NCT00603382:	['26704701', '22342538']
# NCT00180271:	['32701367', '32605387', '30857452', '30466845', '29861050', '28347835', '28003221', '27634117', '26961303', '26796396', '26724489', '26508711', '26216033', '26179186', '26173635', '26124205', '26071234', '25817576', '25438913', '25431345']
# NCT01128179:	['24885942']
# NCT03670810:	['34742230', '33541117']
# NCT02856802:	['30877622', '29878341']
# NCT03627416:	['31214256']
# NCT01544153:	['29878062', '27283295', '25542911']
# NCT01193257:	['25624429']
# NCT04123665:	['32216778']
# NCT02968368:	['34029682']
# NCT01426438:	['30535188', '25979307']
# NCT01774097:	['28209728']
# NCT00519779:	['21784145']
# NCT02036294:	['31593271', '30419103']
# NCT02116361:	['31609787']
# NCT00540514:	['23545279']
# NCT01461096:	['29659751']
# NCT02308540:	['31843266']
# NCT02766023:	['32402161']
# NCT02030002:	['30384932', '30230375']
# NCT01207934:	['21411512']
# NCT00617097:	['19935022']
# NCT02133781:	['28963118']
# NCT02786537:	['34255381']
# NCT00908037:	['26688484']
# NCT01280266:	['24352340']
# NCT01922050:	['28264612']
# NCT00620464:	['22540269']
# NCT01285323:	['31626990', '31262379', '30964365', '30193936', '25736990']
# NCT02162719:	['34264439', '28800861']
# NCT03656744:	['34535644']
# NCT02395172:	['33636453', '30262187']
# NCT01973335:	['31074184']
# NCT01910519:	['34174187']
# NCT03076190:	['31087093']
# NCT02924883:	['33002436']
# NCT03535844:	['33964853']
# NCT03549117:	['31209698']
# NCT01614249:	['30534187']
# NCT02066298:	['31112384', '30593883']
# NCT00991341:	['25853746', '22531338', '20655807']
# NCT02925494:	['32459423']
# NCT02516332:	['34406354', '27264220']
# NCT03484429:	['34761694']
# NCT01641367:	['31528850']
# NCT00056407:	['32856605', '28396999', '27378134', '26184556', '26165588', '23587564', '23541458', '22658758', '21849186', '21074214', '20357281']
# NCT00460434:	['22716974']
# NCT02026141:	['26830642']
# NCT03237845:	['31291516']
# NCT03408639:	['30253403']
# NCT03347279:	['33979488', '33087119', '33050934', '33050928']
# NCT00396877:	['23782178']
# NCT01361308:	['25137243', '24552977', '24045678']
# NCT01449929:	['26424673', '24698485']
# NCT00708552:	['29854923']
# NCT02270255:	['29989515']
# NCT00887978:	['23669822']
# NCT01148862:	['22316089']
# NCT02630953:	['34379236']
# NCT02165735:	['31240605', '26474979']
# NCT03165981:	['32029684']
# NCT00131378:	['29679919', '28628810', '26663235', '24508386', '23146135', '22275471']
# NCT01619423:	['29140155']
# NCT02433340:	['30376130', '30032191']
# NCT00949884:	['22763801']
# NCT02994238:	['33386336']
# NCT00059332:	['31955642', '30039165', '27679533', '26658446', '25651247']
# NCT01642251:	['32860331']
# NCT02004977:	['30772298']
# NCT01443845:	['29763572', '27585384']
# NCT02503540:	['31757691']
# NCT02987972:	['32639460']
# NCT02033499:	['28600913', '28545493']
# NCT00839332:	['28202004']
# NCT04205669:	['32589632']
# NCT00687193:	['32816215', '26275429', '25496464']
# NCT01865747:	['34736367', '34364385', '31887537', '29576624', '29377755', '27279544', '26406150']
# NCT03285477:	['33567191']
# NCT01106859:	['24587571']
# NCT02712424:	['33004239']
# NCT01542788:	['25040192', '23607593']
# NCT02013388:	['28209466']
# NCT00755235:	['21384219']
# NCT02513940:	['33020898']
# NCT02869438:	['32110060']
# NCT00906204:	['26696251']
# NCT00555425:	['25330017']
# NCT02123329:	['28219367']
# NCT02016898:	['29189540']
# NCT00519285:	['30341029', '25515657', '23742877']
# NCT00652327:	['22621316']
# NCT01483599:	['26154787']
# NCT03589885:	['34954841']
# NCT01229735:	['31195326']
# NCT01089231:	['22929118']
# NCT01149369:	['29111115']
# NCT00195624:	['22067384']
# NCT00784277:	['21494892']
# NCT00148798:	['22056021', '21169060', '19410716']
# NCT01228747:	['30525116']
# NCT02433496:	['29370813']
# NCT02990000:	['34110861', '34106240']
# NCT00536809:	['21609937']
# NCT00790335:	['31843251', '31592728', '31354089', '30699446', '29211671', '23537968', '20047905']
# NCT02029989:	['34000112', '25667811']
# NCT02332863:	['31042578']
# NCT03909009:	['32701637']
# NCT01647581:	['31158369']
# NCT00506883:	['20131255']
# NCT02730988:	['30624598']
# NCT00497146:	['23194491', '22337679', '21242674']
# NCT03401190:	['33939666']
# NCT00277394:	['21477846']
# NCT03028220:	['31375042', '29230878']
# NCT01423812:	['25881614']
# NCT00384930:	['26299520', '20163842', '19409693', '18722631']
# NCT02816736:	['34730769', '32641226']
# NCT03296527:	['34179971']
# NCT01453998:	['28340322']
# NCT02295995:	['29632895']
# NCT02377921:	['33874971', '32063397']
# NCT00031486:	['25956891']
# NCT00509873:	['25244402']
# NCT00649389:	['23110471', '22799613', '20678674', '19751459']
# NCT00179621:	['21753188']
# NCT00687076:	['24267254', '21227624']
# NCT02294630:	['33338661']
# NCT01730534:	['33851953', '33653824', '32795086', '31843945', '31196815', '30882239', '30882238', '30415602', '29898853']
# NCT01073020:	['34845204', '29432125', '27555097', '25909333', '24899464']
# NCT00146770:	['33874971', '19117887']
# NCT00557245:	['27029778', '25531343', '25300863', '25038355', '24979446', '22784037', '21998703']
# NCT00896038:	['25409596']
# NCT00886379:	['21697075']
# NCT01729156:	['30976851']
# NCT03818815:	['34851411']
# NCT00321971:	['24119856']
# NCT00504829:	['20110022']
# NCT02856555:	['30059671']
# NCT01035047:	['23664718']
# NCT02647203:	['31176788']
# NCT02472223:	['33973917']
# NCT00953524:	['20018365']
# NCT01465763:	['33127596', '32816215', '30476584', '29850873', '29028981', '28467869']
# NCT01465022:	['22143258']
# NCT02775617:	['29985978']
# NCT01303172:	['27599039']
# NCT01969240:	['27919865']
# NCT00570089:	['21565740']
# NCT00883103:	['19701033']
# NCT00870363:	['29788075', '28968888']
# NCT01132690:	['25453586']
# NCT00790023:	['21130386']
# NCT02181296:	['28025374']
# NCT02344004:	['33887244', '33595792', '30216086']
# NCT00822172:	['22615190']
# NCT02627963:	['33980467', '31810797']
# NCT00619099:	['23733767']
# NCT01372748:	['26550795', '25728722']
# NCT00659789:	['24525316']
# NCT02516202:	['33675793', '30994576', '29738424', '29554173']
# NCT02944513:	['30636101']
# NCT00703326:	['28950290', '28520849', '25185099']
# NCT01881776:	['24257398']
# NCT00703846:	['23377341']
# NCT00847132:	['22325974', '22210240', '21386067']
# NCT01315236:	['33595792', '27748623']
# NCT00088530:	['22652183']
# NCT01642212:	['32272243', '30502508', '29902649', '27889574']
# NCT02008396:	['30196397', '25818246']
# NCT01436201:	['28357715']
# NCT02462148:	['29753264']
# NCT01944930:	['26194251']
# NCT02096861:	['30929895']
# NCT00280059:	['21889410']
# NCT01427309:	['27669017', '26762363', '25119609']
# NCT01972529:	['32047671', '29778606']
# NCT02725411:	['34786956']
# NCT00682539:	['33206392']
# NCT00604812:	['22289113']
# NCT01619059:	['29802530', '26324329']
# NCT01170663:	['33355909', '31234645', '30557792', '28950290', '28716815', '26747859', '26510663', '25240821']
# NCT01500213:	['26272769']
# NCT01900392:	['31675083']
# NCT01819311:	['30877049']
# NCT02466958:	['33757609']
# NCT02367833:	['32612574']
# NCT00107120:	['19465881']
# NCT02260388:	['32809014']
# NCT01836445:	['29937115']
# NCT02066389:	['31194885', '27390150']
# NCT02618187:	['32763240']
# NCT00439738:	['22248871', '20498618']
# NCT02290873:	['29723512']
# NCT03687827:	['34322967']
# NCT00264147:	['25886874']
# NCT02598128:	['28471913']
# NCT00492752:	['28687477', '19095497']
# NCT00562627:	['20736233']
# NCT00974974:	['23485610']
# NCT01435512:	['28726440', '26613288']
# NCT02047929:	['25359128']
# NCT00279201:	['25881510', '24092662', '21270182', '20685497', '19929994', '19336625']
# NCT00324155:	['25713437', '21639810']
# NCT02729025:	['32393252']
# NCT00938782:	['21830049']
# NCT02530281:	['32147881', '31111409', '30451318', '30378087']
# NCT02670915:	['31076415']
# NCT01214421:	['31014270']
# NCT01221597:	['26199168']
# NCT01412060:	['34091867', '30695290', '27427558']
# NCT02469246:	['29475804']
# NCT00727857:	['21122063', '19827910']
# NCT01550731:	['29940209', '28520838']
# NCT00518180:	['20189491']
# NCT02721966:	['33334727']
# NCT02156154:	['32721009']
# NCT01294592:	['25565364']
# NCT02022007:	['28228317']
# NCT00530894:	['30442284', '29217004', '28973520', '27601428', '27437665', '26903039', '26733582', '26264371', '26261157', '26242213', '26238287', '26058718', '25963221', '25832034', '25788234', '25788231', '25700756', '25586156', '25524339', '25459036']
# NCT02383589:	['34097368']
# NCT01135381:	['27339715', '22922245']
# NCT02443883:	['29721850']
# NCT01733329:	['26534874']
# NCT00596011:	['25873370']
# NCT01950013:	['30575602']
# NCT00799643:	['24130358', '23817699']
# NCT00128180:	['23784924']
# NCT00619970:	['21240023']
# NCT03286751:	['32900535']
# NCT04032327:	['34473963']
# NCT02100631:	['30772070']
# NCT01419236:	['26158605']
# NCT03077438:	['32852352']
# NCT00727025:	['20048611']
# NCT01014624:	['22698488']
# NCT00547378:	['24415559']
# NCT01125202:	['26868602']
# NCT00535236:	['23908479']
# NCT01479543:	['26016655', '24205115']
# NCT00956839:	['23564348']
# NCT00771030:	['24286136']
# NCT00474045:	['21557440']
# NCT01416805:	['26366886']
# NCT01650558:	['33744963']
# NCT00368940:	['31582195', '28223082', '25372657']
# NCT01049412:	['26278063', '23193209']
# NCT03285490:	['33567191']
# NCT01832402:	['27401508']
# NCT01946282:	['31085338']
# NCT01322386:	['32633158']
# NCT02887183:	['29754651']
# NCT00968539:	['28446441']
# NCT01143701:	['27462065']
# NCT01994395:	['30568009', '26289955']
# NCT02536313:	['28220512']
# NCT01354145:	['28728606', '27809891']
# NCT02656693:	['33141209', '32428586']
# NCT00913835:	['30591028']
# NCT00166296:	['21034680']
# NCT02858492:	['33726834']
# NCT00411411:	['25243647']
# NCT02016170:	['27013060']
# NCT00714168:	['29633583', '22735431']
# NCT02157376:	['29638148']
# NCT01777295:	['30850240']
# NCT01364649:	['31010445', '28663124']
# NCT01332019:	['25073663']
# NCT01799226:	['26820239']
# NCT00916006:	['22417254']
# NCT02129777:	['30207587']
# NCT01646320:	['29802530', '26246458']
# NCT02481596:	['32706852', '29636319']
# NCT01909791:	['32077907', '31037289']
# NCT03090100:	['31402114']
# NCT02951429:	['32822614']
# NCT01225250:	['26501937']
# NCT01857310:	['34656303', '31910279']
# NCT00459316:	['22622049']
# NCT01617421:	['23548052']
# NCT02285998:	['28636855']
# NCT00048568:	['24786925', '18383390', '16785475']
# NCT01019135:	['26682921']
# NCT02615743:	['28347975']
# NCT01603082:	['26868683']
# NCT00625391:	['23118932', '21766228', '21143878', '19732445']
# NCT01814072:	['32656994']
# NCT04328467:	['33204764', '33068425']
# NCT02948959:	['34879449']
# NCT00941031:	['24393602']
# NCT00223795:	['24933725']
# NCT00584948:	['24345444']
# NCT00388674:	['31306800']
# NCT01143870:	['24567202']
# NCT03392168:	['32845114']
# NCT00774345:	['28958469']
# NCT03530098:	['34581608']
# NCT01720446:	['32744418', '32643857', '32372454', '32227613', '31769496', '27633186']
# NCT02518139:	['32343967', '31666076', '31150963']
# NCT00402363:	['21078810', '19619690']
# NCT01091662:	['25880756']
# NCT01274182:	['28637670']
# NCT01153009:	['31818787', '25575488']
# NCT00915538:	['23176189']
# NCT00082407:	['22913891']
# NCT01342913:	['24114969']
# NCT01920152:	['33786329']
# NCT00353496:	['31977567', '25014687']
# NCT02476357:	['28327108']
# NCT02017171:	['32579810']
# NCT01563003:	['25424398']
# NCT02873377:	['33063570', '29454141']
# NCT03335800:	['31722151', '30392584']
# NCT00642278:	['22632452', '22548646', '22492586']
# NCT02674386:	['34043229']
# NCT01254851:	['23635615']
# NCT00983853:	['23685940']
# NCT02701413:	['34608032']
# NCT02227875:	['34174848']
# NCT00873041:	['25212456', '23553596']
# NCT01787916:	['28722271']
# NCT01081132:	['26506582']
# NCT01647958:	['25284142']
# NCT04502056:	['34259846']
# NCT00857545:	['31653510']
# NCT03831451:	['33238728']
# NCT00517530:	['31050355', '26659915', '23835718', '23835715']
# NCT01314742:	['23608625']
# NCT01235975:	['23494214']
# NCT02526524:	['30252913']
# NCT01947283:	['29466533']
# NCT01913470:	['29992039']
# NCT01224210:	['32008947']
# NCT01705574:	['27562742']
# NCT00160524:	['27494777']
# NCT02155725:	['33713384']
# NCT01000727:	['30371283', '29018021', '25173516', '21982651']
# NCT01133847:	['33772416']
# NCT01262365:	['27598855']
# NCT01333111:	['25261199']
# NCT02396758:	['32757658']
# NCT01262638:	['23770179']
# NCT00514904:	['21278617']
# NCT02899962:	['32950546']
# NCT01408914:	['28559269']
# NCT01375660:	['26209747', '25716637']
# NCT01852214:	['27559041']
# NCT02081391:	['33542653']
# NCT02292849:	['31368583']
# NCT01117181:	['24021498']
# NCT00554099:	['23426454']
# NCT00457977:	['22652582', '19556517']
# NCT02342639:	['34322673']
# NCT01523587:	['29902295', '28577938', '26156651']
# NCT02553317:	['31691462', '30625070']
# NCT03694210:	['34562471']
# NCT01822899:	['26286141']
# NCT01127607:	['27991835', '24796970']
# NCT00260689:	['24415649', '22067384', '21812672']
# NCT01000649:	['28807037']
# NCT01544127:	['31393029', '31237809']
# NCT00281658:	['23509322']
# NCT00719186:	['34180998', '30085176', '29778387', '29102040', '27402910', '27172435', '26413816', '26354094', '25324541', '25006718', '24156957']
# NCT02555657:	['33676601']
# NCT00545129:	['25919474']
# NCT02262377:	['31851666', '27979754']
# NCT02740972:	['32453377']
# NCT01584648:	['33587894', '31166680', '28648698', '28475671', '26037941', '25794603', '25411413', '25265492']
# NCT02665468:	['33206052']
# NCT00711516:	['24532997']
# NCT01753310:	['34888518', '33524060', '29343142']
# NCT01590563:	['24309220']
# NCT00594399:	['26511012', '24933726', '22985140']
# NCT02896075:	['31733755']
# NCT00760552:	['26032843']
# NCT02377349:	['33612341', '31776029']
# NCT03094806:	['31819393']
# NCT01528254:	['31542292', '30576013']
# NCT02509117:	['31424395']
# NCT00049036:	['32107337', '20023215']
# NCT02082769:	['26013187']
# NCT00769015:	['28273318']
# NCT02132767:	['27043047']
# NCT01606007:	['31364269', '30304106', '25352655']
# NCT00685399:	['20926833']
# NCT00518986:	['20051221']
# NCT01275066:	['25487082']
# NCT01362127:	['27254026', '26782957', '25908010', '25582305']
# NCT02314780:	['30354231']
# NCT00715117:	['23188075']
# NCT01341652:	['31644357']
# NCT01739803:	['23819827']
# NCT00350025:	['22927525']
# NCT02022657:	['29038282', '27572401']
# NCT00893763:	['25317722']
# NCT00628927:	['23808868']
# NCT00814177:	['19640572']
# NCT01072929:	['25099397']
# NCT04138810:	['32604202']
# NCT00521352:	['22858212']
# NCT01021553:	['23937679']
# NCT00520741:	['32068241', '27528101', '24915838']
# NCT02865343:	['31738927']
# NCT00644358:	['24127687', '23216998', '22106941']
# NCT01653782:	['28356091']
# NCT01366495:	['33492021', '23536140']
# NCT01953913:	['35020119']
# NCT01827046:	['30739747']
# NCT02729051:	['31321713', '29370819']
# NCT00384774:	['20855362']
# NCT03020992:	['32371433']
# NCT01329939:	['28668546']
# NCT00868959:	['35037813']
# NCT02144519:	['27397608', '26158679', '25998921']
# NCT02008227:	['33737340', '33241650', '32115349', '30562710', '30017645', '29525239', '27979383']
# NCT01786239:	['30241990']
# NCT02903121:	['32649493']
# NCT01975948:	['30486799']
# NCT02062580:	['28405623', '26259542', '25108027']
# NCT02223390:	['29270789']
# NCT03079375:	['29379953']
# NCT02937584:	['32380894']
# NCT03573817:	['32324981']
# NCT00315328:	['20451898', '19064841']
# NCT02615158:	['33196078', '32885909', '31171491', '28385953']
# NCT00358436:	['21518460']
# NCT02858713:	['29654699', '29415699']
# NCT00875420:	['27575546']
# NCT01256424:	['25467012']
# NCT02410772:	['33951360', '33713841']
# NCT01913353:	['31722150']
# NCT02675764:	['30690609']
# NCT02174627:	['33568383']
# NCT01409564:	['30761509']
# NCT00010803:	['20123670', '20040554', '19017911']
# NCT01772004:	['29063313']
# NCT00885365:	['24464974']
# NCT00399360:	['22112605']
# NCT01378273:	['34324880', '34117080', '33113526', '32804205', '32488672', '31940698']
# NCT02969525:	['32035552']
# NCT00781937:	['23812094']
# NCT00646776:	['21712242']
# NCT02580357:	['27344670']
# NCT02305849:	['34429152', '31350269']
# NCT00806026:	['24521108']
# NCT03439124:	['34533489', '33480665']
# NCT01107457:	['25693783', '25242558', '22455413']
# NCT03231943:	['33200887']
# NCT02376257:	['27094721']
# NCT02229851:	['32022863']
# NCT03310268:	['32391584']
# NCT00310375:	['31731109']
# NCT02963597:	['31004141']
# NCT00787202:	['33127596', '32816215', '30476584', '29850873', '27194530', '26376350', '25651782', '22894574']
# NCT01032382:	['23877689']
# NCT02098109:	['28797783']
# NCT01074047:	['29241450', '25987659']
# NCT00671034:	['30626253']
# NCT00699582:	['31954998', '31944276', '25878175', '25823975', '23663001', '22905857']
# NCT00423605:	['24286114']
# NCT01733407:	['30626650']
# NCT02850159:	['28193533']
# NCT01090180:	['29466111']
# NCT02096575:	['25459096']
# NCT02557178:	['33906954']
# NCT00695188:	['22516039']
# NCT01352715:	['27240787']
# NCT00461734:	['26517949', '25666325', '25189602']
# NCT02380690:	['32700220', '30951837']
# NCT02168309:	['27786578']
# NCT01599806:	['34374952', '29912399', '27313268']
# NCT00378508:	['24115337', '23423576', '23086558']
# NCT00443430:	['24786928', '22183975']
# NCT00613938:	['19445652']
# NCT02929069:	['31399071']
# NCT01997723:	['25126034']
# NCT03440723:	['33582306']
# NCT02516592:	['30074294']
# NCT00964886:	['32068667']
# NCT00062738:	['20808132', '20463113']
# NCT00764868:	['23410138']
# NCT00600704:	['20181257', '20187484']
# NCT03316131:	['33075806']
# NCT01032018:	['23471421']
# NCT00651118:	['22418065']
# NCT02512276:	['30083727']
# NCT04365153:	['32830894']
# NCT02772978:	['28066708']
# NCT02055976:	['31549625', '28539539']
# NCT01399736:	['30823897', '28317428']
# NCT01018186:	['23440247']
# NCT01371708:	['30419989']
# NCT00987415:	['25986447']
# NCT02633956:	['31402538']
# NCT01396512:	['25483480']
# NCT01611974:	['30329038']
# NCT00486642:	['24993934']
# NCT00930774:	['26237266']
# NCT00430950:	['22114906']
# NCT02419937:	['29067495']
# NCT01410604:	['22570949']
# NCT03213405:	['33073219']
# NCT01588444:	['23725026']
# NCT01254630:	['31399378']
# NCT01960075:	['34032604', '33336359', '32203691', '31774955']
# NCT01287208:	['24950218']
# NCT02000817:	['33145642', '30566758']
# NCT02558231:	['34593120']
# NCT00356915:	['23884486']
# NCT02165215:	['32445184']
# NCT01106651:	['28619659', '26580237', '26580234', '24517339', '23680739']
# NCT01919112:	['25534369']
# NCT01888640:	['33230010', '31738014', '30157911', '26979999', '25212518']
# NCT01385995:	['22547887']
# NCT01227421:	['24852376']
# NCT02319005:	['32062791']
# NCT01951339:	['31182338']
# NCT00948818:	['24075889', '23116208']
# NCT02364999:	['31768697', '31338773']
# NCT01537835:	['23757125']
# NCT03220204:	['33160091']
# NCT01203098:	['25047458']
# NCT00117676:	['31136052', '30795958', '28215615', '25532501', '23234725', '19052126']
# NCT02899988:	['30734266']
# NCT01829243:	['24800123']
# NCT02963506:	['32253184']
# NCT00580645:	['29389170']
# NCT02172820:	['31078475']
# NCT02169115:	['28389391']
# NCT00391976:	['19996339']
# NCT00469092:	['19821654']
# NCT01640379:	['32569258', '31390037']
# NCT02698215:	['34080890']
# NCT01379625:	['28871440']
# NCT00137969:	['20039413']
# NCT00360399:	['29369664', '28335622']
# NCT00922636:	['24840045']
# NCT00596427:	['22134839']
# NCT00083174:	['24711552', '21639806']
# NCT02086500:	['33016996']
# NCT00960011:	['27889845']
# NCT02957942:	['34859288']
# NCT02738879:	['30393950']
# NCT00431132:	['20859151']
# NCT02066792:	['32496566', '31622374', '26111923']
# NCT02207816:	['31300331']
# NCT03060512:	['31058652']
# NCT01533428:	['27746370']
# NCT02431637:	['29389671']
# NCT00959049:	['25454878']
# NCT01546636:	['24860157']
# NCT00731120:	['24424707']
# NCT01431950:	['25007865', '24966061', '24314123']
# NCT03051100:	['33514449']
# NCT02518230:	['29072677']
# NCT00319956:	['20963840']
# NCT01232946:	['30020461']
# NCT00652145:	['24793028']
# NCT02354976:	['31591263', '30197273']
# NCT02686138:	['33337659']
# NCT02824198:	['33626291', '31464558']
# NCT01624662:	['29928924']
# NCT02443298:	['34706172']
# NCT02713243:	['32702169']
# NCT02835625:	['31078459']
# NCT02344576:	['31129442', '30316931', '29482225', '27203272']
# NCT00730015:	['25312449', '21830967']
# NCT02204657:	['29663517']
# NCT03563183:	['33197294']
# NCT00773513:	['31420350']
# NCT02804594:	['33675156']
# NCT00894166:	['23640009']
# NCT00168064:	['34091453', '23069814']
# NCT00382109:	['24497539']
# NCT02516982:	['28490353']
# NCT00892775:	['23425607']
# NCT01655693:	['30954567']
# NCT01597778:	['34273598', '33475736']
# NCT00411632:	['22586319']
# NCT02477020:	['30190165']
# NCT04317040:	['35012610']
# NCT00486811:	['26535967', '24916058', '24353047']
# NCT00910520:	['26231052', '23608668']
# NCT01053078:	['26345338']
# NCT00970307:	['23838777']
# NCT00676338:	['23748507', '23748506', '23522121', '22210563']
# NCT00565864:	['30165520', '29509918']
# NCT02273167:	['30025414']
# NCT03697252:	['33626254']
# NCT03019796:	['33433153', '31415443', '30459053', '29781921', '29106772', '28803380']
# NCT02330172:	['28493510']
# NCT01559857:	['26731446']
# NCT02699450:	['30905643']
# NCT00712933:	['31302695']
# NCT00224120:	['23234617', '21135869', '19371887']
# NCT01405456:	['34909518', '29659888']
# NCT00279812:	['26803169', '21445287', '20181815']
# NCT00611806:	['23467813']
# NCT00424528:	['19208459']
# NCT02071849:	['25865762']
# NCT00849017:	['28683300', '26577795', '24918790']
# NCT00975286:	['31956422', '23628617', '23564915']
# NCT00135330:	['20107105']
# NCT01441492:	['24374513']
# NCT02960204:	['31870950']
# NCT00225732:	['19843482']
# NCT02696031:	['34481517', '32770640']
# NCT00993447:	['32932330', '24067553']
# NCT01041287:	['25681236']
# NCT00874848:	['28303530']
# NCT02607930:	['32504574', '31068270', '29956087', '28867497']
# NCT01436071:	['25108545', '24966061']
# NCT02429258:	['30222367']
# NCT00551642:	['28046032', '23940237', '20655106']
# NCT01915732:	['27075705']
# NCT01822548:	['28231835']
# NCT01676909:	['33588639']
# NCT02033889:	['32372382', '32324082', '32324065', '31064361', '30614616', '28857451']
# NCT02708095:	['30043749']
# NCT00105196:	['24766999', '23106023', '23585999', '23585997', '21731833', '19407731']
# NCT01480596:	['29661905']
# NCT01177098:	['24667994']
# NCT02332876:	['31605514', '29402761']
# NCT00168454:	['22464310']
# NCT01448044:	['26313445']
# NCT02505542:	['32381562']
# NCT01067521:	['27503905']
# NCT01490450:	['27059799']
# NCT02155738:	['30741813']
# NCT01755767:	['29625879']
# NCT00976274:	['22916320']
# NCT03499028:	['33581971']
# NCT00955903:	['34486528', '31145045']
# NCT01125189:	['25080450']
# NCT01583218:	['30778649', '29188425', '28905172', '28840662', '28698258', '27232649', '24576517']
# NCT02956746:	['34483020']
# NCT04041414:	['34949171']
# NCT01035229:	['27130844', '25058218']
# NCT01265550:	['31618539']
# NCT01130740:	['26720751', '22530979']
# NCT01763905:	['30755061', '24694531']
# NCT01433172:	['30209589']
# NCT00696384:	['25619410']
# NCT00920647:	['25834948']
# NCT01797029:	['29028980', '27746226']
# NCT00099632:	['23300238']
# NCT01736865:	['32559272', '30352748', '27194308']
# NCT01070329:	['21838410']
# NCT02149342:	['26011755']
# NCT02403479:	['29178954']
# NCT02654132:	['30403938']
# NCT00854100:	['30045066']
# NCT03666026:	['32421168']
# NCT02349295:	['33499913', '33479721', '31964419', '30696483', '30053162', '28551073']
# NCT03783702:	['34351376']
# NCT00986180:	['23703422']
# NCT04170686:	['33872182']
# NCT01752712:	['33783399']
# NCT00377858:	['23489710']
# NCT02868229:	['33272965']
# NCT00661583:	['20570237']
# NCT02914275:	['30057283']
# NCT01942590:	['30025991']
# NCT00410826:	['24064970', '23460709']
# NCT00486525:	['24470004']
# NCT00732992:	['20960028']
# NCT00772005:	['22178084']
# NCT00501969:	['23208198']
# NCT00661492:	['22340631']
# NCT03136367:	['33971913', '33170506', '29439691']
# NCT01359644:	['24428467']
# NCT02338193:	['33345876']
# NCT00330460:	['22152181']
# NCT02170051:	['34665853']
# NCT01958073:	['31232721']
# NCT01246960:	['27765757']
# NCT00935818:	['24399554']
# NCT03377790:	['33599960', '32965495']
# NCT00093015:	['30672083', '26299230', '22104547', '21982669', '20843249', '19880844', '19501439']
# NCT00744627:	['29081307']
# NCT00679263:	['23094708']
# NCT02038075:	['25677353']
# NCT00740779:	['21571345']
# NCT00647699:	['22692521']
# NCT00576472:	['19564304']
# NCT03722810:	['32652987']
# NCT00982189:	['23082133']
# NCT01610284:	['30241001', '28576675']
# NCT03174158:	['32198520']
# NCT02411578:	['28591776']
# NCT00716079:	['33647734', '33423518', '31136288', '31085948', '30890109', '30418098', '28235817', '27831492', '27178897', '27165954', '27143274', '27073236', '27009893', '26859491', '26846860', '26814235', '26810526', '26265125', '26202097', '26044442']
# NCT02769312:	['31230462']
# NCT00305604:	['21428727']
# NCT01965158:	['31145214', '28576452']
# NCT00903370:	['31097163', '25853744']
# NCT00080301:	['30153978', '24472478', '21128114']
# NCT02240030:	['30663606']
# NCT04292535:	['33856613']
# NCT00923260:	['20587720']
# NCT01147497:	['24034580', '21527040']
# NCT00104520:	['18658109']
# NCT00571038:	['24755206']
# NCT00905554:	['20883846']
# NCT02240693:	['30755255']
# NCT02278939:	['30294699']
# NCT00409175:	['30558645', '29115008', '28393570', '27494299']
# NCT02021669:	['31163106']
# NCT00098293:	['21388938', '20949133', '20151839']
# NCT01249417:	['31691605']
# NCT01396447:	['34034612', '33677183', '33230026', '32942346', '31969269', '26541814']
# NCT02248480:	['32245696', '31505082', '30126675', '29713194']
# NCT03288987:	['32334845']
# NCT01059630:	['31050355', '29584548', '27345636']
# NCT01791244:	['31276502']
# NCT00214383:	['22835804']
# NCT00286754:	['33979183', '25403606']
# NCT01585038:	['26169561']
# NCT02008773:	['30478008']
# NCT02759939:	['29061624']
# NCT00521456:	['21145532']
# NCT03137459:	['34461035']
# NCT04331899:	['33785743']
# NCT00894543:	['29165623', '26241433', '23760428', '23031421', '22480818', '22353950', '21245182']
# NCT02316223:	['32812836']
# NCT01102972:	['24825167']
# NCT03954158:	['34435694']
# NCT00468676:	['23398269', '22566583', '22074851', '21190455']
# NCT04053465:	['33846088']
# NCT00344175:	['21874537']
# NCT00152009:	['18166547']
# NCT02117934:	['29628151', '29289383']
# NCT01340898:	['29784470']
# NCT00587678:	['21867844', '21570685']
# NCT01498822:	['28395124']
# NCT03415178:	['31879033']
# NCT00432276:	['21733058']
# NCT00730639:	['22658127']
# NCT03409796:	['33130104']
# NCT00071110:	['21672495']
# NCT01822132:	['30266003']
# NCT01890642:	['34591812']
# NCT02467387:	['27856497', '26479144']
# NCT02791490:	['30609212']
# NCT02701400:	['33428583']
# NCT00279916:	['21576556']
# NCT01958320:	['30850756', '30340932']
# NCT02094118:	['28821525']
# NCT01904149:	['26801905']
# NCT02043704:	['28230615']
# NCT02641834:	['29483085']
# NCT01956110:	['30801744', '30713022', '27912901']
# NCT02438384:	['29304831']
# NCT01346293:	['27879555']
# NCT00441480:	['20617456']
# NCT03876743:	['32755488']
# NCT02257385:	['27028749']
# NCT00523718:	['26214725']
# NCT00735072:	['23589670']
# NCT01837719:	['25361436']
# NCT01424813:	['26369589']
# NCT00116428:	['20940250', '20103757']
# NCT02923921:	['33555926']
# NCT01782131:	['33549194']
# NCT02266810:	['27363723']
# NCT00603278:	['26704701', '23062392']
# NCT01447706:	['27998236']
# NCT00790062:	['22227638']
# NCT00162266:	['25005467']
# NCT02321800:	['33393598', '30509675']
# NCT00794924:	['21369670']
# NCT03083483:	['32289719']
# NCT02378220:	['28151991']
# NCT01492686:	['28872913', '28522181']
# NCT03769896:	['32757413']
# NCT01054573:	['25712364']
# NCT02129348:	['29859917']
# NCT00871338:	['23348809']
# NCT00773175:	['23062548']
# NCT00475878:	['24521036', '23891461', '22864399', '21924552', '20598836']
# NCT02091869:	['28111110']
# NCT00542321:	['25727273']
# NCT03453060:	['31977000']
# NCT01469013:	['30784354', '30219772', '28440680', '26834213']
# NCT02722434:	['33249081']
# NCT02706041:	['29766087']
# NCT00358579:	['22353644']
# NCT03577730:	['33939649']
# NCT03795753:	['33011202']
# NCT00741026:	['21857944']
# NCT00474851:	['26181088']
# NCT01146652:	['33871596', '31452928']
# NCT02265705:	['32876903']
# NCT00683475:	['26082390']
# NCT00724711:	['23362296']
# NCT00690040:	['21691166']
# NCT00967005:	['24345329', '23586456']
# NCT02243293:	['30923816', '28951228', '27456384']
# NCT00430989:	['29533264', '28100522', '27956679', '25142708', '19249419']
# NCT01993615:	['29443538', '26846934']
# NCT00142792:	['27225977']
# NCT02343458:	['32917556', '32450869', '32164675', '32021143']
# NCT02254408:	['31793991']
# ...
# NCT00734617:	['20811658', '20379614']
# NCT03259139:	['31150072']
# NCT01587924:	['26494831']
# NCT01694966:	['30742834']
# NCT00535132:	['20216424']
# NCT00303823:	['24388920']
# NCT00802464:	['23904292']
# NCT01156792:	['24010736']
# NCT00388973:	['24162081', '23639212', '23567397']
# NCT00441727:	['23188121', '21415072']
# NCT03633903:	['33858395']
# NCT01975428:	['27334418']
# NCT03449446:	['33169409']
# NCT01537926:	['29540445']
# NCT02219308:	['30095776']
# NCT00105157:	['17434401']
# NCT01691508:	['31053134', '28610668', '27553751', '25199060']
# NCT02146430:	['31284771']
# NCT01355224:	['24216219']
# NCT00307047:	['25940520', '22438430', '22115661', '22017936', '21144968', '20445180', '19781409']
# NCT02128932:	['31769496', '31215727', '28344112']
# NCT01729208:	['31343513']
# NCT04292899:	['32459919']
# NCT00826280:	['21082298']
# NCT01233050:	['28277409']
# NCT02356575:	['33752446']
# NCT02421588:	['34521554']
# NCT01467570:	['22860693']
# NCT00861380:	['31122856', '30145098', '29503110', '27125273', '26284652', '25127244', '24287186', '23158882']
# NCT03515681:	['34382648']
# NCT03630198:	['33760691']
# NCT02261428:	['26487746']
# NCT02201953:	['26575258']
# NCT00735371:	['21421179']
# NCT00380692:	['25369243', '24018545', '23578015', '22721596']
# NCT02106975:	['31573637']
# NCT00006164:	['24886378', '22688849', '22571902', '22103814', '22030902', '21931376', '21829595', '21699796', '21520194', '21376050', '21374690', '21335007', '21129375', '20889211', '20675691', '20564351', '20211180', '20070284', '19766643', '19747918']
# NCT00452530:	['20206776']
# NCT02081846:	['30039161', '29934295']
# NCT02425644:	['33779698']
# NCT01401647:	['28904070', '27043165']
# NCT02460562:	['30056451']
# NCT01912287:	['32805013']
# NCT01329198:	['23044532']
# NCT00041756:	['17958901']
# NCT02299791:	['26059264']
# NCT00244712:	['19542866']
# NCT02935699:	['32653333']
# NCT00131352:	['19304567']
# NCT01419535:	['33507248']
# NCT03779997:	['34399136', '32736660']
# NCT00495131:	['18834319']
# NCT01921205:	['34033237', '31462582']
# NCT01284517:	['27089521']
# NCT01989208:	['25930144']
# NCT00367991:	['19958860']
# NCT02569242:	['31582355']
# NCT00090363:	['19042080']
# NCT02528253:	['32453139']
# NCT02704156:	['34237249']
# NCT02128997:	['28704847']
# NCT02326363:	['33857680']
# NCT01970475:	['28584187']
# NCT00090584:	['21563210', '20945064', '20671098', '18678843']
# NCT00723606:	['23422376']
# NCT02277769:	['34142350', '33453450', '33165005', '32135208', '31424712', '31179791', '30791102', '28503712', '27690741']
# NCT01964092:	['33145494', '30074050', '25403470']
# NCT01643382:	['27423055']
# NCT01295814:	['23792149']
# NCT00783692:	['30615117', '30203005', '29857145', '29471381', '25996351', '23964933']
# NCT02334215:	['33196937', '33187759', '31748939', '27282117']
# NCT02349477:	['34256607', '32150232']
# NCT00774852:	['25403681']
# NCT02290184:	['30291068', '27608829']
# NCT01864174:	['28857388']
# NCT01302483:	['23690356']
# NCT00074412:	['33181788', '25885678', '24189151', '22196945', '22112598']
# NCT00064298:	['28102098']
# NCT00767806:	['24650448']
# NCT03216265:	['30414275']
# NCT01568892:	['25321146']
# NCT01976364:	['32816215']
# NCT01912339:	['33515055']
# NCT01137682:	['32217809', '25260838']
# NCT00100230:	['26469750', '25342618', '25015354', '24805262', '23828615']
# NCT03097341:	['30700130']
# NCT00910429:	['27067478', '23883377']
# NCT03383887:	['33491327']
# NCT00490542:	['22545088']
# NCT03139240:	['31764725']
# NCT00187369:	['33203367', '32592694', '31254526', '28061767', '26551181', '24088091']
# NCT00821119:	['21262883']
# NCT01374906:	['31804965', '31465533', '29032078']
# NCT01709903:	['27715335', '26082625']
# NCT02933060:	['30665504']
# NCT02792231:	['32757523']
# NCT02446912:	['33977796', '33913260']
# NCT01461369:	['25050589']
# NCT00958360:	['31592954', '29800250', '22958237']
# NCT02925923:	['31766977']
# NCT01487668:	['27780336']
# NCT01153347:	['25602163', '25514064']
# NCT02437383:	['33560875', '33030089', '32701836']
# NCT01421342:	['32603560', '30947531', '30695291', '28697253', '27479536']
# NCT02723916:	['33338496']
# NCT00734578:	['25245353', '22176941']
# NCT01691859:	['30359681']
# NCT00980278:	['25652112']
# NCT02956837:	['31418022']
# NCT01660672:	['31672143']
# NCT03159624:	['29856526']
# NCT01483144:	['32905675', '27480131']
# NCT02707146:	['31300571', '30858257']
# NCT03124108:	['33484775']
# NCT01243242:	['23933905', '23290324']
# NCT02037984:	['30689507']
# NCT01263015:	['26262777', '24195548']
# NCT00775944:	['22446739']
# NCT00425945:	['20876405']
# NCT02634346:	['32141723']
# NCT00520039:	['24917631', '20538749']
# NCT03021187:	['31530667']
# NCT00105027:	['26086920', '23229691', '19752420', '19752419', '19674727']
# NCT02428699:	['30106311']
# NCT02014402:	['31376435']
# NCT02691260:	['33245118']
# NCT01763866:	['30755061', '24825642']
# NCT00569530:	['23037875']
# NCT02114684:	['30809633']
# NCT02549287:	['32569643']
# NCT02753413:	['29401325']
# NCT01415427:	['29248359', '28535791', '27955919']
# NCT01294748:	['25044635', '24801119']
# NCT02596620:	['27175657']
# NCT01107912:	['23747759']
# NCT01709708:	['25828648', '25338927']
# NCT00907335:	['22712470']
# NCT00442546:	['25565885']
# NCT01968447:	['27154574']
# NCT02460666:	['34404606']
# NCT03706313:	['34261807']
# NCT02783599:	['28838379']
# NCT03388268:	['33441409']
# NCT00450216:	['26165391']
# NCT00679302:	['19409657']
# NCT03120013:	['30135258']
# NCT00127166:	['20568384']
# NCT00129545:	['29103847', '26627989', '25399274', '23500276', '23325525', '19683639']
# NCT01495923:	['25883095']
# NCT00348283:	['29380251', '23856361']
# NCT03032380:	['33058798']
# NCT02861534:	['34407626', '33185650', '32222134', '29032136']
# NCT01798992:	['25637602']
# NCT01576718:	['27937064']
# NCT02692391:	['34704970']
# NCT00958880:	['24237691']
# NCT02937454:	['33197395', '31883356']
# NCT01080807:	['23251870', '22104981']
# NCT00060606:	['33555337', '33165214', '31980545', '26416930', '21306277']
# NCT01072630:	['25933099']
# NCT02709018:	['34275593']
# NCT00628589:	['21200077']
# NCT00349622:	['28864675', '25297012', '23613806']
# NCT00722137:	['30348538', '28583031', '28183846', '25738670']
# NCT01175369:	['23400614']
# NCT01241448:	['26681715']
# NCT00650585:	['19581545']
# NCT01101022:	['32470230', '24106804', '23945447']
# NCT01086540:	['33651671', '28963118']
# NCT00522379:	['26882318', '24643203']
# NCT02465372:	['31102834']
# NCT03067987:	['30025713']
# NCT04308668:	['33204764', '32673060', '32492293']
# NCT00683852:	['21939613']
# NCT01896193:	['27376706']
# NCT00586157:	['25575616', '20492851']
# NCT02546609:	['30569637']
# NCT00565773:	['24684552']
# NCT00492856:	['24528179']
# NCT02699983:	['30535101']
# NCT00120250:	['21367352']
# NCT00459667:	['21952094']
# NCT00708435:	['26135740', '23935011']
# NCT03327220:	['33279353']
# NCT00765882:	['25312449', '21830967']
# NCT00806988:	['33573741', '27777294', '27040451', '25405390']
# NCT02970942:	['33185364', '33039693']
# NCT02872012:	['32446842']
# NCT00958581:	['20370916']
# NCT01598831:	['32697484', '31104069']
# NCT01513473:	['25683037']
# NCT00133705:	['17138770']
# NCT01808118:	['29961640']
# NCT02164864:	['32389658', '32252548', '31439336', '30015064', '28844193']
# NCT00585637:	['26858840', '24974387', '24368437', '23487599']
# NCT01439360:	['35083365', '31725115', '31306399', '30325891']
# NCT00435045:	['22108152', '20118387']
# NCT01098474:	['25305000']
# NCT00833833:	['24421329']
# NCT03046056:	['33177349']
# NCT01113892:	['25720929']
# NCT02196831:	['34006921', '33852720', '33125080', '31611038']
# NCT03037307:	['31249709']
# NCT01154985:	['24818764']
# NCT01611194:	['31394603', '31394602', '31394601', '31394600', '30099354', '29734566', '28768071', '28768070', '28768069']
# NCT01690000:	['26424587']
# NCT03744780:	['31541426']
# NCT01994889:	['33667442', '33220323', '33070419', '30145929', '28611125']
# NCT02667236:	['30365590']
# NCT01255670:	['26968881']
# NCT03159299:	['32368713']
# NCT02552888:	['33023894']
# NCT00984698:	['33065820']
# NCT00428844:	['22908174']
# NCT01240902:	['34581194', '32997095', '31902431', '30249462', '30172363', '27541162', '27443429', '27313280', '27296201', '27050187', '26764063', '26508386', '26292584', '26055947', '24678937']
# NCT00576693:	['31484697', '28455321', '28003500', '26747792', '26382173', '25593135', '24168957', '22984008', '21899409']
# NCT01234649:	['32046931']
# NCT00130923:	['26302441']
# NCT02905032:	['34255051', '32897386', '32398149']
# NCT01640964:	['28245243']
# NCT01782742:	['26822146']
# NCT01010061:	['31050355', '24401022']
# NCT00746395:	['19577749']
# NCT03040011:	['33278291']
# NCT02903966:	['34389633']
# NCT02919761:	['32185745']
# NCT03270085:	['32088296']
# NCT01445951:	['31811662', '26180109']
# NCT03862482:	['33314332']
# NCT03021005:	['29903889']
# NCT03283371:	['34521687', '33831649']
# NCT02571218:	['29535136']
# NCT01078298:	['24042367']
# NCT01184014:	['26492541']
# NCT01127659:	['26622051']
# NCT02019264:	['30586726', '30293771', '30145941', '29803985']
# NCT00110890:	['22863242']
# NCT02630459:	['31612482']
# NCT01430403:	['26518090']
# NCT01033240:	['26071796']
# NCT01769365:	['25070099']
# NCT00178919:	['18426998']
# NCT00114530:	['29298160']
# NCT02025621:	['28316276', '27914501', '25989324']
# NCT00441285:	['26984901', '24999157']
# NCT00744471:	['23553790']
# NCT01684722:	['33098434', '31703120']
# NCT01034462:	['27861191', '27455513', '26773906', '24172209']
# NCT01606787:	['28822586']
# NCT01056640:	['22507696', '20809953']
# NCT01262352:	['24461666']
# NCT01736124:	['31006684']
# NCT02863354:	['32829304', '32584384', '31917731', '31472160']
# NCT01596335:	['29386515']
# NCT00690573:	['30054164']
# NCT02573870:	['32366249']
# NCT03563313:	['33155824', '31618560']
# NCT01743027:	['26266427']
# NCT01495702:	['28689453', '24908550']
# NCT01844817:	['28935773']
# NCT02193087:	['32119591']
# NCT02501642:	['34184976']
# NCT03107377:	['33705748']
# NCT00847912:	['29299592', '28877312', '28532759', '25950503']
# NCT01864564:	['31926951']
# NCT02964247:	['34132018']
# NCT02586896:	['32883337']
# NCT01133626:	['23062389']
# NCT01618968:	['24728329']
# NCT01293695:	['34403019']
# NCT03612856:	['34086880']
# NCT01946191:	['32808209', '31711168']
# NCT02032888:	['26196502']
# NCT01934972:	['25566387']
# NCT01311687:	['27081177', '26250580', '26160879', '26149712', '25425684', '24007748']
# NCT01472185:	['26049552']
# NCT01534520:	['27500351']
# NCT02544984:	['27638496']
# NCT02380742:	['28594757']
# NCT00283686:	['30803434', '25399733', '25111236', '22205355']
# NCT02101437:	['30783954']
# NCT02058589:	['30843046']
# NCT00400153:	['20172704']
# NCT01845831:	['27964837']
# NCT00926796:	['25031289']
# NCT02611765:	['28200045']
# NCT02132910:	['28919191']
# NCT00472303:	['25054392']
# NCT03056690:	['33328761']
# NCT03191552:	['30293457']
# NCT04005391:	['34709526', '32819394']
# NCT00356278:	['30059794', '27183343', '24743802']
# NCT01853696:	['26020827']
# NCT00570739:	['22913890', '22836068', '20634176', '20634175']
# NCT01160640:	['32052831']
# NCT01214980:	['25868409']
# NCT01209234:	['30763195']
# NCT02343406:	['33601293', '31747009']
# NCT00460525:	['28282396', '27087149', '24260195', '21916638']
# NCT00932113:	['25946554']
# NCT01539759:	['26241250']
# NCT01182441:	['29103847', '26627989']
# NCT00097773:	['26288390', '25972024', '21893650', '19470318']
# NCT04137627:	['32372215']
# NCT02636699:	['30794314']
# NCT00498706:	['22706833']
# NCT00877058:	['27716095', '20504358']
# NCT02796963:	['30153265']
# NCT00296400:	['25660356']
# NCT00532779:	['20673995']
# NCT01628016:	['25245928']
# NCT03226275:	['30232699']
# NCT01174576:	['21346100']
# NCT01785186:	['28100438']
# NCT00424476:	['34741731', '33568389', '31302695', '23524886', '22337213', '22275291', '21296403']
# NCT00770146:	['24013058']
# NCT00810693:	['27457511', '26135803', '23883378']
# NCT01081834:	['29022746', '28327140', '28241822', '28197834', '27600862', '26580237', '26579834', '26373629', '26121561', '25813214', '24585202', '24517339', '24073995']
# NCT00723450:	['26598477']
# NCT01121211:	['31219558']
# NCT00855166:	['26894924', '23906445', '22651373']
# NCT01063972:	['31367875']
# NCT00501852:	['20541381']
# NCT02765490:	['30693573']
# NCT00999544:	['22260216']
# NCT00957359:	['31916890', '27909164']
# NCT01539239:	['32143828', '29945799']
# NCT00178685:	['27923864', '27839954', '21999719', '21382516', '19373517', '18838243']
# NCT01404611:	['28006041']
# NCT02940860:	['32049331']
# NCT00619073:	['20736449']
# NCT00678639:	['21835378']
# NCT00725985:	['24502830']
# NCT01144715:	['26122686', '25782693', '23280269']
# NCT02515058:	['30161278']
# NCT01115738:	['24718367', '24065443']
# NCT00371644:	['29905663', '29573657', '26198645', '23325750']
# NCT00162123:	['25210016']
# NCT00808470:	['22122960']
# NCT02105636:	['32583557', '31422216', '31246283', '30972702', '29884413', '28939066', '28651929', '27718784']
# NCT00926783:	['24425420']
# NCT00912925:	['33874971']
# NCT01753999:	['33202147']
# NCT03343639:	['32007513']
# NCT03226457:	['32865004', '29042392']
# NCT00600886:	['27039081', '25103549']
# NCT02360293:	['32687474', '30694208', '30681965']
# NCT02608450:	['32320027']
# NCT01113749:	['24083403', '22091750']
# NCT00790400:	['30192751', '30053159', '29569806', '28792952', '26156073', '23312829']
# NCT00474266:	['26780033', '21443965']
# NCT02194933:	['32450497']
# NCT03384745:	['33894834']
# NCT02821403:	['28045969']
# NCT02980978:	['30711463']
# NCT01823861:	['29191231', '25388660']
# NCT02752074:	['31221619']
# NCT01966458:	['30007559']
# NCT03201419:	['34932192']
# NCT00227266:	['20808854']
# NCT03237481:	['31429023']
# NCT02417064:	['34288609', '34235612', '32860422', '32367114', '31290965']
# NCT03049917:	['33048877']
# NCT02326233:	['30464411']
# NCT00332241:	['24138011', '20973712', '19948625']
# NCT03252145:	['33872573']
# NCT01903811:	['32299820']
# NCT02018562:	['31385620']
# NCT00122460:	['32993574', '23265711', '18784101']
# NCT01002547:	['31332029']
# NCT01106352:	['31082669']
# NCT01982786:	['29903505']
# NCT01635244:	['26819292']
# NCT01948076:	['25387438']
# NCT01854047:	['31351189', '30138668', '29355679', '27130691']
# NCT00444067:	['25646746']
# NCT02334267:	['28851317']
# NCT01808573:	['34553296', '33909203', '32678716']
# NCT01147926:	['25869393']
# NCT02570425:	['29954359']
# NCT01040351:	['20672903']
# NCT02296138:	['32943047', '32776202', '29605624']
# NCT01551212:	['34525259']
# NCT01173601:	['27035159']
# NCT02752048:	['31957953']
# NCT01471457:	['29474292', '25935783']
# NCT00919867:	['23615868']
# NCT00920816:	['33947608', '27498023', '24206640']
# NCT00183196:	['21454917']
# NCT00873327:	['22569355']
# NCT00966875:	['26669919', '24623718']
# NCT00181155:	['22361399']
# NCT00953927:	['26554383', '24912498', '23391465']
# NCT00415870:	['23085329', '19141433']
# NCT00747617:	['21270326']
# NCT01763788:	['30797492']
# NCT01639339:	['32937045']
# NCT02795767:	['33512413']
# NCT02983552:	['30352226']
# NCT01514786:	['31128959']
# NCT01093417:	['22293363']
# NCT01059903:	['24006953']
# NCT01107015:	['29217502']
# NCT00711971:	['31783739', '29940888', '27485050', '23531328', '21696635']
# NCT02425891:	['31786121', '30345906']
# NCT01059773:	['27515070']
# NCT00403481:	['21777013', '20085534']
# NCT00627393:	['26333778']
# NCT01446913:	['26429745']
# NCT02877927:	['31861009', '31474458', '31367742']
# NCT01871506:	['33048154']
# NCT00600925:	['20825316']
# NCT01427738:	['27677161']
# NCT01754389:	['29326124']
# NCT01794741:	['29490769']
# NCT01500226:	['26272768']
# NCT01064687:	['26691396']
# NCT00891319:	['27608819']
# NCT02016105:	['33651341']
# NCT00004562:	['30950656', '23141853', '22025606', '20547926', '19228620', '19194534', '17105759']
# NCT00872430:	['20433751']
# NCT00788151:	['22863660']
# NCT02576938:	['33826132']
# NCT00509106:	['30597021', '26702925', '25487791', '23357290', '21482568', '21482570']
# NCT01879722:	['29103081']
# NCT03334747:	['34930267']
# NCT00475085:	['22915657']
# NCT03631732:	['34397746']
# NCT00423657:	['34741280', '30597021', '21115456', '21115455', '20695801']
# NCT01392625:	['27856208', '25354998']
# NCT00594165:	['25997442', '25444083', '22326237']
# NCT01019694:	['23658479']
# NCT02992197:	['31607603']
# NCT00233480:	['22041323']
# NCT02283762:	['27746061']
# NCT01989130:	['27100764']
# NCT02326220:	['27572070', '27206951']
# NCT03374683:	['33904820']
# NCT01875861:	['24103648']
# NCT00325442:	['22628490']
# NCT02139046:	['30073793']
# NCT03629184:	['32516282']
# NCT01258803:	['24019197']
# NCT02530385:	['32150549']
# NCT01690130:	['23485014']
# NCT00736580:	['24294709']
# NCT00644995:	['21414216']
# NCT00359736:	['20012639']
# NCT00975923:	['21312329']
# NCT01377194:	['26773906', '24144196']
# NCT01629589:	['31301919']
# number of nctid: 8162
# number of pmid: 14066
# number of unique pmid: 12864

# %% [markdown]
# - number of nctid mapped with pmid: 8162
# - number of pmid: 14066
# - number of unique pmid: 12864

# %% [markdown]
# ## Extract abstract by pmid

# %%
import sys
import regex as re
import urllib.request as ur
import os,codecs
from time import sleep
from xml.dom import minidom 
import xml.etree.ElementTree as xml_parser

import urllib.parse
import requests, json             
import pickle

def get_abstract_bypmid(pmid):
    url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id="+str(pmid)+"&retmode=XML&rettype=abstract"
    
    try:
        fetch = ur.urlopen(url)
        datam = fetch.read().decode('utf-8')  # xml of one article

    except:
        return None
    
    datam = re.sub("<i>", "", datam)  # remove <i> in xml to avoid failure in parsing .text
    datam = re.sub("</i>", "", datam)
    datam = re.sub("<sup>", "", datam)  # remove <i> in xml to avoid failure in parsing .text
    datam = re.sub("</sup>", "", datam)
    datam = re.sub("<sub>", "", datam)  # remove <i> in xml to avoid failure in parsing .text
    datam = re.sub("</sub>", "", datam)
    datam = re.sub("<em>", "", datam)  # remove <i> in xml to avoid failure in parsing .text
    datam = re.sub("</em>", "", datam)
    datam = re.sub("<strong>", "", datam)  # remove <i> in xml to avoid failure in parsing .text
    datam = re.sub("</strong>", "", datam)
    datam = re.sub("<b>", "", datam)  # remove <b> in xml to avoid failure in parsing .text
    datam = re.sub("</b>", "", datam)

    xmldoc = xml_parser.fromstring(datam)
    
    PubmedArticle = xmldoc.find("PubmedArticle")
    abstract_text = ""
    title_text=""
    meta_data={}

    meta_data['pubdate'] = ""
    meta_data['source'] = ""
    meta_data['volume'] = ""
    meta_data['pages'] = ""
    meta_data['pubtype'] = []
    meta_data['authors'] = []

    if PubmedArticle is not None:
        data = PubmedArticle.find("MedlineCitation")
        if data is not None:
            article = data.find("Article")
            if article is not None:
                title = article.find("ArticleTitle")
                #print("Title:",title.text)
                title_text = title.text
                abstract = article.find("Abstract")
                if abstract is not None:
                    for seg in abstract:
                        if seg.text:
                            if 'NlmCategory' in seg.attrib:
                                abstract_text = abstract_text + "\n" + seg.attrib['NlmCategory'] + " : " + seg.text
                            elif 'Label' in seg.attrib:
                                abstract_text = abstract_text + "\n" + seg.attrib['Label'] + " : " + seg.text
                            else:
                                abstract_text = abstract_text + "\n" + seg.text
                        elif 'Label' in seg.attrib and len(seg.attrib['Label'].split(':'))>1:
                            abstract_text = abstract_text + "\n" + seg.attrib['Label'].split(':')[0] + " : " + seg.attrib['Label'].split(':')[1]
                
                journal = article.find("Journal")
                if journal is not None:
                    if journal.find("ISOAbbreviation") is not None:
                        meta_data['source'] = journal.find("ISOAbbreviation").text
                    if journal.find("JournalIssue").find('Volume') is not None:
                        meta_data['volume'] = journal.find("JournalIssue").find('Volume').text
                   
                Pagination = article.find("Pagination")
                if Pagination is not None:
                    meta_data['pages'] = Pagination.find("MedlinePgn").text 
    

                AuthorList = article.find('AuthorList')

                if AuthorList is not None:
                    for author in AuthorList.findall('Author'):
                        if author.find('Initials') is not None and author.find('LastName') is not None:
                            meta_data['authors'].append(author.find('Initials').text+'. '+author.find('LastName').text)
                PublicationTypeList = article.find('PublicationTypeList')
                if PublicationTypeList is not None:
                    for PublicationType in PublicationTypeList.findall('PublicationType'):
                        meta_data['pubtype'].append(PublicationType.text)

        PubmedData = PubmedArticle.find('PubmedData')
        if PubmedData is not None:
            History = PubmedData.find('History')
            if History.find("PubMedPubDate") is not None:
                date = History.find("PubMedPubDate")
                Year=""
                Month=""
                Day=""
                if date.find('Year') is not None:
                    Year =date.find('Year').text
                if date.find('Month') is not None:
                    Month=date.find('Month').text+'/'
                if date.find('Day') is not None:
                    Day=date.find('Day').text+'/'
                
                meta_data['pubdate'] = Month + Day +Year
                
    meta_data['title'] = title_text
    #print (meta_data)

    #abstract_text = re.search("©|(copyright)","", abstract_text)
    abstract_text = re.sub("^\s+", "", abstract_text)

    return title_text, abstract_text, meta_data

# %%
# test
id = 31950977
title, ab, meta_data = get_abstract_bypmid(id)
print(ab)
# Out:
# Importance : Proton pump inhibitors (PPIs) or histamine-2 receptor blockers (H2RBs) are often prescribed for patients as stress ulcer prophylaxis drugs in the intensive care unit (ICU). The comparative effect of these drugs on mortality is unknown.
# Objective : To compare in-hospital mortality rates using PPIs vs H2RBs for stress ulcer prophylaxis.
# Design, Setting, and Participants : Cluster crossover randomized clinical trial conducted at 50 ICUs in 5 countries between August 2016 and January 2019. Patients requiring invasive mechanical ventilation within 24 hours of ICU admission were followed up for 90 days at the hospital.
# Interventions : Two stress ulcer prophylaxis strategies were compared (preferential use with PPIs vs preferential use with H2RBs). Each ICU used each strategy sequentially for 6 months in random order; 25 ICUs were randomized to the sequence with use of PPIs and then use of H2RBs and 25 ICUs were randomized to the sequence with use of H2RBs and then use of PPIs (13 436 patients randomized by site to PPIs and 13 392 randomized by site to H2RBs).
# Main Outcomes and Measures : The primary outcome was all-cause mortality within 90 days during index hospitalization. Secondary outcomes were clinically important upper gastrointestinal bleeding, Clostridioides difficile infection, and ICU and hospital lengths of stay.
# Results : Among 26 982 patients who were randomized, 154 opted out, and 26 828 were analyzed (mean [SD] age, 58 [17.0] years; 9691 [36.1%] were women). There were 26 771 patients (99.2%) included in the mortality analysis; 2459 of 13 415 patients (18.3%) in the PPI group died at the hospital by day 90 and 2333 of 13 356 patients (17.5%) in the H2RB group died at the hospital by day 90 (risk ratio, 1.05 [95% CI, 1.00 to 1.10]; absolute risk difference, 0.93 percentage points [95% CI, -0.01 to 1.88] percentage points; P = .054). An estimated 4.1% of patients randomized by ICU site to PPIs actually received H2RBs and an estimated 20.1% of patients randomized by ICU site to H2RBs actually received PPIs. Clinically important upper gastrointestinal bleeding occurred in 1.3% of the PPI group and 1.8% of the H2RB group (risk ratio, 0.73 [95% CI, 0.57 to 0.92]; absolute risk difference, -0.51 percentage points [95% CI, -0.90 to -0.12 percentage points]; P = .009). Rates of Clostridioides difficile infection and ICU and hospital lengths of stay were not significantly different by treatment group. One adverse event (an allergic reaction) was reported in 1 patient in the PPI group.
# Conclusions and Relevance : Among ICU patients requiring mechanical ventilation, a strategy of stress ulcer prophylaxis with use of proton pump inhibitors vs histamine-2 receptor blockers resulted in hospital mortality rates of 18.3% vs 17.5%, respectively, a difference that did not reach the significance threshold. However, study interpretation may be limited by crossover in the use of the assigned medication.
# Trial Registration : anzctr.org.au Identifier: ACTRN12616000481471.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# !ls /content/gdrive/MyDrive/Demographic\ Analysis\ Project/
# Out:
# Mounted at /content/gdrive
#  aact_primary_outcome_with_cui.tsv
#  aact_primary_outcome_with_cui_v2.tsv
# 'age_segment_by_nctid (1).tsv'
#  age_segment_by_nctid.tsv
# 'AMIA 2022 paper.gsheet'
#  asian_embedding.model
#  asian_fasttext.model
#  baseline_model2
#  black_embedding.model
#  black_fasttext.model
#  cui_voc.pickle
# 'Demographic Bias Project Proposal.gdoc'
# 'Demographic-sensitive concept embeddings for bias investigation in clinical trials.gdoc'
#  embeddings
#  final_dataframe_demographic_analysis.csv
#  hao_test
#  hispanic_embedding.model
#  hispanic_fasttext.model
#  icd_diagnoses_with_cui.gsheet
#  icd_diagnoses_with_cui.tsv
# 'july 12th'
# 'june 17th'
# 'june 23rd'
# 'june 27th'
# 'may 16th'
#  mimic-iv-1.0
#  native_embedding.model
#  native_fasttext.model
#  nctid_list.tsv
#  nctid_to_pmid_dict_25000.pickle
#  nctid_to_pmid_dict_26000.pickle
#  nctid_to_pmid_dict_27000.pickle
#  nctid_to_pmid_dict_29000.pickle
#  nctid_to_pmid_dict_30000.pickle
#  nctid_to_pmid_dict.pickle
#  neutral_embedding.model
#  neutral_fasttext.model
#  neutral_fasttext.model.trainables.vectors_ngrams_lockf.npy
# 'neutral_fasttext.model.wv.vectors_ngrams (1).npy'
#  neutral_fasttext.model.wv.vectors_ngrams.npy
#  new_data_pubmed_abstracts
#  outcome_by_nctid_primary.gsheet
#  outcome_by_nctid_primary.tsv
#  pmed_abstract_cui_replaced_v2
#  pmed_abstract_cui_replaced_v2.zip
#  pmed_abstract_cui_replaced.zip
#  pmid_abstracts
# 'race_segment_by_nctid (1).tsv'
# 'race_segment_by_nctid (2).tsv'
#  race_segment_by_nctid.tsv
#  raw_data_1960-2022_cui_repleced_v2.zip
#  raw_data_1960-2022_cui_repleced.zip
# 'Script v1.ipynb'
#  vocab_cui_v3.txt
#  white_embedding.model
#  white_fasttext.model

# %%
import pickle
filename = '/content/gdrive/MyDrive/Demographic Analysis Project/nctid_to_pmid_dict.pickle'

with open(filename, 'rb') as handle:
    results_dict = pickle.load(handle)

print(len(results_dict.keys()))
# Out:
# 30151

# %%
pmid_set = set()
for k, v in results_dict.items():
  if v:
    for vv in v:
      pmid_set.add(vv)
pmidlist = list(pmid_set)

print(f'size of pmid list: {len(pmidlist)}')
# Out:
# size of pmid list: 12864

# %%
import os
import codecs
import re
from time import sleep
pm_path = '/content/gdrive/MyDrive/Demographic Analysis Project/pmid_abstracts/'
if not os.path.exists(pm_path):
    os.mkdir(pm_path)

# %%
def download_abstract_by_pmid(pmid, save_path):
    test_url = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id='+str(pmid)+'&retmode=XML'

    try:
        fetch = ur.urlopen(test_url)
        datam = fetch.read().decode('utf-8')  # xml of one article
        filename_xml = str(pmid)+'.xml'
        file_dir = os.path.join(save_path, filename_xml)
        xml = open(file_dir, "w")
        xml.write(datam)
        xml.close()
    except Exception as e:
        print(f'{e} at {pmid}')

# %%
print(pmidlist[:10])
# Out:
# ['31766977', '32665528', '31362741', '32199723', '27328486', '25693783', '25485670', '27062245', '28607708', '29754812']

# %%
from random import randint
from tqdm.auto import tqdm
def save_xmls(pmidlist, save_path):
    pm_path = save_path
    print("dir for xml saved in", pm_path)
    if not os.path.exists(pm_path):
        os.mkdir(pm_path)

    exceptionlistfile=codecs.open(os.path.join(pm_path,"exceptionlist"),'w')
    length = len(pmidlist)

    for (index,id) in enumerate(tqdm(pmidlist, total=length, position=0, leave=True)):
        id = id.rstrip()
        filename_xml=id+".xml"

        print(f'processing id: {id}')
        
        if os.path.exists(os.path.join(pm_path,filename_xml)):
            print ("existed, skipped")
            continue
        if re.search("^#",id):
            continue 
        if re.search("^pmid", id):
            continue
        if re.search("^\s*$",id):
            continue
        id = id.rstrip().split("\t")[0]

        if (index) % 1000 == 0:
            print(index,"finished...")
        sleep(0.3)

        pmid = id
        # print(f'processing pmid: {pmid}')
        for i in range(5):
            try:
                download_abstract_by_pmid(pmid, pm_path)
                break
            except Exception as e:
                print(f"Retrying: {i}")
                sleep(randint(1,10))
        else:
            print(f'extraction failed at {pmid}')
            exceptionlistfile.write(str(id)+"\n")
            continue

    print("Retrieved xml saved in", pm_path)

save_xmls(pmidlist, pm_path)
# Out:
# dir for xml saved in /content/gdrive/MyDrive/Demographic Analysis Project/pmid_abstracts/
#   0%|          | 0/12864 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# processing id: 27093976
# processing id: 30962681
# processing id: 27133551
# processing id: 27720142
# processing id: 22658389
# processing id: 30376130
# processing id: 30857647
# processing id: 32721009
# processing id: 29374054
# processing id: 30976782
# processing id: 23802840
# processing id: 22569355
# processing id: 19935992
# processing id: 28374645
# processing id: 31635976
# processing id: 28103841
# processing id: 31276502
# processing id: 33883254
# processing id: 33653824
# processing id: 26493248
# processing id: 24415559
# processing id: 32644148
# processing id: 29789238
# processing id: 32816874
# processing id: 26283236
# processing id: 24798072
# processing id: 32653447
# processing id: 32164888
# processing id: 22704099
# processing id: 21791356
# processing id: 34197181
# processing id: 29207976
# processing id: 32248638
# processing id: 34412104
# processing id: 29461870
# processing id: 25941016
# processing id: 18789766
# processing id: 27811204
# processing id: 33516082
# processing id: 29803985
# processing id: 25773757
# processing id: 24906437
# processing id: 24565019
# processing id: 31461138
# processing id: 23676577
# processing id: 28968735
# processing id: 21128114
# processing id: 25416807
# processing id: 33534940
# processing id: 25978741
# processing id: 27720499
# processing id: 23032552
# processing id: 22353950
# processing id: 33683313
# processing id: 32780999
# processing id: 34387119
# processing id: 29045770
# processing id: 32777606
# processing id: 23585997
# processing id: 34266940
# processing id: 31566651
# processing id: 31117986
# processing id: 29926300
# processing id: 27749608
# processing id: 30830724
# processing id: 29241762
# processing id: 30648126
# processing id: 26135803
# processing id: 22123685
# processing id: 30690609
# processing id: 26894413
# processing id: 32726105
# processing id: 25996491
# processing id: 26009829
# processing id: 32897367
# processing id: 23754238
# processing id: 31358477
# processing id: 32229033
# processing id: 30336824
# processing id: 34171279
# processing id: 35013866
# processing id: 30654882
# processing id: 18498956
# processing id: 27593728
# processing id: 19656386
# processing id: 31244760
# processing id: 31981557
# processing id: 34275593
# processing id: 19581545
# processing id: 18438876
# processing id: 29420695
# processing id: 23497788
# processing id: 34696742
# processing id: 26989182
# processing id: 21156071
# processing id: 28836458
# processing id: 25371077
# processing id: 24074642
# processing id: 29525393
# processing id: 27494299
# processing id: 23128163
# processing id: 22480818
# processing id: 21865947
# processing id: 30348538
# processing id: 18003959
# processing id: 28223082
# processing id: 26249300
# processing id: 27154574
# processing id: 21324520
# processing id: 25054436
# processing id: 33871596
# processing id: 31466479
# processing id: 31828052
# processing id: 23937679
# processing id: 26393847
# processing id: 23784924
# processing id: 22750403
# processing id: 33540206
# processing id: 27355400
# processing id: 31626990
# processing id: 32076985
# processing id: 33043969
# processing id: 29891538
# processing id: 24992552
# processing id: 32532654
# processing id: 32755035
# processing id: 21939613
# processing id: 28636855
# processing id: 32031690
# processing id: 23148287
# processing id: 28060463
# 8000 finished...
# processing id: 22682875
# processing id: 29947751
# processing id: 30297199
# processing id: 26324372
# processing id: 28427593
# processing id: 23510951
# processing id: 25853744
# processing id: 23080427
# processing id: 32829304
# processing id: 33031757
# processing id: 24736647
# processing id: 25289942
# processing id: 29856685
# processing id: 28768070
# processing id: 31284771
# processing id: 27815101
# processing id: 24316509
# processing id: 22652582
# processing id: 23188075
# processing id: 29116540
# processing id: 26118315
# processing id: 32602170
# processing id: 25245812
# processing id: 25296661
# processing id: 24606117
# processing id: 29138794
# processing id: 26121746
# processing id: 20131255
# processing id: 19410716
# processing id: 21646588
# processing id: 28554908
# processing id: 20449934
# processing id: 23174471
# processing id: 21225563
# processing id: 31494097
# processing id: 24309905
# processing id: 22247480
# processing id: 22984008
# processing id: 28371882
# processing id: 26038524
# processing id: 17105759
# processing id: 23916805
# processing id: 21808751
# processing id: 26180109
# processing id: 26348032
# processing id: 31530665
# processing id: 19797474
# processing id: 30427582
# processing id: 27195316
# processing id: 29288545
# processing id: 22101225
# processing id: 24399553
# processing id: 23312829
# processing id: 22540269
# processing id: 26082504
# processing id: 30536081
# processing id: 28923789
# processing id: 27491280
# processing id: 19918088
# processing id: 20733306
# processing id: 27522631
# processing id: 22939029
# processing id: 28510679
# processing id: 32929215
# processing id: 25776953
# processing id: 28796913
# processing id: 25752740
# processing id: 31530666
# processing id: 22722512
# processing id: 19175450
# processing id: 31475794
# processing id: 27251051
# processing id: 20683766
# processing id: 22301417
# processing id: 25184863
# processing id: 23998969
# processing id: 24512252
# processing id: 21798658
# processing id: 29022746
# processing id: 25231953
# processing id: 33230526
# processing id: 26062002
# processing id: 21672497
# processing id: 32883108
# processing id: 32931496
# processing id: 21350053
# processing id: 30953543
# processing id: 28653394
# processing id: 31711168
# processing id: 29504498
# processing id: 25726088
# processing id: 29063313
# processing id: 34711335
# processing id: 22814329
# processing id: 28453471
# processing id: 26928521
# processing id: 23500237
# processing id: 19778495
# processing id: 28599636
# processing id: 20456213
# processing id: 33475736
# processing id: 32165251
# processing id: 21303529
# processing id: 31853709
# processing id: 29655627
# processing id: 24078868
# processing id: 25808103
# processing id: 26006754
# processing id: 30095776
# processing id: 23841532
# processing id: 29063860
# processing id: 23292882
# processing id: 33130104
# processing id: 22991696
# processing id: 28249150
# processing id: 34021038
# processing id: 29095245
# processing id: 29189540
# processing id: 34736575
# processing id: 27499448
# processing id: 26598476
# processing id: 32860422
# processing id: 24253247
# processing id: 24209977
# processing id: 24055414
# processing id: 23529377
# processing id: 23098672
# processing id: 33130235
# processing id: 31577341
# processing id: 26537182
# processing id: 27919865
# processing id: 31311674
# processing id: 23642377
# processing id: 30445896
# processing id: 22716976
# processing id: 33408512
# processing id: 22342106
# processing id: 32228379
# processing id: 29450890
# processing id: 27358435
# processing id: 24450301
# processing id: 22111718
# processing id: 27532880
# processing id: 25205868
# processing id: 28596794
# processing id: 22531237
# processing id: 27585384
# processing id: 21105279
# processing id: 24618964
# processing id: 32532275
# processing id: 25623903
# processing id: 24200404
# processing id: 24079852
# processing id: 27717756
# processing id: 20466589
# processing id: 30100404
# processing id: 24257721
# processing id: 30918101
# processing id: 29370813
# processing id: 31784217
# processing id: 33113596
# processing id: 33531690
# processing id: 28589238
# processing id: 24512981
# processing id: 30282622
# processing id: 30052097
# processing id: 26351344
# processing id: 29092882
# processing id: 28166784
# processing id: 31999300
# processing id: 28828489
# processing id: 32444457
# processing id: 30202085
# processing id: 34000112
# processing id: 23218813
# processing id: 31230825
# processing id: 34144047
# processing id: 30354631
# processing id: 31418808
# processing id: 32386720
# processing id: 28947466
# processing id: 29902295
# processing id: 32006006
# processing id: 32912276
# processing id: 33306564
# processing id: 24187118
# processing id: 27083334
# processing id: 26934128
# processing id: 20445180
# processing id: 21727232
# processing id: 25175313
# processing id: 30212861
# processing id: 31914963
# processing id: 30616614
# processing id: 25365753
# processing id: 32294346
# processing id: 28340322
# processing id: 29486514
# processing id: 32562683
# processing id: 20817209
# processing id: 24140268
# processing id: 32937045
# processing id: 23792149
# processing id: 26507180
# processing id: 30341453
# processing id: 33706344
# processing id: 22584132
# processing id: 24507460
# processing id: 25761202
# processing id: 30885591
# processing id: 29788903
# processing id: 33231929
# processing id: 27354234
# processing id: 33792547
# processing id: 24472478
# processing id: 32852613
# processing id: 19156629
# processing id: 26291900
# processing id: 30883056
# processing id: 33001232
# processing id: 24117597
# processing id: 25698492
# processing id: 27505115
# processing id: 29866475
# processing id: 19415122
# processing id: 26244563
# processing id: 24168767
# processing id: 30734266
# processing id: 21142534
# processing id: 30628860
# processing id: 33075806
# processing id: 19695549
# processing id: 24149930
# processing id: 25744115
# processing id: 30474567
# processing id: 30575407
# processing id: 24867013
# processing id: 27573561
# processing id: 26568588
# processing id: 31365113
# processing id: 31932084
# processing id: 27598855
# processing id: 30768393
# processing id: 30176883
# processing id: 32701367
# processing id: 29396092
# processing id: 30444982
# processing id: 25282520
# processing id: 34415011
# processing id: 26624824
# processing id: 26175145
# processing id: 32777055
# processing id: 27746061
# processing id: 28382371
# processing id: 22891287
# processing id: 29672714
# processing id: 32062791
# processing id: 30382728
# processing id: 19409657
# processing id: 25576879
# processing id: 29039979
# processing id: 34761694
# processing id: 27442691
# processing id: 28945118
# processing id: 31576433
# processing id: 28003221
# processing id: 23254903
# processing id: 21135327
# processing id: 33470755
# processing id: 23415472
# processing id: 25811395
# processing id: 21270326
# processing id: 28297591
# processing id: 31066646
# processing id: 32803641
# processing id: 23234725
# processing id: 30552937
# processing id: 28802777
# processing id: 23973522
# processing id: 33650630
# processing id: 21828231
# processing id: 22824474
# processing id: 29227727
# processing id: 22152181
# processing id: 28011757
# processing id: 30817018
# processing id: 33708484
# processing id: 24835833
# processing id: 31755906
# processing id: 22566583
# processing id: 33524060
# processing id: 21902621
# processing id: 28762527
# processing id: 23453090
# processing id: 24647726
# processing id: 21654093
# processing id: 26165588
# processing id: 22100010
# processing id: 31355957
# processing id: 28522181
# processing id: 31394600
# processing id: 32856605
# processing id: 22419732
# processing id: 30443999
# processing id: 25800900
# processing id: 28839341
# processing id: 32484552
# processing id: 30522501
# processing id: 24425420
# processing id: 30253043
# processing id: 30937600
# processing id: 32857445
# processing id: 19183825
# processing id: 20433751
# processing id: 33413075
# processing id: 31470814
# processing id: 25940724
# processing id: 30804739
# processing id: 21434995
# processing id: 30169322
# processing id: 22640930
# processing id: 32029684
# processing id: 30098962
# processing id: 26089554
# processing id: 31430268
# processing id: 30464411
# processing id: 24462230
# processing id: 33910578
# processing id: 19568773
# processing id: 29080265
# processing id: 23464930
# processing id: 27637340
# processing id: 24888818
# processing id: 33527249
# processing id: 30587441
# processing id: 25659187
# processing id: 23701526
# processing id: 30352894
# processing id: 32897344
# processing id: 28215362
# processing id: 25840904
# processing id: 28666993
# processing id: 28582240
# processing id: 25377349
# processing id: 30972702
# processing id: 30343455
# processing id: 31269364
# processing id: 27979383
# processing id: 29958855
# processing id: 22913893
# processing id: 32997095
# processing id: 25073879
# processing id: 31792940
# processing id: 25933099
# processing id: 26550795
# processing id: 19230772
# processing id: 26492541
# processing id: 32783644
# processing id: 32444306
# processing id: 26759138
# processing id: 32193541
# processing id: 24815533
# processing id: 26822398
# processing id: 18823658
# processing id: 29266308
# processing id: 20940250
# processing id: 29802530
# processing id: 31549577
# processing id: 32162970
# processing id: 26195058
# processing id: 24833247
# processing id: 22024001
# processing id: 25165041
# processing id: 23635914
# processing id: 26930527
# processing id: 20843249
# processing id: 31238925
# processing id: 33249632
# processing id: 32690640
# processing id: 21889410
# processing id: 22549879
# processing id: 29648647
# processing id: 28387616
# processing id: 33915104
# processing id: 26386793
# processing id: 32239164
# processing id: 33272036
# processing id: 25189089
# processing id: 32186653
# processing id: 33043600
# processing id: 24094768
# processing id: 23714781
# processing id: 26016655
# processing id: 23625945
# processing id: 22334811
# processing id: 28514601
# processing id: 27365387
# processing id: 26883526
# processing id: 32488672
# processing id: 24735128
# processing id: 21397626
# processing id: 25939894
# processing id: 25038977
# processing id: 25607727
# processing id: 32057574
# processing id: 31265100
# processing id: 30379086
# processing id: 28006055
# processing id: 31981106
# processing id: 31823222
# processing id: 29045520
# processing id: 31444872
# processing id: 19912135
# processing id: 23497452
# processing id: 22762347
# processing id: 33338496
# processing id: 34000119
# processing id: 30130430
# processing id: 27473306
# processing id: 32741143
# processing id: 24168957
# processing id: 23545372
# processing id: 23384404
# processing id: 20690893
# processing id: 24323795
# processing id: 29247148
# processing id: 25400062
# processing id: 24419418
# processing id: 31557380
# processing id: 34138638
# processing id: 23188489
# processing id: 30797638
# processing id: 24682463
# processing id: 20959530
# processing id: 28006041
# processing id: 26214039
# processing id: 24504441
# processing id: 30166073
# processing id: 28919201
# processing id: 26671818
# processing id: 33973838
# processing id: 30620370
# processing id: 19363221
# processing id: 19213680
# processing id: 26911380
# processing id: 27753650
# processing id: 33619370
# processing id: 25525171
# processing id: 34411158
# processing id: 19797985
# processing id: 33855215
# processing id: 32031887
# processing id: 22936892
# processing id: 28595611
# processing id: 20051221
# processing id: 27669017
# processing id: 26174114
# processing id: 25890673
# processing id: 31141104
# processing id: 24240354
# processing id: 23625191
# processing id: 21374690
# processing id: 28792952
# processing id: 22336221
# processing id: 26881417
# processing id: 33356422
# processing id: 33882206
# processing id: 21392602
# processing id: 25409112
# processing id: 27168434
# processing id: 31956422
# processing id: 24114969
# processing id: 30020415
# processing id: 24408401
# processing id: 28237411
# processing id: 23494931
# processing id: 33514274
# processing id: 26627989
# processing id: 26739717
# processing id: 31806413
# processing id: 27397608
# processing id: 31708380
# processing id: 33482699
# processing id: 33582306
# processing id: 34406354
# processing id: 30264119
# processing id: 17666597
# processing id: 32209248
# processing id: 23234617
# processing id: 25697851
# processing id: 20429832
# processing id: 22739142
# processing id: 21273172
# processing id: 21948782
# processing id: 26803328
# processing id: 33074143
# processing id: 23690364
# processing id: 33989539
# processing id: 23224207
# processing id: 34797506
# processing id: 29522174
# processing id: 21723064
# processing id: 21299274
# processing id: 25330017
# processing id: 26453773
# processing id: 27078022
# processing id: 31008751
# processing id: 22795046
# processing id: 22777096
# processing id: 28942334
# processing id: 26493786
# processing id: 27767328
# processing id: 32114502
# processing id: 29343507
# processing id: 29500065
# processing id: 27334739
# processing id: 30902750
# processing id: 20979470
# processing id: 29987324
# processing id: 27233466
# processing id: 28104250
# processing id: 31679946
# processing id: 33557578
# processing id: 32817358
# processing id: 24560483
# processing id: 29324595
# processing id: 28919143
# processing id: 20562124
# processing id: 27317843
# processing id: 25622149
# processing id: 26152562
# processing id: 22394386
# processing id: 31084291
# processing id: 17525777
# processing id: 22740509
# processing id: 28271424
# processing id: 32170033
# processing id: 29110972
# processing id: 29631362
# processing id: 26315282
# processing id: 21143878
# processing id: 33438437
# processing id: 24384588
# processing id: 30650326
# processing id: 31774028
# processing id: 26772822
# processing id: 23815124
# processing id: 23664718
# processing id: 32130184
# processing id: 30591028
# processing id: 30562322
# processing id: 25470228
# processing id: 30189282
# processing id: 34453917
# processing id: 28416247
# processing id: 19671656
# processing id: 21034899
# processing id: 27341450
# processing id: 32887873
# processing id: 32474744
# processing id: 33068751
# processing id: 21118280
# processing id: 28455321
# processing id: 20456211
# processing id: 25773607
# processing id: 32203691
# processing id: 29859917
# processing id: 34034612
# processing id: 31783739
# processing id: 30857452
# processing id: 18945398
# processing id: 29666071
# processing id: 34076401
# processing id: 30053162
# processing id: 29768149
# processing id: 30448355
# processing id: 32459035
# processing id: 29948025
# processing id: 27434441
# processing id: 24860180
# processing id: 32841554
# processing id: 28304237
# processing id: 31246522
# processing id: 25519680
# processing id: 24020899
# processing id: 23446104
# processing id: 28590309
# processing id: 31582358
# processing id: 25645847
# processing id: 18420099
# processing id: 28025374
# processing id: 34089122
# processing id: 25548329
# processing id: 30192751
# processing id: 23537458
# processing id: 32071051
# processing id: 29071764
# processing id: 25785967
# processing id: 33017565
# processing id: 31816249
# processing id: 25866155
# processing id: 32356074
# processing id: 30569637
# processing id: 27856497
# processing id: 32633541
# processing id: 31429023
# processing id: 22568450
# processing id: 28135841
# processing id: 32789619
# processing id: 28039187
# processing id: 24567843
# processing id: 27203272
# processing id: 29659595
# processing id: 30852711
# processing id: 25151341
# processing id: 30478008
# processing id: 32732305
# processing id: 28803380
# processing id: 22945623
# processing id: 30807663
# processing id: 29407226
# processing id: 33000465
# processing id: 30550828
# processing id: 33196806
# processing id: 31524498
# processing id: 30025713
# processing id: 26967206
# processing id: 34087115
# processing id: 23425012
# processing id: 25372556
# processing id: 31470005
# processing id: 23842022
# processing id: 21346609
# processing id: 27439911
# processing id: 33631141
# processing id: 25139785
# processing id: 26402769
# processing id: 21857944
# processing id: 28768069
# processing id: 26673811
# processing id: 33301785
# processing id: 24007748
# processing id: 27736051
# processing id: 28145413
# processing id: 32281393
# processing id: 34242498
# processing id: 31693078
# processing id: 30638392
# processing id: 17494926
# processing id: 31923341
# processing id: 25108027
# processing id: 30450545
# processing id: 24438321
# processing id: 30522886
# processing id: 20492840
# processing id: 34032604
# processing id: 22594907
# processing id: 25156886
# processing id: 23094708
# processing id: 28839340
# processing id: 24372304
# processing id: 23846316
# processing id: 30241766
# processing id: 19470987
# processing id: 24384538
# processing id: 31653353
# processing id: 26580237
# processing id: 23724353
# processing id: 20606148
# processing id: 31053157
# processing id: 28236984
# processing id: 22714699
# processing id: 27225353
# processing id: 21285388
# processing id: 25769357
# processing id: 34052232
# processing id: 23168362
# processing id: 32660977
# processing id: 30801744
# processing id: 29452684
# processing id: 33973917
# processing id: 31804851
# processing id: 28449657
# processing id: 33353412
# processing id: 22370531
# processing id: 29287665
# processing id: 29602631
# processing id: 29576624
# processing id: 22893770
# processing id: 21949432
# processing id: 29402141
# processing id: 27696762
# processing id: 32000630
# processing id: 24875610
# processing id: 22197127
# processing id: 32404343
# processing id: 21175312
# processing id: 34704970
# processing id: 29101797
# processing id: 32739049
# processing id: 28455295
# processing id: 29370538
# processing id: 34774885
# processing id: 24194506
# processing id: 23881862
# processing id: 29501590
# processing id: 25048345
# processing id: 30284674
# processing id: 19619690
# processing id: 29038282
# processing id: 25376267
# processing id: 25476727
# processing id: 25070302
# processing id: 34649459
# processing id: 28052977
# processing id: 24872136
# processing id: 31912462
# processing id: 29627188
# processing id: 23041618
# processing id: 21346100
# processing id: 21861971
# processing id: 33957642
# processing id: 33538237
# processing id: 24007934
# processing id: 24911369
# processing id: 30666823
# processing id: 33759836
# processing id: 26501204
# processing id: 27062270
# processing id: 31399377
# processing id: 22077144
# processing id: 21320840
# processing id: 29503112
# processing id: 33443580
# processing id: 27807925
# processing id: 21193187
# processing id: 30030268
# processing id: 24947719
# processing id: 31087093
# processing id: 20622031
# processing id: 25865762
# processing id: 26241686
# processing id: 32306247
# processing id: 28506776
# processing id: 20525995
# processing id: 29967197
# processing id: 34882169
# processing id: 27050187
# processing id: 19674727
# processing id: 32492293
# processing id: 34027703
# processing id: 32819394
# processing id: 23006447
# processing id: 31138224
# processing id: 33625893
# processing id: 25321146
# processing id: 28697253
# processing id: 26907736
# processing id: 32641236
# processing id: 33124987
# processing id: 31058771
# processing id: 29854923
# processing id: 33720350
# processing id: 31695840
# processing id: 25402495
# processing id: 32475838
# processing id: 31402114
# processing id: 22064267
# processing id: 30522969
# processing id: 26432182
# processing id: 30068306
# processing id: 33872573
# processing id: 26489804
# processing id: 33974564
# processing id: 32652544
# processing id: 32643857
# processing id: 32150750
# processing id: 26070699
# processing id: 23672672
# processing id: 34593120
# processing id: 23508540
# processing id: 29652551
# processing id: 22311004
# processing id: 19958855
# processing id: 33483617
# processing id: 30383184
# processing id: 34261541
# processing id: 31228560
# processing id: 25419594
# processing id: 32077907
# processing id: 32865374
# processing id: 21677329
# processing id: 27880789
# processing id: 32711801
# processing id: 27574838
# processing id: 30925126
# processing id: 31418022
# processing id: 23369827
# processing id: 21345487
# processing id: 27856432
# processing id: 18990046
# processing id: 30939090
# processing id: 26267726
# processing id: 21384219
# processing id: 25917337
# processing id: 33346789
# processing id: 30459138
# processing id: 19858155
# processing id: 27956565
# processing id: 25054392
# processing id: 22389254
# processing id: 26064192
# processing id: 23816026
# processing id: 33687687
# processing id: 32362166
# processing id: 30922373
# processing id: 29746232
# processing id: 22205355
# processing id: 30629889
# processing id: 27059799
# processing id: 27683846
# processing id: 32954885
# processing id: 31757774
# processing id: 22509297
# processing id: 32021143
# processing id: 31629805
# processing id: 21732797
# processing id: 24183563
# processing id: 20883227
# processing id: 30146935
# processing id: 31533906
# processing id: 32504574
# processing id: 32303206
# processing id: 23015655
# processing id: 24940526
# processing id: 21174145
# processing id: 24210923
# processing id: 24229753
# processing id: 31833849
# processing id: 21672123
# processing id: 22003405
# processing id: 31100455
# processing id: 24767265
# processing id: 23873891
# processing id: 31214256
# processing id: 25151418
# processing id: 29203355
# processing id: 23602601
# processing id: 22336878
# processing id: 23685080
# processing id: 33328761
# processing id: 29879277
# processing id: 29279300
# processing id: 30747254
# processing id: 30718072
# processing id: 34015478
# processing id: 30994197
# processing id: 32950693
# processing id: 26143613
# processing id: 30415602
# processing id: 19392908
# processing id: 23134211
# processing id: 30797651
# processing id: 21306238
# processing id: 27030601
# processing id: 34782430
# processing id: 21768541
# processing id: 34920739
# processing id: 32282044
# processing id: 28642125
# processing id: 24885187
# processing id: 30531234
# processing id: 18032763
# processing id: 27264220
# processing id: 34108929
# processing id: 29103847
# processing id: 29898836
# processing id: 25542911
# processing id: 25413621
# processing id: 24156640
# processing id: 22496918
# processing id: 27978548
# processing id: 30516797
# processing id: 29615003
# processing id: 21216197
# processing id: 23159770
# processing id: 28005705
# processing id: 22017192
# processing id: 28700805
# processing id: 29857145
# processing id: 27523719
# processing id: 30421856
# processing id: 27567966
# processing id: 28007348
# processing id: 27093610
# processing id: 22760005
# processing id: 30340932
# processing id: 25372087
# processing id: 28363637
# processing id: 31776029
# processing id: 30182376
# processing id: 26209747
# processing id: 32809014
# processing id: 29339393
# processing id: 31207561
# processing id: 22395584
# processing id: 26328624
# processing id: 31447131
# processing id: 31607205
# processing id: 31185157
# processing id: 30272234
# processing id: 34398236
# processing id: 20363366
# processing id: 27723271
# processing id: 22320292
# processing id: 32192799
# processing id: 21527040
# processing id: 25742759
# processing id: 24297189
# processing id: 33601293
# processing id: 19321573
# processing id: 28608719
# processing id: 20511481
# processing id: 27573938
# processing id: 26069034
# processing id: 33460320
# processing id: 29875101
# processing id: 19553647
# processing id: 33945982
# processing id: 26453968
# processing id: 32942939
# processing id: 25158865
# processing id: 34750128
# processing id: 28194729
# processing id: 34665204
# processing id: 25427288
# processing id: 20045700
# processing id: 23351522
# processing id: 26241253
# processing id: 34780798
# processing id: 32034447
# processing id: 32049551
# processing id: 30646266
# processing id: 25878309
# processing id: 23439301
# processing id: 23975226
# processing id: 32978755
# processing id: 26762363
# processing id: 18668535
# processing id: 24521108
# processing id: 33110622
# processing id: 20498618
# processing id: 33478521
# processing id: 27423055
# processing id: 26414902
# processing id: 25619410
# processing id: 24725616
# processing id: 24450858
# processing id: 27718781
# processing id: 22891232
# processing id: 25058845
# processing id: 30882240
# processing id: 32925629
# processing id: 33537703
# processing id: 22210240
# processing id: 29778387
# processing id: 31818787
# processing id: 26865601
# processing id: 32930994
# processing id: 31017637
# processing id: 25576215
# processing id: 28241231
# processing id: 34783839
# processing id: 29447737
# processing id: 32209647
# processing id: 33715994
# processing id: 26547357
# processing id: 33516293
# processing id: 31439336
# processing id: 33214209
# processing id: 29430796
# processing id: 24708675
# processing id: 29429912
# processing id: 32372382
# processing id: 31945015
# processing id: 23528626
# processing id: 26376350
# processing id: 26427562
# processing id: 33249467
# processing id: 25798575
# processing id: 22485048
# processing id: 27601428
# processing id: 20505177
# processing id: 27417017
# processing id: 27362506
# processing id: 24461901
# processing id: 25459097
# processing id: 29694685
# processing id: 25905829
# processing id: 29807477
# 9000 finished...
# processing id: 28935273
# processing id: 32252976
# processing id: 33588594
# processing id: 33324394
# processing id: 30303904
# processing id: 20965379
# processing id: 32139381
# processing id: 30419103
# processing id: 22554598
# processing id: 23332012
# processing id: 30095762
# processing id: 27922453
# processing id: 32050833
# processing id: 27309523
# processing id: 24905795
# processing id: 23938061
# processing id: 22449293
# processing id: 34406911
# processing id: 25546486
# processing id: 30794084
# processing id: 25667244
# processing id: 26820239
# processing id: 26253730
# processing id: 32187462
# processing id: 21091279
# processing id: 19843481
# processing id: 30197273
# processing id: 28947039
# processing id: 30862659
# processing id: 21897852
# processing id: 26811165
# processing id: 27780334
# processing id: 29226570
# processing id: 24284293
# processing id: 21561960
# processing id: 25504861
# processing id: 24034580
# processing id: 26979999
# processing id: 24238862
# processing id: 30901302
# processing id: 24461666
# processing id: 21482568
# processing id: 33939497
# processing id: 23332366
# processing id: 33888245
# processing id: 23436336
# processing id: 31800988
# processing id: 23816489
# processing id: 26704701
# processing id: 31896036
# processing id: 24091311
# processing id: 23971740
# processing id: 23811853
# processing id: 21839467
# processing id: 29439691
# processing id: 25673148
# processing id: 27012781
# processing id: 28095881
# processing id: 29976505
# processing id: 28724581
# processing id: 23382191
# processing id: 20529203
# processing id: 23277897
# processing id: 25826322
# processing id: 32986075
# processing id: 20533546
# processing id: 34109545
# processing id: 20054046
# processing id: 28637881
# processing id: 27842543
# processing id: 32761160
# processing id: 25295804
# processing id: 25524798
# processing id: 29912399
# processing id: 26348166
# processing id: 34671652
# processing id: 27160892
# processing id: 30168896
# processing id: 29100702
# processing id: 32432388
# processing id: 26680684
# processing id: 32981097
# processing id: 30982556
# processing id: 18835953
# processing id: 31207009
# processing id: 30130351
# processing id: 30472141
# processing id: 30343489
# processing id: 20216298
# processing id: 21240023
# processing id: 20949623
# processing id: 26554383
# processing id: 25077418
# processing id: 22710649
# processing id: 28545978
# processing id: 23964752
# processing id: 30294699
# processing id: 33861329
# processing id: 26044291
# processing id: 34426527
# processing id: 20934459
# processing id: 25938681
# processing id: 23106926
# processing id: 19752419
# processing id: 33051646
# processing id: 26156651
# processing id: 26513517
# processing id: 31851666
# processing id: 21691166
# processing id: 28399844
# processing id: 31930360
# processing id: 28826627
# processing id: 24740134
# processing id: 25683037
# processing id: 26475054
# processing id: 27196121
# processing id: 18606901
# processing id: 24983709
# processing id: 30683124
# processing id: 25545025
# processing id: 18178525
# processing id: 32119035
# processing id: 31302695
# processing id: 29059442
# processing id: 29759777
# processing id: 33998674
# processing id: 28977399
# processing id: 30169969
# processing id: 22447793
# processing id: 20598967
# processing id: 30858257
# processing id: 23883379
# processing id: 31948641
# processing id: 31642690
# processing id: 29751001
# processing id: 25706950
# processing id: 27389174
# processing id: 29848776
# processing id: 27549242
# processing id: 19359142
# processing id: 28252528
# processing id: 29140155
# processing id: 23059649
# processing id: 32044999
# processing id: 20064072
# processing id: 33165774
# processing id: 31253454
# processing id: 19675193
# processing id: 33177349
# processing id: 24588936
# processing id: 25465416
# processing id: 29956495
# processing id: 28796687
# processing id: 19587338
# processing id: 23545917
# processing id: 25107900
# processing id: 29436756
# processing id: 29471679
# processing id: 23106931
# processing id: 25548978
# processing id: 29535132
# processing id: 25074072
# processing id: 25759571
# processing id: 30695290
# processing id: 32299860
# processing id: 33636648
# processing id: 30809633
# processing id: 30573030
# processing id: 31138319
# processing id: 20697044
# processing id: 32380271
# processing id: 24633684
# processing id: 26585622
# processing id: 34747368
# processing id: 22170366
# processing id: 21911782
# processing id: 30580130
# processing id: 26237742
# processing id: 32416978
# processing id: 31940698
# processing id: 26487588
# processing id: 24918567
# processing id: 25811889
# processing id: 31738834
# processing id: 22991405
# processing id: 22088518
# processing id: 27993828
# processing id: 20166794
# processing id: 24862623
# processing id: 28374207
# processing id: 30634036
# processing id: 28076709
# processing id: 33478712
# processing id: 25454878
# processing id: 27276397
# processing id: 29668352
# processing id: 27225977
# processing id: 27980409
# processing id: 29496722
# processing id: 21844490
# processing id: 19339720
# processing id: 31484697
# processing id: 25880826
# processing id: 27978579
# processing id: 34090504
# processing id: 28651929
# processing id: 24970858
# processing id: 29937430
# processing id: 33082245
# processing id: 24443547
# processing id: 33262641
# processing id: 22004765
# processing id: 22628490
# processing id: 21982669
# processing id: 31599840
# processing id: 28426106
# processing id: 25062611
# processing id: 28320223
# processing id: 32480252
# processing id: 30788847
# processing id: 25157951
# processing id: 32389658
# processing id: 34879449
# processing id: 26770664
# processing id: 27232052
# processing id: 29069359
# processing id: 31699517
# processing id: 25818754
# processing id: 32586587
# processing id: 31707788
# processing id: 29292308
# processing id: 26980371
# processing id: 33979557
# processing id: 26181088
# processing id: 32818112
# processing id: 25613307
# processing id: 29369537
# processing id: 33334939
# processing id: 24125150
# processing id: 26400827
# processing id: 34608032
# processing id: 24184053
# processing id: 29504252
# processing id: 23223867
# processing id: 22889694
# processing id: 31694576
# processing id: 22742523
# processing id: 29979640
# processing id: 33834177
# processing id: 31567024
# processing id: 28407727
# processing id: 29619533
# processing id: 30362375
# processing id: 26372383
# processing id: 26666258
# processing id: 27174694
# processing id: 23895801
# processing id: 21982652
# processing id: 33622517
# processing id: 31237809
# processing id: 28942807
# processing id: 29028981
# processing id: 27693439
# processing id: 19909879
# processing id: 20306820
# processing id: 20040554
# processing id: 27872067
# processing id: 23256574
# processing id: 25625809
# processing id: 31135883
# processing id: 25851628
# processing id: 21231862
# processing id: 35083774
# processing id: 34246602
# processing id: 27671974
# processing id: 25415805
# processing id: 21830049
# processing id: 26628417
# processing id: 29116597
# processing id: 26471432
# processing id: 23715562
# processing id: 31420414
# processing id: 32599655
# processing id: 24934787
# processing id: 34235612
# processing id: 28424871
# processing id: 21652026
# processing id: 21714641
# processing id: 34034753
# processing id: 31375042
# processing id: 27955663
# processing id: 25227656
# processing id: 31957953
# processing id: 21558517
# processing id: 21600054
# processing id: 25600421
# processing id: 28787505
# processing id: 30552595
# processing id: 19948625
# processing id: 28697102
# processing id: 24622005
# processing id: 32949542
# processing id: 22132138
# processing id: 22446565
# processing id: 21992852
# processing id: 32353418
# processing id: 26115386
# processing id: 20942666
# processing id: 21670715
# processing id: 34819017
# processing id: 33074326
# processing id: 23855761
# processing id: 20617456
# processing id: 31845894
# processing id: 20194812
# processing id: 27914822
# processing id: 32564804
# processing id: 26228031
# processing id: 25038355
# processing id: 24247410
# processing id: 24026523
# processing id: 21402547
# processing id: 23621902
# processing id: 33026630
# processing id: 33334727
# processing id: 25952085
# processing id: 24326106
# processing id: 27232649
# processing id: 21060036
# processing id: 28141897
# processing id: 31490342
# processing id: 33713841
# processing id: 34389633
# processing id: 32088207
# processing id: 32446752
# processing id: 28423174
# processing id: 31887537
# processing id: 21576282
# processing id: 26889973
# processing id: 29889750
# processing id: 34400362
# processing id: 27443429
# processing id: 21665007
# processing id: 33914256
# processing id: 26173635
# processing id: 32862232
# processing id: 30898609
# processing id: 31206808
# processing id: 21386067
# processing id: 25622198
# processing id: 21414843
# processing id: 32459005
# processing id: 32147881
# processing id: 32524500
# processing id: 28832750
# processing id: 21507715
# processing id: 21247627
# processing id: 27046320
# processing id: 33278280
# processing id: 22341427
# processing id: 23169523
# processing id: 19403902
# processing id: 33314332
# processing id: 18824641
# processing id: 34175001
# processing id: 27611736
# processing id: 29960800
# processing id: 25659956
# processing id: 26242213
# processing id: 29954454
# processing id: 33461302
# processing id: 23704675
# processing id: 33724104
# processing id: 27223147
# processing id: 31740443
# processing id: 24467979
# processing id: 31778659
# processing id: 33772963
# processing id: 24571205
# processing id: 25266438
# processing id: 29486867
# processing id: 24150466
# processing id: 30306144
# processing id: 28962558
# processing id: 33913260
# processing id: 23193209
# processing id: 25908010
# processing id: 33128725
# processing id: 26782632
# processing id: 31085948
# processing id: 34246118
# processing id: 24101698
# processing id: 29242014
# processing id: 32721228
# processing id: 31193674
# processing id: 21747241
# processing id: 25456692
# processing id: 22507979
# processing id: 25872754
# processing id: 34319398
# processing id: 30640653
# processing id: 33153527
# processing id: 24952712
# processing id: 29620722
# processing id: 30139779
# processing id: 31647185
# processing id: 31334793
# processing id: 35073865
# processing id: 20868642
# processing id: 32013700
# processing id: 30216086
# processing id: 25133963
# processing id: 32434932
# processing id: 27391533
# processing id: 26302024
# processing id: 30586726
# processing id: 31634154
# processing id: 23863036
# processing id: 24717964
# processing id: 27995521
# processing id: 26299520
# processing id: 31068182
# processing id: 32035892
# processing id: 25464907
# processing id: 19699854
# processing id: 23704677
# processing id: 28333318
# processing id: 30642925
# processing id: 22108765
# processing id: 32160801
# processing id: 16894061
# processing id: 29937267
# processing id: 29235884
# processing id: 28903892
# processing id: 24021517
# processing id: 25402400
# processing id: 21983154
# processing id: 18823363
# processing id: 23008442
# processing id: 19765321
# processing id: 25741971
# processing id: 20131302
# processing id: 28797414
# processing id: 19188505
# processing id: 29564996
# processing id: 27007010
# processing id: 26811525
# processing id: 24584926
# processing id: 23141817
# processing id: 32203978
# processing id: 25311218
# processing id: 27364808
# processing id: 26148007
# processing id: 22325170
# processing id: 33979488
# processing id: 22781424
# processing id: 26267623
# processing id: 29099333
# processing id: 32521325
# processing id: 30742834
# processing id: 23835333
# processing id: 23607594
# processing id: 29779416
# processing id: 26164807
# processing id: 26746456
# processing id: 28667230
# processing id: 23136909
# processing id: 28755394
# processing id: 31253091
# processing id: 30239757
# processing id: 32363929
# processing id: 23645886
# processing id: 32847838
# processing id: 23921857
# processing id: 29759957
# processing id: 30877186
# processing id: 32678452
# processing id: 20375406
# processing id: 21777972
# processing id: 31791552
# processing id: 23975663
# processing id: 33677183
# processing id: 21262883
# processing id: 25822284
# processing id: 32131611
# processing id: 23410138
# processing id: 23522788
# processing id: 32191267
# processing id: 27657520
# processing id: 34272849
# processing id: 31669738
# processing id: 28606591
# processing id: 28809995
# processing id: 23641006
# processing id: 22266043
# processing id: 22109997
# processing id: 27184785
# processing id: 21397868
# processing id: 30859218
# processing id: 31138278
# processing id: 27136493
# processing id: 27769273
# processing id: 22549370
# processing id: 25716637
# processing id: 28074446
# processing id: 27159290
# processing id: 26040806
# processing id: 29698720
# processing id: 23889885
# processing id: 22786596
# processing id: 32160422
# processing id: 28485186
# processing id: 27804270
# processing id: 32139505
# processing id: 30794310
# processing id: 22265697
# processing id: 23545279
# processing id: 32702101
# processing id: 29055056
# processing id: 26516810
# processing id: 19800193
# processing id: 22685234
# processing id: 24781936
# processing id: 31241194
# processing id: 22115661
# processing id: 30950656
# processing id: 25637602
# processing id: 27794487
# processing id: 26227019
# processing id: 30741813
# processing id: 28581821
# processing id: 32668111
# processing id: 23874588
# processing id: 27206463
# processing id: 33013880
# processing id: 34132753
# processing id: 23883378
# processing id: 31125092
# processing id: 27599329
# processing id: 21571362
# processing id: 33692621
# processing id: 26409473
# processing id: 22134226
# processing id: 32965495
# processing id: 34380322
# processing id: 24671945
# processing id: 19906348
# processing id: 29961640
# processing id: 28737608
# processing id: 31722152
# processing id: 28104251
# processing id: 31321713
# processing id: 25888263
# processing id: 23377341
# processing id: 27816497
# processing id: 26556097
# processing id: 30125001
# processing id: 23622922
# processing id: 33461308
# processing id: 25399551
# processing id: 23022285
# processing id: 28988541
# processing id: 25011722
# processing id: 32393129
# processing id: 30586750
# processing id: 25562462
# processing id: 28215615
# processing id: 22963001
# processing id: 30145929
# processing id: 24813026
# processing id: 26707905
# processing id: 26658447
# processing id: 24331545
# processing id: 26125415
# processing id: 34186022
# processing id: 30670043
# processing id: 29273067
# processing id: 30582156
# processing id: 34620618
# processing id: 29614502
# processing id: 24802206
# processing id: 28390934
# processing id: 24231627
# processing id: 32252548
# processing id: 22000810
# processing id: 26507494
# processing id: 21423852
# processing id: 27175291
# processing id: 30257191
# processing id: 33620905
# processing id: 25840499
# processing id: 22585772
# processing id: 30407513
# processing id: 27060177
# processing id: 29443664
# processing id: 23845016
# processing id: 21529904
# processing id: 34878707
# processing id: 27179847
# processing id: 19139333
# processing id: 24356792
# processing id: 28274253
# processing id: 22852760
# processing id: 23306000
# processing id: 23062548
# processing id: 25745075
# processing id: 24106072
# processing id: 27194308
# processing id: 34581608
# processing id: 22030902
# processing id: 27879555
# processing id: 29293895
# processing id: 33349862
# processing id: 30935742
# processing id: 24240244
# processing id: 19028741
# processing id: 26071616
# processing id: 26018036
# processing id: 32430458
# processing id: 29070709
# processing id: 26341920
# processing id: 24352340
# processing id: 24509965
# processing id: 34384301
# processing id: 23321547
# processing id: 24131140
# processing id: 19061696
# processing id: 25908323
# processing id: 19420195
# processing id: 31104833
# processing id: 29389170
# processing id: 32479328
# processing id: 31912791
# processing id: 32516282
# processing id: 25178568
# processing id: 25798215
# processing id: 30370613
# processing id: 19920051
# processing id: 29701615
# processing id: 33461782
# processing id: 21606537
# processing id: 31558473
# processing id: 33090921
# processing id: 34462864
# processing id: 28679430
# processing id: 28654972
# processing id: 22422823
# processing id: 21317148
# processing id: 31810797
# processing id: 31209698
# processing id: 27669457
# processing id: 34904132
# processing id: 29294429
# processing id: 23582415
# processing id: 33871063
# processing id: 22915657
# processing id: 21768314
# processing id: 31300571
# processing id: 23531349
# processing id: 26818781
# processing id: 31448420
# processing id: 28399902
# processing id: 21707573
# processing id: 34135015
# processing id: 20119464
# processing id: 22353644
# processing id: 28100522
# processing id: 20206776
# processing id: 34807241
# processing id: 24289224
# processing id: 24914549
# processing id: 24163386
# processing id: 32008947
# processing id: 29581078
# processing id: 22695473
# processing id: 20609969
# processing id: 29426320
# processing id: 27215976
# processing id: 25424810
# processing id: 34192387
# processing id: 24021518
# processing id: 20685497
# processing id: 21576556
# processing id: 29945727
# processing id: 31785550
# processing id: 32193187
# processing id: 22509337
# processing id: 20672903
# processing id: 31620067
# processing id: 29898870
# processing id: 28347835
# processing id: 27238065
# processing id: 21674393
# processing id: 23532097
# processing id: 32203207
# processing id: 28399825
# processing id: 30334693
# processing id: 21482191
# processing id: 22504093
# processing id: 25500324
# processing id: 25225436
# processing id: 29029606
# processing id: 32289719
# processing id: 24794368
# processing id: 27437883
# processing id: 30347019
# processing id: 26269240
# processing id: 24718367
# processing id: 22721596
# processing id: 18784101
# processing id: 28516874
# processing id: 29032136
# processing id: 34383954
# processing id: 20227053
# processing id: 30950565
# processing id: 27986684
# processing id: 34954841
# processing id: 31189511
# processing id: 25345840
# processing id: 29733982
# processing id: 24019259
# processing id: 20200306
# processing id: 23446197
# processing id: 29017067
# processing id: 23257370
# processing id: 21719618
# processing id: 22017936
# processing id: 33047216
# processing id: 26527790
# processing id: 28931586
# processing id: 26844197
# processing id: 31688452
# processing id: 33626904
# processing id: 20025778
# processing id: 27716095
# processing id: 30586695
# processing id: 31918169
# processing id: 29029210
# processing id: 27526692
# processing id: 23904292
# processing id: 32780844
# processing id: 29243164
# processing id: 27824758
# processing id: 29898844
# processing id: 29793828
# processing id: 19519260
# processing id: 22900785
# processing id: 26241597
# processing id: 24825642
# processing id: 25659348
# processing id: 31954680
# processing id: 33345878
# processing id: 29305927
# processing id: 29105594
# processing id: 19493565
# processing id: 26613263
# processing id: 29141858
# processing id: 26803764
# processing id: 34264500
# processing id: 30563770
# processing id: 29921144
# processing id: 28003500
# processing id: 34215454
# processing id: 26461821
# processing id: 29146401
# processing id: 28898536
# processing id: 32350915
# processing id: 22204724
# processing id: 23760428
# processing id: 33734539
# processing id: 31851290
# processing id: 30059671
# processing id: 34907907
# processing id: 26844757
# processing id: 29921143
# processing id: 30202945
# processing id: 21557440
# processing id: 20808854
# processing id: 21676990
# processing id: 28981379
# processing id: 29650764
# processing id: 33427851
# processing id: 28924103
# processing id: 29792074
# processing id: 20109208
# processing id: 33081825
# processing id: 33620895
# processing id: 24632280
# processing id: 30177021
# processing id: 34261994
# processing id: 32436683
# processing id: 28872913
# processing id: 33290772
# processing id: 24915778
# processing id: 25117805
# processing id: 21353695
# processing id: 30383086
# processing id: 29972647
# processing id: 33278291
# processing id: 26962728
# processing id: 28389391
# processing id: 25479584
# processing id: 23857320
# processing id: 28722271
# processing id: 24766732
# processing id: 25562205
# processing id: 24286114
# processing id: 30045066
# processing id: 32933342
# processing id: 27031099
# processing id: 31391223
# processing id: 29633583
# processing id: 33771837
# processing id: 26761707
# processing id: 23642462
# processing id: 27927683
# processing id: 31427046
# processing id: 26706237
# processing id: 23278590
# processing id: 24578164
# processing id: 24814607
# processing id: 34214499
# processing id: 26997243
# processing id: 28211560
# processing id: 22443427
# processing id: 33600915
# processing id: 22225814
# processing id: 28498975
# processing id: 22248871
# processing id: 30354781
# processing id: 24655729
# processing id: 26338095
# processing id: 27028914
# processing id: 30554783
# processing id: 23800482
# processing id: 25595177
# processing id: 33617632
# processing id: 29760228
# processing id: 33372185
# processing id: 22805294
# processing id: 19336625
# processing id: 30165984
# processing id: 34339951
# processing id: 23932548
# processing id: 23343062
# processing id: 19767093
# processing id: 24329972
# processing id: 32729897
# processing id: 31396834
# processing id: 23635626
# processing id: 31327670
# processing id: 27716283
# processing id: 24834924
# processing id: 24355994
# processing id: 29055031
# processing id: 30980514
# processing id: 31502893
# processing id: 24211163
# processing id: 30217232
# ...
# processing id: 32710396
# processing id: 31606589
# processing id: 29915123
# processing id: 22064591
# processing id: 32568464
# processing id: 22122960
# processing id: 33993302
# processing id: 23953056
# processing id: 24006953
# processing id: 32123969
# processing id: 26144908
# processing id: 23500276
# processing id: 30597042
# processing id: 33121204
# processing id: 33263359
# processing id: 34229554
# processing id: 26470910
# processing id: 23325525
# processing id: 23490226
# processing id: 20593911
# processing id: 23537966
# processing id: 30865796
# processing id: 24021498
# processing id: 34258469
# processing id: 24237691
# processing id: 22784040
# processing id: 29783024
# processing id: 33835383
# processing id: 23268367
# processing id: 31167892
# processing id: 30531560
# processing id: 26521019
# processing id: 25803642
# processing id: 33428631
# processing id: 20460548
# processing id: 23557820
# processing id: 33979802
# processing id: 28241185
# processing id: 23628617
# processing id: 29752413
# processing id: 20736470
# processing id: 33504496
# processing id: 21543987
# processing id: 25524686
# processing id: 30694576
# processing id: 25913022
# processing id: 27918780
# processing id: 28228106
# processing id: 33639181
# processing id: 26158679
# processing id: 28597604
# processing id: 30910541
# processing id: 27358434
# processing id: 24550378
# processing id: 25819865
# processing id: 25617202
# processing id: 30718952
# processing id: 25388660
# processing id: 29931216
# processing id: 34000130
# processing id: 20957659
# processing id: 33568389
# processing id: 25727273
# processing id: 34297275
# processing id: 34862359
# processing id: 32719011
# processing id: 33794441
# processing id: 29886522
# processing id: 22223180
# processing id: 23398269
# processing id: 33878341
# processing id: 27497762
# processing id: 24910934
# processing id: 28353191
# processing id: 30898204
# processing id: 19439741
# processing id: 21504485
# processing id: 33059389
# processing id: 31394601
# processing id: 33772416
# processing id: 30295803
# processing id: 30206821
# processing id: 31779684
# processing id: 25459096
# processing id: 30300367
# processing id: 20332351
# processing id: 22244781
# processing id: 21471141
# processing id: 27528177
# processing id: 28318835
# processing id: 30791871
# processing id: 19208459
# processing id: 34556320
# processing id: 25652112
# processing id: 21569570
# processing id: 23770108
# processing id: 28847455
# processing id: 25085357
# processing id: 29281036
# processing id: 24740025
# processing id: 33834354
# processing id: 24880577
# processing id: 24245543
# processing id: 33087119
# processing id: 29761915
# processing id: 29254862
# processing id: 25123600
# processing id: 26529070
# processing id: 29489017
# processing id: 22234716
# processing id: 32221866
# processing id: 29278818
# processing id: 21898590
# processing id: 27914656
# processing id: 31556978
# processing id: 26465985
# processing id: 30242745
# processing id: 25381051
# processing id: 25411413
# processing id: 22730366
# processing id: 26905901
# processing id: 31925529
# processing id: 20493653
# processing id: 28202004
# processing id: 31350934
# processing id: 33904781
# processing id: 30770519
# processing id: 33581146
# processing id: 23086558
# processing id: 33761207
# processing id: 27175657
# processing id: 32667636
# processing id: 29201994
# processing id: 30926955
# processing id: 19432546
# processing id: 33338413
# processing id: 27737774
# processing id: 33238728
# processing id: 29721850
# processing id: 23158522
# processing id: 31542292
# processing id: 27780336
# processing id: 32739962
# processing id: 26352680
# processing id: 34097048
# processing id: 21415072
# processing id: 31215837
# processing id: 26224203
# processing id: 29150421
# processing id: 25753362
# processing id: 31371315
# processing id: 21294997
# processing id: 26433819
# processing id: 29550566
# processing id: 22429066
# processing id: 27339303
# processing id: 24760791
# processing id: 25302624
# processing id: 20494267
# processing id: 24162898
# processing id: 27831492
# processing id: 24841647
# processing id: 26630143
# processing id: 22949147
# processing id: 33497547
# processing id: 25199526
# processing id: 34412009
# processing id: 31443654
# processing id: 26829760
# processing id: 32726475
# processing id: 32459919
# processing id: 25148234
# processing id: 29644875
# processing id: 24107072
# processing id: 27991835
# processing id: 27039081
# processing id: 29903674
# processing id: 23942868
# processing id: 33100049
# processing id: 28737971
# processing id: 21601519
# processing id: 20085534
# processing id: 33543139
# processing id: 29080924
# processing id: 27532829
# processing id: 27348211
# processing id: 28072797
# processing id: 29398998
# processing id: 34747701
# processing id: 33930380
# processing id: 28554911
# processing id: 34244703
# processing id: 32122219
# processing id: 27044557
# processing id: 30993499
# processing id: 21628399
# processing id: 29220623
# processing id: 20707601
# processing id: 22443231
# processing id: 31182338
# processing id: 31450969
# processing id: 24682346
# processing id: 23380890
# processing id: 29066452
# processing id: 20573750
# processing id: 31796519
# processing id: 32822633
# processing id: 22830462
# processing id: 19052126
# processing id: 31606455
# processing id: 30092324
# processing id: 27809891
# processing id: 22994519
# processing id: 26540028
# processing id: 24342385
# processing id: 31380506
# processing id: 23665965
# processing id: 23471469
# processing id: 33440084
# processing id: 25751199
# processing id: 27410907
# processing id: 33788162
# processing id: 26392095
# processing id: 31914241
# processing id: 32048083
# processing id: 23559082
# processing id: 31912801
# processing id: 30524702
# processing id: 31482511
# processing id: 32946821
# processing id: 20040610
# processing id: 25048382
# processing id: 22325110
# processing id: 29625879
# processing id: 23141853
# processing id: 30354558
# processing id: 27565938
# processing id: 20679166
# processing id: 29635383
# processing id: 22920930
# processing id: 28464935
# processing id: 31980545
# processing id: 32851411
# processing id: 23895803
# processing id: 23018312
# processing id: 18722631
# processing id: 19189907
# processing id: 27440003
# processing id: 27203508
# processing id: 25189602
# processing id: 23856361
# processing id: 27564409
# processing id: 34437410
# processing id: 27529375
# processing id: 33736821
# processing id: 29396713
# processing id: 31394603
# processing id: 20151997
# processing id: 34128818
# processing id: 28570481
# processing id: 23787544
# processing id: 28235705
# processing id: 30721737
# processing id: 24057294
# processing id: 32071044
# processing id: 28926793
# processing id: 24595567
# processing id: 29462231
# processing id: 30150460
# processing id: 25077835
# processing id: 30543801
# processing id: 31742631
# processing id: 23564755
# processing id: 26868602
# processing id: 32891191
# processing id: 32522251
# processing id: 33831213
# processing id: 25141241
# processing id: 27330023
# processing id: 31582355
# processing id: 22474202
# processing id: 32135208
# processing id: 27130202
# processing id: 31403587
# processing id: 30714202
# processing id: 23473338
# processing id: 26488677
# processing id: 31171092
# processing id: 24228710
# processing id: 27669539
# processing id: 31925605
# processing id: 26729431
# processing id: 30935633
# processing id: 26879051
# processing id: 30341029
# processing id: 20719253
# processing id: 23725394
# processing id: 31964419
# processing id: 33855222
# processing id: 28256307
# processing id: 33576735
# processing id: 30055562
# processing id: 22158330
# processing id: 28065708
# processing id: 24747867
# processing id: 29949045
# processing id: 17179052
# processing id: 32620262
# processing id: 21417623
# processing id: 26049551
# processing id: 26501236
# processing id: 30690294
# processing id: 21421179
# processing id: 24013058
# processing id: 32393252
# processing id: 26308112
# processing id: 24607003
# processing id: 34378456
# processing id: 30975570
# processing id: 33113526
# processing id: 23891461
# processing id: 24084072
# processing id: 25473191
# processing id: 30288127
# processing id: 19217077
# processing id: 26421634
# processing id: 26435889
# processing id: 26891418
# processing id: 31492718
# processing id: 30755061
# processing id: 26475142
# processing id: 25851955
# processing id: 34392331
# processing id: 22927525
# processing id: 26102252
# processing id: 25503265
# processing id: 27608829
# processing id: 22137081
# processing id: 31332045
# processing id: 21266651
# processing id: 26586780
# processing id: 22293363
# processing id: 26300464
# processing id: 32921587
# processing id: 32220916
# processing id: 21856481
# processing id: 28437225
# processing id: 33050900
# processing id: 26888433
# processing id: 25168268
# processing id: 32150232
# processing id: 32368713
# processing id: 31821429
# processing id: 25985907
# processing id: 30170012
# processing id: 31241362
# processing id: 23589390
# processing id: 24839884
# processing id: 27046309
# processing id: 22213771
# processing id: 26503204
# processing id: 26241419
# processing id: 20042557
# processing id: 29769203
# processing id: 32925623
# processing id: 23585999
# processing id: 32678716
# processing id: 24612097
# processing id: 21278617
# processing id: 31152740
# processing id: 26125448
# processing id: 28576675
# processing id: 29889751
# processing id: 33838113
# processing id: 28118533
# processing id: 25883095
# processing id: 33937611
# processing id: 28899524
# processing id: 24429175
# processing id: 21880336
# processing id: 33070154
# processing id: 29789243
# processing id: 22357140
# processing id: 30946495
# processing id: 31730370
# processing id: 26568428
# processing id: 33887244
# processing id: 27354258
# processing id: 24954745
# processing id: 30134976
# processing id: 29784470
# processing id: 31609930
# processing id: 31087226
# processing id: 28729311
# processing id: 25462653
# processing id: 23159524
# processing id: 28933799
# processing id: 31479105
# processing id: 20219292
# processing id: 29617064
# processing id: 33587132
# processing id: 27313280
# processing id: 22405352
# processing id: 32498620
# processing id: 23680407
# processing id: 19828532
# processing id: 31485965
# processing id: 25857939
# processing id: 33241721
# processing id: 28846163
# processing id: 31092895
# processing id: 29180522
# processing id: 27247226
# processing id: 21731833
# processing id: 33999548
# processing id: 19683639
# processing id: 33258422
# processing id: 33110039
# processing id: 30449328
# processing id: 22915643
# processing id: 19626391
# processing id: 30681964
# processing id: 29490959
# processing id: 27091810
# processing id: 32521132
# processing id: 20001836
# processing id: 21871372
# processing id: 24237300
# processing id: 32402161
# processing id: 21055739
# processing id: 30316931
# processing id: 27890522
# processing id: 32492087
# processing id: 28864675
# processing id: 25631362
# processing id: 33683083
# processing id: 33252490
# processing id: 20573799
# processing id: 23311856
# processing id: 27690741
# processing id: 26927909
# processing id: 27206939
# processing id: 33583120
# processing id: 25192771
# processing id: 26683347
# processing id: 26534874
# processing id: 26811535
# processing id: 31254526
# processing id: 28427286
# processing id: 26747792
# processing id: 32419304
# processing id: 34534923
# processing id: 31944276
# processing id: 25104617
# processing id: 33026766
# processing id: 26688484
# processing id: 28597542
# processing id: 21784436
# processing id: 23911183
# processing id: 20969457
# processing id: 22998754
# processing id: 29555812
# processing id: 23279924
# processing id: 29788075
# processing id: 26316013
# processing id: 28011247
# processing id: 30759221
# processing id: 26669919
# processing id: 20007923
# processing id: 33306991
# processing id: 22907732
# processing id: 27653448
# processing id: 33587397
# processing id: 30694917
# processing id: 34031871
# processing id: 29925489
# processing id: 28522352
# processing id: 30880443
# processing id: 32297992
# processing id: 27986874
# processing id: 30689507
# processing id: 24158787
# processing id: 27899747
# processing id: 19130903
# processing id: 28595147
# processing id: 20101008
# processing id: 28116151
# processing id: 22147444
# processing id: 30545576
# processing id: 22056021
# processing id: 34190962
# processing id: 32975556
# processing id: 24055306
# processing id: 25733749
# processing id: 19470318
# processing id: 28620791
# processing id: 22689677
# processing id: 34388360
# processing id: 30056451
# processing id: 31650412
# processing id: 25097243
# processing id: 23435622
# processing id: 23982695
# processing id: 27331882
# processing id: 30867034
# processing id: 24450992
# processing id: 22847059
# processing id: 19236277
# processing id: 25873729
# processing id: 26869678
# processing id: 29415175
# processing id: 26840902
# processing id: 26039600
# processing id: 30261955
# processing id: 32141723
# processing id: 31981558
# processing id: 26225498
# processing id: 32391584
# processing id: 24262299
# processing id: 27732819
# processing id: 29170073
# processing id: 30020461
# processing id: 24567202
# processing id: 27037091
# processing id: 26424232
# processing id: 23953385
# processing id: 31822399
# processing id: 26545726
# processing id: 23786504
# processing id: 31820339
# processing id: 27192969
# processing id: 23290324
# processing id: 25677353
# processing id: 26429522
# processing id: 22627983
# processing id: 34437784
# processing id: 30621831
# processing id: 25692915
# processing id: 26291768
# processing id: 34465695
# processing id: 24667994
# processing id: 25812927
# processing id: 30414275
# processing id: 32696704
# processing id: 25596910
# processing id: 25511551
# processing id: 32389735
# processing id: 29884413
# processing id: 31340042
# processing id: 24572997
# processing id: 29610265
# processing id: 32702169
# processing id: 30614717
# processing id: 33609100
# processing id: 31915807
# processing id: 24128381
# processing id: 30346242
# processing id: 34131048
# processing id: 31345462
# processing id: 28510680
# processing id: 29221779
# processing id: 25214516
# processing id: 31354089
# processing id: 32496566
# processing id: 20377407
# processing id: 31676303
# processing id: 27805299
# processing id: 17551159
# processing id: 34867786
# processing id: 30792007
# processing id: 30488542
# processing id: 22517103
# processing id: 28746019
# processing id: 22900984
# processing id: 28844816
# processing id: 33560426
# processing id: 28079023
# processing id: 30095550
# processing id: 29725983
# processing id: 29031492
# processing id: 24698485
# processing id: 34560015
# processing id: 28747487
# processing id: 30423468
# processing id: 21550957
# processing id: 29793970
# processing id: 30149332
# processing id: 27082709
# processing id: 25951857
# processing id: 33744963
# processing id: 21185401
# processing id: 33588897
# processing id: 32683644
# processing id: 31262379
# processing id: 24723432
# processing id: 26879279
# processing id: 23033239
# processing id: 25138978
# processing id: 28214613
# processing id: 25127659
# processing id: 23460709
# processing id: 21498674
# processing id: 26271843
# processing id: 22789766
# processing id: 30266774
# processing id: 27034455
# processing id: 33138628
# processing id: 27296201
# processing id: 28194841
# processing id: 23715567
# processing id: 29452178
# processing id: 32145994
# processing id: 32654156
# processing id: 32164675
# processing id: 22691240
# processing id: 22619366
# processing id: 32453369
# processing id: 29188425
# processing id: 30145671
# processing id: 20163842
# processing id: 21926663
# processing id: 20889211
# processing id: 22420596
# processing id: 25809680
# processing id: 29342163
# processing id: 20431425
# processing id: 34747583
# processing id: 24066715
# processing id: 33765912
# processing id: 30342255
# processing id: 23907995
# processing id: 22995323
# processing id: 25524487
# processing id: 29101117
# processing id: 32852352
# processing id: 28043937
# processing id: 22257825
# processing id: 20660805
# processing id: 31112385
# processing id: 24445955
# processing id: 28947022
# processing id: 32166429
# processing id: 25877498
# processing id: 26313445
# processing id: 24065443
# processing id: 28455085
# processing id: 29322164
# processing id: 31147675
# processing id: 21617168
# processing id: 21050476
# processing id: 26997579
# processing id: 32617646
# processing id: 24881631
# processing id: 26184525
# processing id: 30236308
# processing id: 33744812
# processing id: 22694905
# processing id: 31288028
# processing id: 30998747
# processing id: 20030854
# processing id: 23838777
# processing id: 25566387
# Retrieved xml saved in /content/gdrive/MyDrive/Demographic Analysis Project/pmid_abstracts/

# %%
import xml.etree.ElementTree as xml_parser
import re
import tarfile
from tqdm.auto import tqdm
import json
import os,codecs
from time import sleep
import pandas as pd
import urllib.request as ur
import pickle
from random import randint

# must run

path = '/content/gdrive/MyDrive/Demographic Analysis Project/pmid_abstracts/'


def parse_abstract_bypmid(pmid, pm_from_path):
    one_file = os.path.join(pm_from_path, str(pmid)+'.xml')
    try:
        with open(one_file, 'r') as f:
            datam = f.read()
    except Exception as e:
        print(e)
        return None
    
    datam = re.sub("<i>", "", datam)  # remove <i> in xml to avoid failure in parsing .text
    datam = re.sub("</i>", "", datam)
    datam = re.sub("<sup>", "", datam)  # remove <i> in xml to avoid failure in parsing .text
    datam = re.sub("</sup>", "", datam)
    datam = re.sub("<sub>", "", datam)  # remove <i> in xml to avoid failure in parsing .text
    datam = re.sub("</sub>", "", datam)
    datam = re.sub("<em>", "", datam)  # remove <i> in xml to avoid failure in parsing .text
    datam = re.sub("</em>", "", datam)
    datam = re.sub("<strong>", "", datam)  # remove <i> in xml to avoid failure in parsing .text
    datam = re.sub("</strong>", "", datam)
    datam = re.sub("<b>", "", datam)  # remove <b> in xml to avoid failure in parsing .text
    datam = re.sub("</b>", "", datam)

    xmldoc = xml_parser.fromstring(datam)
    
    PubmedArticle = xmldoc.find("PubmedArticle")
    abstract_text = ""
    title_text=""
    meta_data={}

    meta_data['pubdate'] = ""
    meta_data['source'] = ""
    meta_data['volume'] = ""
    meta_data['pages'] = ""
    meta_data['pubtype'] = []
    meta_data['authors'] = []

    if PubmedArticle is not None:
        data = PubmedArticle.find("MedlineCitation")
        if data is not None:
            article = data.find("Article")
            if article is not None:
                title = article.find("ArticleTitle")
                #print("Title:",title.text)
                title_text = title.text
                abstract = article.find("Abstract")
                if abstract is not None:
                    for seg in abstract:
                        if seg.text:
                            if 'NlmCategory' in seg.attrib:
                                abstract_text = abstract_text + "\n" + seg.attrib['NlmCategory'] + " : " + seg.text
                            elif 'Label' in seg.attrib:
                                abstract_text = abstract_text + "\n" + seg.attrib['Label'] + " : " + seg.text
                            else:
                                abstract_text = abstract_text + "\n" + seg.text
                        elif 'Label' in seg.attrib and len(seg.attrib['Label'].split(':'))>1:
                            abstract_text = abstract_text + "\n" + seg.attrib['Label'].split(':')[0] + " : " + seg.attrib['Label'].split(':')[1]
                
                journal = article.find("Journal")
                if journal is not None:
                    if journal.find("Title") is not None:
                        meta_data['source_title'] = journal.find("Title").text
                    if journal.find("ISOAbbreviation") is not None:
                        meta_data['source'] = journal.find("ISOAbbreviation").text
                    if journal.find("JournalIssue").find('Volume') is not None:
                        meta_data['volume'] = journal.find("JournalIssue").find('Volume').text
                   
                Pagination = article.find("Pagination")
                if Pagination is not None:
                    meta_data['pages'] = Pagination.find("MedlinePgn").text 
    

                AuthorList = article.find('AuthorList')

                if AuthorList is not None:
                    for author in AuthorList.findall('Author'):
                        if author.find('Initials') is not None and author.find('LastName') is not None:
                            meta_data['authors'].append(author.find('Initials').text+'. '+author.find('LastName').text)
                PublicationTypeList = article.find('PublicationTypeList')
                if PublicationTypeList is not None:
                    for PublicationType in PublicationTypeList.findall('PublicationType'):
                        meta_data['pubtype'].append(PublicationType.text)

        PubmedData = PubmedArticle.find('PubmedData')
        if PubmedData is not None:
            History = PubmedData.find('History')
            if History.find("PubMedPubDate") is not None:
                date = History.find("PubMedPubDate")
                Year=""
                Month=""
                Day=""
                if date.find('Year') is not None:
                    Year =date.find('Year').text
                if date.find('Month') is not None:
                    Month=date.find('Month').text+'/'
                if date.find('Day') is not None:
                    Day=date.find('Day').text+'/'
                
                meta_data['pubdate'] = Month + Day +Year
                
    meta_data['title'] = title_text
    #print (meta_data)

    #abstract_text = re.search("©|(copyright)","", abstract_text)
    abstract_text = re.sub("^\s+", "", abstract_text)

    return title_text, abstract_text, meta_data


def get_all_files(rootdir):
    files_dirs = []
    for root, dirs, files in os.walk(rootdir):
        for name in files:
            if name.endswith((".xml")):
                full_path = os.path.join(root, name)
                files_dirs.append(full_path)
    return files_dirs


def save_abstracts(pmidlist, path):
    pm_from_path = path
    pm_path = os.path.join(path, 'txt/')
    os.makedirs(pm_path, exist_ok=True)
    
    exceptionlistfile=codecs.open(os.path.join(pm_from_path,"exceptionlist"),'w')
    for id in tqdm(pmidlist):
#             print(f'processing {id}')
        id = id.rstrip()
        filename=id+".txt"
        # file_meta=id+".meta"
        file_meta_pkl = id+"_meta"+".pkl"
        #print (id)
        #Yingcheng added
        if os.path.exists(os.path.join(pm_path,filename)):
            print ("existed, skipped")
            continue
        if re.search("^#",id):
            continue 
        if re.search("^pmid", id):
            continue
        if re.search("^\s*$",id):
            continue
        id = id.rstrip().split("\t")[0]

        try:
            title, ab, meta_data= parse_abstract_bypmid(id, pm_from_path)
#                 print(f'title:\t{title}')
#                 print(ab)
#                 print(f'meta:\t{meta_data}')
            if ab == "":
                print(id, " no abstract")
                exceptionlistfile.write(str(id)+"\n")
                continue

            sections = ab.split("\n")
            
            outfile = codecs.open(os.path.join(pm_path,filename),'w')
            outfile.write("TITLE : "+str(title)+"\n")
            for s in sections:
                if s == "":
                    continue
                outfile.write(s+"\n")

            with open(os.path.join(pm_path,file_meta_pkl),'wb') as fout:
                pickle.dump(meta_data, fout)                  

        except Exception as e:
            print("Exection at ", id,"!!!")
#                 print("Exection message: ", e,"!!!")
            exceptionlistfile.write(str(id)+"\n")
            continue

    print ("Retrieved abstracts saved in", pm_path)
        

save_abstracts(pmidlist, path)
# Out:
#   0%|          | 0/12864 [00:00<?, ?it/s]
# 34190999  no abstract
# 22012178  no abstract
# 20040671  no abstract
# 28306371  no abstract
# 24898665  no abstract
# 27387422  no abstract
# 24930531  no abstract
# 28704847  no abstract
# 26844757  no abstract
# 32950849  no abstract
# 25631362  no abstract
# 28760541  no abstract
# 26011755  no abstract
# 28532759  no abstract
# 30139779  no abstract
# 33483617  no abstract
# 28389391  no abstract
# 31192894  no abstract
# 28389393  no abstract
# 26971692  no abstract
# 20732794  no abstract
# 24966061  no abstract
# 26977746  no abstract
# 32515118  no abstract
# 28668546  no abstract
# 27007007  no abstract
# 27466629  no abstract
# 24612976  no abstract
# 25456692  no abstract
# 31707833  no abstract
# 25010170  no abstract
# 30991823  no abstract
# 29046319  no abstract
# 24046475  no abstract
# 24467979  no abstract
# 26663235  no abstract
# 30255316  no abstract
# 25840600  no abstract
# 23018312  no abstract
# 30117142  no abstract
# 28687231  no abstract
# 30003479  no abstract
# 32701367  no abstract
# 35006163  no abstract
# 32077361  no abstract
# 28679611  no abstract
# 33238728  no abstract
# 29729809  no abstract
# 26278063  no abstract
# 24996961  no abstract
# 22991405  no abstract
# 30237305  no abstract
# 27007010  no abstract
# 29653640  no abstract
# 33176443  no abstract
# 21205715  no abstract
# 29760228  no abstract
# 30882240  no abstract
# 31034999  no abstract
# 25818754  no abstract
# 34293527  no abstract
# 29348179  no abstract
# 29412688  no abstract
# 24018545  no abstract
# 25425684  no abstract
# 30245150  no abstract
# 27306615  no abstract
# 31707795  no abstract
# 25695181  no abstract
# 32031690  no abstract
# Retrieved abstracts saved in /content/gdrive/MyDrive/Demographic Analysis Project/pmid_abstracts/txt/

# %%
ls /content/gdrive/MyDrive/Demographic\ Analysis\ Project/pmid_abstracts/txt/ | wc -l
# Out:
# ls: cannot open directory '/content/gdrive/MyDrive/Demographic Analysis Project/pmid_abstracts/txt/': Input/output error
# 0

# %%
import os
import codecs
import re
from time import sleep
pm_path = '/content/gdrive/MyDrive/Demographic Analysis Project/pmid_abstracts/'
if not os.path.exists(pm_path):
    os.mkdir(pm_path)
exceptionlistfile=codecs.open(os.path.join(pm_path,"exceptionlist"),'w')
for (index,id) in enumerate(pmidlist):
    id = id.rstrip()
    filename=id+".txt"
    # file_meta=id+".meta"
    file_meta_pkl = id+"_meta"+".pkl"
    #print (id)
    #Yingcheng added
    if os.path.exists(os.path.join(pm_path,filename)):
        print ("existed, skipped")
        continue
    if re.search("^#",id):
        continue 
    if re.search("^pmid", id):
        continue
    if re.search("^\s*$",id):
        continue
    id = id.rstrip().split("\t")[0]

    if (index) % 1000 == 0:
        print(index,"finished...")
    sleep(0.5)

    try:
    #if True:
        title, ab, meta_data= get_abstract_bypmid(id)
        if ab == "":
            print (id, " no abstract")
            exceptionlistfile.write(str(id)+"\n")
            continue

        sections = ab.split("\n")
        
        outfile = codecs.open(os.path.join(pm_path,filename),'w')
        outfile.write("TITLE : "+str(title)+"\n")
        for s in sections:
            if s == "":
                continue
            outfile.write(s+"\n")
        
        # outfile_meta = codecs.open(os.path.join(pm_path,file_meta),'w')
        # outfile_meta.write(str(meta_data))

        with open(os.path.join(pm_path,file_meta_pkl),'wb') as fout:
            pickle.dump(meta_data, fout)
            

    except:
        print("Expection at ", id,"!!!")
        exceptionlistfile.write(str(id)+"\n")
        continue

print ("Retrieved abstracts saved in", pm_path)
# Out:
# 0 finished...
# 29348179  no abstract
# 30003479  no abstract
# 28668546  no abstract
# 23018312  no abstract
# 28679611  no abstract
# 25695181  no abstract
# 22012178  no abstract
# 26977746  no abstract
# 1000 finished...
# 26971692  no abstract
# 31707833  no abstract
# 30882240  no abstract
# 25456692  no abstract
# 2000 finished...
# 27306615  no abstract
# 32077361  no abstract
# 25840600  no abstract
# 34293527  no abstract
# 24018545  no abstract
# 27007007  no abstract
# 3000 finished...
# 33483617  no abstract
# 26011755  no abstract
# 29729809  no abstract
# 28687231  no abstract
# 24046475  no abstract
# 26278063  no abstract
# 32031690  no abstract
# 4000 finished...
# 29653640  no abstract
# 28389391  no abstract
# 29412688  no abstract
# 5000 finished...
# 29046319  no abstract
# 31192894  no abstract
# 25010170  no abstract
# 22991405  no abstract
# 25818754  no abstract
# 30991823  no abstract
# 6000 finished...
# 28389393  no abstract
# 28532759  no abstract
# 25631362  no abstract
# 26663235  no abstract
# 20040671  no abstract
# 24467979  no abstract
# 7000 finished...
# 20732794  no abstract
# 33176443  no abstract
# 30255316  no abstract
# 33238728  no abstract
# 21205715  no abstract
# 31707795  no abstract
# 8000 finished...
# 24930531  no abstract
# 26844757  no abstract
# 27387422  no abstract
# 9000 finished...
# 32701367  no abstract
# 24898665  no abstract
# 31034999  no abstract
# 24996961  no abstract
# 30117142  no abstract
# 27007010  no abstract
# 10000 finished...
# 29760228  no abstract
# 30237305  no abstract
# 32950849  no abstract
# 11000 finished...
# 28306371  no abstract
# 34190999  no abstract
# 24966061  no abstract
# 25425684  no abstract
# 30245150  no abstract
# 24612976  no abstract
# 12000 finished...
# 27466629  no abstract
# 30139779  no abstract
# 28704847  no abstract
# 32515118  no abstract
# 28760541  no abstract
# Retrieved abstracts saved in /content/gdrive/MyDrive/Demographic Analysis Project/pmid_abstracts/

# %% [markdown]
# ## mulitiprocess version (Skip)
# Not quite working with request exceeding errors.

# %%
from multiprocessing import Process, Manager, Semaphore
import pprint

da = datetime.datetime(2000, 1, 1)
def dict_all(d, nctid, sema):
    d[nctid] = get_pubmed_linked_articles(nctid, da, 'narrow')
    time.sleep(1)
    sema.release()

# %%
concurrency = 20

sema = Semaphore(concurrency)
with Manager() as manager:
    d = manager.dict()
    # jobs = [Process(target=dict_all, args=(d, i)) for i in range(5)]
    all_processes = []
    for i in tqdm(nctid_list_to_map):
        # once 20 processes are running, the following `acquire` call
        # will block the main process since `sema` has been reduced
        # to 0. This loop will continue only after one or more
        # previously created processes complete.
        sema.acquire()
        p = Process(target=dict_all, args=(d, i, sema))
        all_processes.append(p)
        # time.sleep()
        p.start()
    # `d` is a DictProxy object that can be converted to dict
    # _ = [p.start() for p in jobs]
    # _ = [p.join() for p in jobs]
    # inside main process, wait for all processes to finish
    for p in all_processes:
        p.join()

    pprint.pprint(dict(d))
